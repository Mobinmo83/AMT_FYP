# %% [markdown]
# # Post-Processing Ablation Study — OF_full_run_v2
#
# This notebook evaluates the impact of **7 post-processing methods** on the
# Onsets & Frames baseline model (OF_full_run_v2, 1000 epochs, full MAESTRO).

# %% [markdown]
# ---
# ## Environment Setup

# %%
# ── GPU check ─────────────────────────────────────────────────────────────
import torch
assert torch.cuda.is_available(), "No GPU! Change runtime to GPU."
print(f"GPU : {torch.cuda.get_device_name(0)}")
print(f"CUDA: {torch.version.cuda}")
print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
# Out:
# GPU : NVIDIA RTX PRO 6000 Blackwell Server Edition
# CUDA: 12.8
# VRAM: 102.0 GB

# %%
# ── Mount Google Drive ─────────────────────────────────────────────────────
from google.colab import drive
drive.mount('/content/drive')
print("Drive mounted ✓")
# Out:
# Mounted at /content/drive
# Drive mounted ✓

# %%
# ── Clone / update repo ────────────────────────────────────────────────────
import os
from getpass import getpass

REPO_DIR = '/content/AMT_FYP'
TOKEN    = getpass('GitHub token: ')

if not os.path.exists(REPO_DIR):
    os.system(f"git clone https://{TOKEN}@github.com/Mobinmo83/AMT_FYP.git {REPO_DIR}")
    print(f"Cloned → {REPO_DIR}")
else:
    os.system(f"cd {REPO_DIR} && git pull")
    print(f"Pulled latest → {REPO_DIR}")
# Out:
# GitHub token: ··········
# Cloned → /content/AMT_FYP

# %%
# %cd /content/AMT_FYP/piano_amt
# !pip install -q -r requirements.txt
print("Packages installed ✓")
# Out:
# /content/AMT_FYP/piano_amt
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 103.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 22.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.8/102.8 kB 16.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 190.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 278.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 13.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 12.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 8.4 MB/s eta 0:00:00
#   Building wheel for pretty_midi (setup.py) ... done
# Packages installed ✓

# %%
# ── sys.path + imports ─────────────────────────────────────────────────────
import sys
import mir_eval

PROJECT_ROOT = '/content/AMT_FYP/piano_amt'
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

from src.constants import N_MELS, FRAMES_PER_SECOND, N_KEYS
assert N_MELS == 229 and abs(FRAMES_PER_SECOND - 31.25) < 1e-6 and N_KEYS == 88

from models.onsets_frames.decode_advanced import advanced_rolls_to_note_events
from models.onsets_frames.evaluate_advanced import run_advanced_evaluation

print("All imports OK ✓")
print("  decode_advanced.py  ✓")
print("  evaluate_advanced.py ✓")
# Out:
# All imports OK ✓
#   decode_advanced.py  ✓
#   evaluate_advanced.py ✓

# %% [markdown]
# ---
# ## Paths & Configuration

# %%
import os, glob

# ── Paths ────────────────────────────────────────────────────────────────────
DRIVE_ROOT   = '/content/drive/MyDrive/piano_amt'
MAESTRO_ROOT = f'{DRIVE_ROOT}/maestro-v3.0.0'
CACHE_DIR    = f'{DRIVE_ROOT}/cache'
RUNS_DIR     = f'{DRIVE_ROOT}/runs'
BEST_CKPT    = f'{RUNS_DIR}/OF_full_run_v2/checkpoints/best.pt'

# ── Evaluation settings ──────────────────────────────────────────────────────
SPLIT            = 'validation'     # 'test' for final, 'validation' for tuning
MODEL_COMPLEXITY = 48
MAX_FILES        = None       # None = all files in split

# ── Common kwargs (locked for all experiments) ───────────────────────────────
EVAL_KWARGS = dict(
    checkpoint_path      = BEST_CKPT,
    maestro_root         = MAESTRO_ROOT,
    cache_dir            = CACHE_DIR,
    split                = SPLIT,
    max_files            = MAX_FILES,
    model_complexity     = MODEL_COMPLEXITY,
    save_midi            = False,
    save_plots           = False,
    onset_threshold      = 0.4,
    frame_threshold      = 0.4,
    offset_threshold     = 0.5,
    onset_tolerance      = 0.05,
    offset_ratio         = 0.2,
    offset_min_tolerance = 0.05,
    velocity_tolerance   = 0.1,
)

# ── Storage for all results ──────────────────────────────────────────────────
ALL_SUMMARIES = {}  # config_name → summary dict

# ── Verify ───────────────────────────────────────────────────────────────────
assert os.path.exists(BEST_CKPT), f"Checkpoint not found: {BEST_CKPT}"
npzs = glob.glob(f'{CACHE_DIR}/*.npz')
print(f"Checkpoint : {BEST_CKPT}")
print(f"Cache files: {len(npzs)}")
print(f"Split      : {SPLIT}")
print(f"Max files  : {MAX_FILES or 'ALL'}")
print("\nReady ✓")
# Out:
# Checkpoint : /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/checkpoints/best.pt
# Cache files: 1276
# Split      : validation
# Max files  : ALL
#
# Ready ✓

# %% [markdown]
# ---
# # Parameter Tuning using validation set
#
# ### Exp 0 — Baseline (No Post-Processing)
# All methods OFF. Should match your original `eval_test` results exactly.

# %%
ALL_SUMMARIES['exp0_baseline'] = run_advanced_evaluation(
    **EVAL_KWARGS,
    config_name='exp0_baseline_validation',
)
print("Exp 0 DONE ✓")
# Out:
# Device: NVIDIA RTX PRO 6000 Blackwell Server Edition
# Loaded checkpoint: /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/checkpoints/best.pt
#   Trained for 990 epochs, val_loss=0.0453
#   Model parameters: 26,491,256
#
#   Post-processing config: 'exp0_baseline_validation'
#     (no post-processing — baseline decode)
#
# Evaluating 137/137 files from 'validation' split...
#   Strategy: full-length single-pass inference + advanced post-processing
#
#   Evaluated 137/137 files in 505.3s
#
#
#
#
#
#
#
# ============================================================
#         — Decoding + evaluation protocol —
# ============================================================
#
#   Decode thresholds:
#     onset_threshold:   0.40
#     frame_threshold:   0.40
#     offset_threshold:  0.50
#   Evaluation tolerances:
#     onset_tolerance:   50 ms
#     pitch_tolerance:   0.25 (25 cents)
#     offset_ratio:      0.2
#     offset_min_tol:    50 ms
#     velocity_tolerance:0.1
#     mir_eval version:  0.8.2
#
#
#
#
#
# ============================================================
#   EVALUATION SUMMARY — validation split (n=137)
# ============================================================
#
#   Dataset:    MAESTRO v3.0.0, validation split
#   Model:      OnsetsAndFrames (complexity=48, 26,491,256 params)
#   Checkpoint: epoch 990, val_loss=0.0453
#   Config:     exp0_baseline_validation
#   GPU:        NVIDIA RTX PRO 6000 Blackwell Server Edition
#   Eval time:  505.3s (3.7s/file)
#
#
#
#
#
#
# ============================================================
#                  — Primary metrics —
# ============================================================
#
#   Metric                                     P        R       F1
#   ------------------------------------------------------------
#   Note (onset+pitch)                    0.9540   0.9173   0.9347
#   Note w/ offset                        0.6324   0.6075   0.6192
#   Note w/ offset+vel                    0.6024   0.5790   0.5901
#   Frame                                 0.8031   0.7604   0.7793
#
#
#   ------------------------------------------------------------
#   Avg notes/file:  pred=4442  gt=4667  ratio=0.95
#
#
#
#
#
# ============================================================
#          — Supplementary error analysis —
# ============================================================
#
#   Offset MAE                           112.9 ms
#   Onset MAE                            3.6 ms
#   Chord completeness                   0.9133
#   Duplicate note rate                  0.0348
#
#   Results saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_validation_exp0_baseline_validation
# ============================================================
#
# Exp 0 DONE ✓

# %% [markdown]
# ### Exp 1 — Method 3 ONLY: Minimum Note Duration
# Increases MIN_DUR from 16ms to 50ms. Removes spurious very short notes.

# %%
ALL_SUMMARIES['exp1_m3_min_dur'] = run_advanced_evaluation(
    **EVAL_KWARGS,
    config_name='exp1_m3_min_dur_validation',
    min_note_duration_ms=55.0, # 60 before
)
print("Exp 1 DONE ✓")
# Out:
# Device: NVIDIA RTX PRO 6000 Blackwell Server Edition
# Loaded checkpoint: /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/checkpoints/best.pt
#   Trained for 990 epochs, val_loss=0.0453
#   Model parameters: 26,491,256
#
#   Post-processing config: 'exp1_m3_min_dur_validation'
#     ✓ Min Note Duration = 55.0ms
#
# Evaluating 137/137 files from 'validation' split...
#   Strategy: full-length single-pass inference + advanced post-processing
#
#   Evaluated 137/137 files in 477.0s
#
#
#
#
#
#
#
# ============================================================
#         — Decoding + evaluation protocol —
# ============================================================
#
#   Decode thresholds:
#     onset_threshold:   0.40
#     frame_threshold:   0.40
#     offset_threshold:  0.50
#   Evaluation tolerances:
#     onset_tolerance:   50 ms
#     pitch_tolerance:   0.25 (25 cents)
#     offset_ratio:      0.2
#     offset_min_tol:    50 ms
#     velocity_tolerance:0.1
#     mir_eval version:  0.8.2
#
#
#
#
#
# ============================================================
#   EVALUATION SUMMARY — validation split (n=137)
# ============================================================
#
#   Dataset:    MAESTRO v3.0.0, validation split
#   Model:      OnsetsAndFrames (complexity=48, 26,491,256 params)
#   Checkpoint: epoch 990, val_loss=0.0453
#   Config:     exp1_m3_min_dur_validation
#   GPU:        NVIDIA RTX PRO 6000 Blackwell Server Edition
#   Eval time:  477.0s (3.5s/file)
#
#
#
#
#
#
# ============================================================
#                  — Primary metrics —
# ============================================================
#
#   Metric                                     P        R       F1
#   ------------------------------------------------------------
#   Note (onset+pitch)                    0.9895   0.9148   0.9499
#   Note w/ offset                        0.6557   0.6059   0.6292
#   Note w/ offset+vel                    0.6247   0.5777   0.5997
#   Frame                                 0.8031   0.7604   0.7793
#
#
#   ------------------------------------------------------------
#   Avg notes/file:  pred=4264  gt=4667  ratio=0.91
#
#
#
#
#
# ============================================================
#          — Supplementary error analysis —
# ============================================================
#
#   Offset MAE                           110.0 ms
#   Onset MAE                            4.1 ms
#   Chord completeness                   0.9109
#   Duplicate note rate                  0.0000
#
#   Results saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_validation_exp1_m3_min_dur_validation
# ============================================================
#
# Exp 1 DONE ✓

# %% [markdown]
# ### Exp 2 — Method 1 ONLY: Onset-Conditioned Offset
# Uses the offset head to end notes. The offset head is trained but ignored by original decode.

# %%
# not effective after tuning expriemnt with 0.9
ALL_SUMMARIES['exp2_m1_offset'] = run_advanced_evaluation(
    **EVAL_KWARGS,
    config_name='exp2_m1_offset_validation',
    use_onset_conditioned_offset=True,
)
print("Exp 2 DONE ✓")
# Out:
# Device: NVIDIA RTX PRO 6000 Blackwell Server Edition
# Loaded checkpoint: /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/checkpoints/best.pt
#   Trained for 990 epochs, val_loss=0.0453
#   Model parameters: 26,491,256
#
#   Post-processing config: 'exp2_m1_offset_validation'
#     ✓ Onset-Conditioned Offset
#
# Evaluating 137/137 files from 'validation' split...
#   Strategy: full-length single-pass inference + advanced post-processing
#
#   Evaluated 137/137 files in 801.0s
#
#
#
#
#
#
#
# ============================================================
#         — Decoding + evaluation protocol —
# ============================================================
#
#   Decode thresholds:
#     onset_threshold:   0.40
#     frame_threshold:   0.40
#     offset_threshold:  0.50
#   Evaluation tolerances:
#     onset_tolerance:   50 ms
#     pitch_tolerance:   0.25 (25 cents)
#     offset_ratio:      0.2
#     offset_min_tol:    50 ms
#     velocity_tolerance:0.1
#     mir_eval version:  0.8.2
#
#
#
#
#
# ============================================================
#   EVALUATION SUMMARY — validation split (n=137)
# ============================================================
#
#   Dataset:    MAESTRO v3.0.0, validation split
#   Model:      OnsetsAndFrames (complexity=48, 26,491,256 params)
#   Checkpoint: epoch 990, val_loss=0.0453
#   Config:     exp2_m1_offset_validation
#   GPU:        NVIDIA RTX PRO 6000 Blackwell Server Edition
#   Eval time:  801.0s (5.8s/file)
#
#
#
#
#
#
# ============================================================
#                  — Primary metrics —
# ============================================================
#
#   Metric                                     P        R       F1
#   ------------------------------------------------------------
#   Note (onset+pitch)                    0.9560   0.8673   0.9075
#   Note w/ offset                        0.5816   0.5238   0.5500
#   Note w/ offset+vel                    0.5535   0.4989   0.5236
#   Frame                                 0.8031   0.7604   0.7793
#
#
#   ------------------------------------------------------------
#   Avg notes/file:  pred=4133  gt=4667  ratio=0.89
#
#
#
#
#
# ============================================================
#          — Supplementary error analysis —
# ============================================================
#
#   Offset MAE                           122.8 ms
#   Onset MAE                            3.7 ms
#   Chord completeness                   0.8598
#   Duplicate note rate                  0.0322
#
#   Results saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_validation_exp2_m1_offset_validation
# ============================================================
#
# Exp 2 DONE ✓

# %% [markdown]
# ### Exp 3 — Method 2 ONLY: Frame-Level Smoothing
# Applies median filter (kernel=7) to frame roll before decoding.

# %%
ALL_SUMMARIES['exp3_m2_smooth'] = run_advanced_evaluation(
    **EVAL_KWARGS,
    config_name='exp3_m2_smooth_validation',
    use_frame_smoothing=True,
    frame_smoothing_kernel=3,
    frame_smoothing_method='gaussian', # closing, median
)
print("Exp 3 DONE ✓")
# Out:
# Device: NVIDIA RTX PRO 6000 Blackwell Server Edition
# Loaded checkpoint: /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/checkpoints/best.pt
#   Trained for 990 epochs, val_loss=0.0453
#   Model parameters: 26,491,256
#
#   Post-processing config: 'exp3_m2_smooth_validation'
#     ✓ Frame Smoothing (kernel=3, method=closing)
#
# Evaluating 137/137 files from 'validation' split...
#   Strategy: full-length single-pass inference + advanced post-processing
#
#   Evaluated 137/137 files in 1364.9s
#
#
#
#
#
#
#
# ============================================================
#         — Decoding + evaluation protocol —
# ============================================================
#
#   Decode thresholds:
#     onset_threshold:   0.40
#     frame_threshold:   0.40
#     offset_threshold:  0.50
#   Evaluation tolerances:
#     onset_tolerance:   50 ms
#     pitch_tolerance:   0.25 (25 cents)
#     offset_ratio:      0.2
#     offset_min_tol:    50 ms
#     velocity_tolerance:0.1
#     mir_eval version:  0.8.2
#
#
#
#
#
# ============================================================
#   EVALUATION SUMMARY — validation split (n=137)
# ============================================================
#
#   Dataset:    MAESTRO v3.0.0, validation split
#   Model:      OnsetsAndFrames (complexity=48, 26,491,256 params)
#   Checkpoint: epoch 990, val_loss=0.0453
#   Config:     exp3_m2_smooth_validation
#   GPU:        NVIDIA RTX PRO 6000 Blackwell Server Edition
#   Eval time:  1364.9s (10.0s/file)
#
#
#
#
#
#
# ============================================================
#                  — Primary metrics —
# ============================================================
#
#   Metric                                     P        R       F1
#   ------------------------------------------------------------
#   Note (onset+pitch)                    0.9543   0.9163   0.9343
#   Note w/ offset                        0.6394   0.6132   0.6256
#   Note w/ offset+vel                    0.6093   0.5847   0.5963
#   Frame                                 0.8344   0.7221   0.7720
#
#
#   ------------------------------------------------------------
#   Avg notes/file:  pred=4435  gt=4667  ratio=0.95
#
#
#
#
#
# ============================================================
#          — Supplementary error analysis —
# ============================================================
#
#   Offset MAE                           112.6 ms
#   Onset MAE                            3.6 ms
#   Chord completeness                   0.9123
#   Duplicate note rate                  0.0348
#
#   Results saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_validation_exp3_m2_smooth_validation
# ============================================================
#
# Exp 3 DONE ✓

# %% [markdown]
# ### Exp 4 — Method 4 ONLY: Velocity-Aware Duplicate Removal
# Removes duplicate same-pitch onsets within 50ms, keeps highest velocity.

# %%
ALL_SUMMARIES['exp4_m4_dedup'] = run_advanced_evaluation(
    **EVAL_KWARGS,
    config_name='exp4_m4_dedup_validation',
    use_duplicate_removal=True,
    duplicate_tolerance_sec=0.06, #2.0.04 before, 1. 0.05 before that
)
print("Exp 4 DONE ✓")
# Out:
# Device: NVIDIA RTX PRO 6000 Blackwell Server Edition
# Loaded checkpoint: /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/checkpoints/best.pt
#   Trained for 990 epochs, val_loss=0.0453
#   Model parameters: 26,491,256
#
#   Post-processing config: 'exp4_m4_dedup_validation'
#     ✓ Duplicate Removal (tol=65ms)
#
# Evaluating 137/137 files from 'validation' split...
#   Strategy: full-length single-pass inference + advanced post-processing
#
#   Evaluated 137/137 files in 499.4s
#
#
#
#
#
#
#
# ============================================================
#         — Decoding + evaluation protocol —
# ============================================================
#
#   Decode thresholds:
#     onset_threshold:   0.40
#     frame_threshold:   0.40
#     offset_threshold:  0.50
#   Evaluation tolerances:
#     onset_tolerance:   50 ms
#     pitch_tolerance:   0.25 (25 cents)
#     offset_ratio:      0.2
#     offset_min_tol:    50 ms
#     velocity_tolerance:0.1
#     mir_eval version:  0.8.2
#
#
#
#
#
# ============================================================
#   EVALUATION SUMMARY — validation split (n=137)
# ============================================================
#
#   Dataset:    MAESTRO v3.0.0, validation split
#   Model:      OnsetsAndFrames (complexity=48, 26,491,256 params)
#   Checkpoint: epoch 990, val_loss=0.0453
#   Config:     exp4_m4_dedup_validation
#   GPU:        NVIDIA RTX PRO 6000 Blackwell Server Edition
#   Eval time:  499.4s (3.6s/file)
#
#
#
#
#
#
# ============================================================
#                  — Primary metrics —
# ============================================================
#
#   Metric                                     P        R       F1
#   ------------------------------------------------------------
#   Note (onset+pitch)                    0.9885   0.9169   0.9506
#   Note w/ offset                        0.6506   0.6033   0.6255
#   Note w/ offset+vel                    0.6202   0.5754   0.5965
#   Frame                                 0.8031   0.7604   0.7793
#
#
#   ------------------------------------------------------------
#   Avg notes/file:  pred=4281  gt=4667  ratio=0.92
#
#
#
#
#
# ============================================================
#          — Supplementary error analysis —
# ============================================================
#
#   Offset MAE                           112.7 ms
#   Onset MAE                            4.2 ms
#   Chord completeness                   0.9130
#   Duplicate note rate                  0.0000
#
#   Results saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_validation_exp4_m4_dedup_validation
# ============================================================
#
# Exp 4 DONE ✓

# %% [markdown]
# ### Exp 5 — Method 5 ONLY: Chord-Aware Onset Grouping
# Snaps near-simultaneous onsets (within 30ms) to median time.

# %%
# RESUE AS HMM MARKOV MDOEL
ALL_SUMMARIES['exp5_m5_chord'] = run_advanced_evaluation(
    **EVAL_KWARGS,
    config_name='exp5_m5_chord_validation',
    use_chord_grouping=True,
    chord_tolerance_sec=0.05,
    chord_snap_to='median',
)
print("Exp 5 DONE ✓")
# Out:
# Device: NVIDIA RTX PRO 6000 Blackwell Server Edition
# Loaded checkpoint: /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/checkpoints/best.pt
#   Trained for 990 epochs, val_loss=0.0453
#   Model parameters: 26,491,256
#
#   Post-processing config: 'exp5_m5_chord_validation'
#     ✓ Chord Grouping (tol=50ms, snap=median)
#
# Evaluating 137/137 files from 'validation' split...
#   Strategy: full-length single-pass inference + advanced post-processing
#
#   Evaluated 137/137 files in 477.9s
#
#
#
#
#
#
#
# ============================================================
#         — Decoding + evaluation protocol —
# ============================================================
#
#   Decode thresholds:
#     onset_threshold:   0.40
#     frame_threshold:   0.40
#     offset_threshold:  0.50
#   Evaluation tolerances:
#     onset_tolerance:   50 ms
#     pitch_tolerance:   0.25 (25 cents)
#     offset_ratio:      0.2
#     offset_min_tol:    50 ms
#     velocity_tolerance:0.1
#     mir_eval version:  0.8.2
#
#
#
#
#
# ============================================================
#   EVALUATION SUMMARY — validation split (n=137)
# ============================================================
#
#   Dataset:    MAESTRO v3.0.0, validation split
#   Model:      OnsetsAndFrames (complexity=48, 26,491,256 params)
#   Checkpoint: epoch 990, val_loss=0.0453
#   Config:     exp5_m5_chord_validation
#   GPU:        NVIDIA RTX PRO 6000 Blackwell Server Edition
#   Eval time:  477.9s (3.5s/file)
#
#
#
#
#
#
# ============================================================
#                  — Primary metrics —
# ============================================================
#
#   Metric                                     P        R       F1
#   ------------------------------------------------------------
#   Note (onset+pitch)                    0.9531   0.9164   0.9338
#   Note w/ offset                        0.6343   0.6093   0.6212
#   Note w/ offset+vel                    0.6042   0.5807   0.5918
#   Frame                                 0.8031   0.7604   0.7793
#
#
#   ------------------------------------------------------------
#   Avg notes/file:  pred=4442  gt=4667  ratio=0.95
#
#
#
#
#
# ============================================================
#          — Supplementary error analysis —
# ============================================================
#
#   Offset MAE                           116.3 ms
#   Onset MAE                            7.0 ms
#   Chord completeness                   0.9128
#   Duplicate note rate                  0.0344
#
#   Results saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_validation_exp5_m5_chord_validation
# ============================================================
#
# Exp 5 DONE ✓

# %% [markdown]
# ### Exp 6 — Method 6 ONLY: Adaptive Thresholding
# Per-piece threshold adaptation: threshold = 0.5 + k × std(activations).

# %%
ALL_SUMMARIES['exp6_m6_adaptive'] = run_advanced_evaluation(
    **EVAL_KWARGS,
    config_name='exp6_m6_adaptive_validation',
    use_adaptive_thresholds=True,
    adaptive_onset_k=0.3, # -0.1 and -2 before
    adaptive_frame_k=0.3, # -0.1 and -2 before
)
print("Exp 6 DONE ✓")
# Out:
# Device: NVIDIA RTX PRO 6000 Blackwell Server Edition
# Loaded checkpoint: /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/checkpoints/best.pt
#   Trained for 990 epochs, val_loss=0.0453
#   Model parameters: 26,491,256
#
#   Post-processing config: 'exp6_m6_adaptive_validation'
#     ✓ Adaptive Thresholds (onset_k=0.3, frame_k=0.3)
#
# Evaluating 137/137 files from 'validation' split...
#   Strategy: full-length single-pass inference + advanced post-processing
#
#   Evaluated 137/137 files in 509.6s
#
#
#
#
#
#
#
# ============================================================
#         — Decoding + evaluation protocol —
# ============================================================
#
#   Decode thresholds:
#     onset_threshold:   0.40
#     frame_threshold:   0.40
#     offset_threshold:  0.50
#   Evaluation tolerances:
#     onset_tolerance:   50 ms
#     pitch_tolerance:   0.25 (25 cents)
#     offset_ratio:      0.2
#     offset_min_tol:    50 ms
#     velocity_tolerance:0.1
#     mir_eval version:  0.8.2
#
#
#
#
#
# ============================================================
#   EVALUATION SUMMARY — validation split (n=137)
# ============================================================
#
#   Dataset:    MAESTRO v3.0.0, validation split
#   Model:      OnsetsAndFrames (complexity=48, 26,491,256 params)
#   Checkpoint: epoch 990, val_loss=0.0453
#   Config:     exp6_m6_adaptive_validation
#   GPU:        NVIDIA RTX PRO 6000 Blackwell Server Edition
#   Eval time:  509.6s (3.7s/file)
#
#
#
#
#
#
# ============================================================
#                  — Primary metrics —
# ============================================================
#
#   Metric                                     P        R       F1
#   ------------------------------------------------------------
#   Note (onset+pitch)                    0.9583   0.9145   0.9352
#   Note w/ offset                        0.6387   0.6087   0.6229
#   Note w/ offset+vel                    0.6087   0.5805   0.5938
#   Frame                                 0.8166   0.7445   0.7769
#
#
#   ------------------------------------------------------------
#   Avg notes/file:  pred=4405  gt=4667  ratio=0.94
#
#
#
#
#
# ============================================================
#          — Supplementary error analysis —
# ============================================================
#
#   Offset MAE                           112.4 ms
#   Onset MAE                            3.6 ms
#   Chord completeness                   0.9103
#   Duplicate note rate                  0.0312
#
#   Results saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_validation_exp6_m6_adaptive_validation
# ============================================================
#
# Exp 6 DONE ✓

# %% [markdown]
# ### Exp 7 — Method 7 ONLY: Sustain Pedal Extension
# Extends note offsets in regions with high simultaneous activity (likely pedal).

# %%
ALL_SUMMARIES['exp7_m7_pedal'] = run_advanced_evaluation(
    **EVAL_KWARGS,
    config_name='exp7_m7_pedal_validation',
    use_pedal_extension=True,
    pedal_energy_threshold=5.0,
    pedal_max_extension_sec=1.0,
)
print("Exp 7 DONE ✓")
# Out:
# Device: NVIDIA RTX PRO 6000 Blackwell Server Edition
# Loaded checkpoint: /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/checkpoints/best.pt
#   Trained for 990 epochs, val_loss=0.0453
#   Model parameters: 26,491,256
#
#   Post-processing config: 'exp7_m7_pedal_validation'
#     ✓ Pedal Extension (threshold=5.0, max=1.0s)
#
# Evaluating 137/137 files from 'validation' split...
#   Strategy: full-length single-pass inference + advanced post-processing
#
#   Evaluated 137/137 files in 504.7s
#
#
#
#
#
#
#
# ============================================================
#         — Decoding + evaluation protocol —
# ============================================================
#
#   Decode thresholds:
#     onset_threshold:   0.40
#     frame_threshold:   0.40
#     offset_threshold:  0.50
#   Evaluation tolerances:
#     onset_tolerance:   50 ms
#     pitch_tolerance:   0.25 (25 cents)
#     offset_ratio:      0.2
#     offset_min_tol:    50 ms
#     velocity_tolerance:0.1
#     mir_eval version:  0.8.2
#
#
#
#
#
# ============================================================
#   EVALUATION SUMMARY — validation split (n=137)
# ============================================================
#
#   Dataset:    MAESTRO v3.0.0, validation split
#   Model:      OnsetsAndFrames (complexity=48, 26,491,256 params)
#   Checkpoint: epoch 990, val_loss=0.0453
#   Config:     exp7_m7_pedal_validation
#   GPU:        NVIDIA RTX PRO 6000 Blackwell Server Edition
#   Eval time:  504.7s (3.7s/file)
#
#
#
#
#
#
# ============================================================
#                  — Primary metrics —
# ============================================================
#
#   Metric                                     P        R       F1
#   ------------------------------------------------------------
#   Note (onset+pitch)                    0.9456   0.9175   0.9308
#   Note w/ offset                        0.6268   0.6076   0.6167
#   Note w/ offset+vel                    0.5972   0.5792   0.5877
#   Frame                                 0.8031   0.7604   0.7793
#
#
#   ------------------------------------------------------------
#   Avg notes/file:  pred=4489  gt=4667  ratio=0.96
#
#
#
#
#
# ============================================================
#          — Supplementary error analysis —
# ============================================================
#
#   Offset MAE                           112.7 ms
#   Onset MAE                            3.4 ms
#   Chord completeness                   0.9135
#   Duplicate note rate                  0.0433
#
#   Results saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_validation_exp7_m7_pedal_validation
# ============================================================
#
# Exp 7 DONE ✓

# %% [markdown]
# ---
# # Tuning Combination Experiments
#
# Based on Phase 1 results, combine methods that individually showed improvement.

# %%
EVAL_KWARGS = dict(
    checkpoint_path      = BEST_CKPT,
    maestro_root         = MAESTRO_ROOT,
    cache_dir            = CACHE_DIR,
    split                = 'validation',   # on valdiation set for tuning
    max_files            = None,
    model_complexity     = 48,
    save_midi            = False,
    save_plots           = False,

    # Global decode thresholds (TUNED)
    onset_threshold      = 0.4,
    frame_threshold      = 0.4,
    offset_threshold     = 0.5,   # NOT USING IT AS METHOD 1 HASNT BEEN HELPFULL WUTH OFFSET EVAL

    # mir_eval tolerances
    onset_tolerance      = 0.05,
    offset_ratio         = 0.2,
    offset_min_tolerance = 0.05,
    velocity_tolerance   = 0.1,
)

# %% [markdown]
# ### Exp 8 — Method 2 & Method 3: Frame-Level Smoothing & Minimum Note Duration

# %%
# M2+M3 (without M4 and M6)
ALL_SUMMARIES['M2+M3_comb'] = run_advanced_evaluation(
    **EVAL_KWARGS,
    config_name='M2+M3_comb_validation',
    use_frame_smoothing     = True,
    frame_smoothing_kernel  = 3,
    frame_smoothing_method  = 'closing',
    min_note_duration_ms    = 55.0,
)
# Out:
# Device: NVIDIA RTX PRO 6000 Blackwell Server Edition
# Loaded checkpoint: /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/checkpoints/best.pt
#   Trained for 990 epochs, val_loss=0.0453
#   Model parameters: 26,491,256
#
#   Post-processing config: 'full_comb_validation'
#     ✓ Frame Smoothing (kernel=3, method=closing)
#     ✓ Min Note Duration = 55.0ms
#
# Evaluating 137/137 files from 'validation' split...
#   Strategy: full-length single-pass inference + advanced post-processing
#
#   Evaluated 137/137 files in 1348.3s
#
#
#
#
#
#
#
# ============================================================
#         — Decoding + evaluation protocol —
# ============================================================
#
#   Decode thresholds:
#     onset_threshold:   0.40
#     frame_threshold:   0.40
#     offset_threshold:  0.50
#   Evaluation tolerances:
#     onset_tolerance:   50 ms
#     pitch_tolerance:   0.25 (25 cents)
#     offset_ratio:      0.2
#     offset_min_tol:    50 ms
#     velocity_tolerance:0.1
#     mir_eval version:  0.8.2
#
#
#
#
#
# ============================================================
#   EVALUATION SUMMARY — validation split (n=137)
# ============================================================
#
#   Dataset:    MAESTRO v3.0.0, validation split
#   Model:      OnsetsAndFrames (complexity=48, 26,491,256 params)
#   Checkpoint: epoch 990, val_loss=0.0453
#   Config:     full_comb_validation
#   GPU:        NVIDIA RTX PRO 6000 Blackwell Server Edition
#   Eval time:  1348.3s (9.8s/file)
#
#
#
#
#
#
# ============================================================
#                  — Primary metrics —
# ============================================================
#
#   Metric                                     P        R       F1
#   ------------------------------------------------------------
#   Note (onset+pitch)                    0.9902   0.9125   0.9489
#   Note w/ offset                        0.6637   0.6112   0.6357
#   Note w/ offset+vel                    0.6325   0.5828   0.6061
#   Frame                                 0.8344   0.7221   0.7720
#
#
#   ------------------------------------------------------------
#   Avg notes/file:  pred=4249  gt=4667  ratio=0.91
#
#
#
#
#
# ============================================================
#          — Supplementary error analysis —
# ============================================================
#
#   Offset MAE                           109.6 ms
#   Onset MAE                            4.1 ms
#   Chord completeness                   0.9086
#   Duplicate note rate                  0.0000
#
#   Results saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_validation_full_comb_validation
# ============================================================
#
# Hero no-M6 DONE ✓

# %% [markdown]
# ### Exp 9 — Method 2 & Method 4: Frame-Level Smoothing & Velocity-Aware Duplicate Removal

# %%
# M2+M4 (without M3 and M6)
ALL_SUMMARIES['M2+M4_comb_'] = run_advanced_evaluation(
    **EVAL_KWARGS,
    config_name='M2+M4_comb_validation',
    use_frame_smoothing     = True,
    frame_smoothing_kernel  = 3,
    frame_smoothing_method  = 'closing',
    use_duplicate_removal   = True,
    duplicate_tolerance_sec = 0.06,
)
# Out:
# Device: NVIDIA RTX PRO 6000 Blackwell Server Edition
# Loaded checkpoint: /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/checkpoints/best.pt
#   Trained for 990 epochs, val_loss=0.0453
#   Model parameters: 26,491,256
#
#   Post-processing config: 'full_comb_validation'
#     ✓ Frame Smoothing (kernel=3, method=closing)
#     ✓ Duplicate Removal (tol=60ms)
#
# Evaluating 137/137 files from 'validation' split...
#   Strategy: full-length single-pass inference + advanced post-processing
#
#   Evaluated 137/137 files in 1354.9s
#
#
#
#
#
#
#
# ============================================================
#         — Decoding + evaluation protocol —
# ============================================================
#
#   Decode thresholds:
#     onset_threshold:   0.40
#     frame_threshold:   0.40
#     offset_threshold:  0.50
#   Evaluation tolerances:
#     onset_tolerance:   50 ms
#     pitch_tolerance:   0.25 (25 cents)
#     offset_ratio:      0.2
#     offset_min_tol:    50 ms
#     velocity_tolerance:0.1
#     mir_eval version:  0.8.2
#
#
#
#
#
# ============================================================
#   EVALUATION SUMMARY — validation split (n=137)
# ============================================================
#
#   Dataset:    MAESTRO v3.0.0, validation split
#   Model:      OnsetsAndFrames (complexity=48, 26,491,256 params)
#   Checkpoint: epoch 990, val_loss=0.0453
#   Config:     full_comb_validation
#   GPU:        NVIDIA RTX PRO 6000 Blackwell Server Edition
#   Eval time:  1354.9s (9.9s/file)
#
#
#
#
#
#
# ============================================================
#                  — Primary metrics —
# ============================================================
#
#   Metric                                     P        R       F1
#   ------------------------------------------------------------
#   Note (onset+pitch)                    0.9886   0.9163   0.9503
#   Note w/ offset                        0.6580   0.6095   0.6322
#   Note w/ offset+vel                    0.6272   0.5813   0.6029
#   Frame                                 0.8344   0.7221   0.7720
#
#
#   ------------------------------------------------------------
#   Avg notes/file:  pred=4277  gt=4667  ratio=0.92
#
#
#
#
#
# ============================================================
#          — Supplementary error analysis —
# ============================================================
#
#   Offset MAE                           112.4 ms
#   Onset MAE                            4.2 ms
#   Chord completeness                   0.9124
#   Duplicate note rate                  0.0000
#
#   Results saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_validation_full_comb_validation
# ============================================================
#
# Hero no-M6 DONE ✓

# %% [markdown]
# ### Exp 10 — Method 3 & Method 4: Minimum Note Duration & Velocity-Aware Duplicate Removal

# %%
# M3+M4 only (the "minimal hero")
ALL_SUMMARIES['M3+M4_comb'] = run_advanced_evaluation(
    **EVAL_KWARGS,
    config_name='M3+M4_comb_validation',
    min_note_duration_ms    = 55.0,
    use_duplicate_removal   = True,
    duplicate_tolerance_sec = 0.06,
)
# Out:
# Device: NVIDIA RTX PRO 6000 Blackwell Server Edition
# Loaded checkpoint: /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/checkpoints/best.pt
#   Trained for 990 epochs, val_loss=0.0453
#   Model parameters: 26,491,256
#
#   Post-processing config: 'minimal_comb_validation'
#     ✓ Min Note Duration = 55.0ms
#     ✓ Duplicate Removal (tol=60ms)
#
# Evaluating 137/137 files from 'validation' split...
#   Strategy: full-length single-pass inference + advanced post-processing
#
#   Evaluated 137/137 files in 481.2s
#
#
#
#
#
#
#
# ============================================================
#         — Decoding + evaluation protocol —
# ============================================================
#
#   Decode thresholds:
#     onset_threshold:   0.40
#     frame_threshold:   0.40
#     offset_threshold:  0.50
#   Evaluation tolerances:
#     onset_tolerance:   50 ms
#     pitch_tolerance:   0.25 (25 cents)
#     offset_ratio:      0.2
#     offset_min_tol:    50 ms
#     velocity_tolerance:0.1
#     mir_eval version:  0.8.2
#
#
#
#
#
# ============================================================
#   EVALUATION SUMMARY — validation split (n=137)
# ============================================================
#
#   Dataset:    MAESTRO v3.0.0, validation split
#   Model:      OnsetsAndFrames (complexity=48, 26,491,256 params)
#   Checkpoint: epoch 990, val_loss=0.0453
#   Config:     minimal_comb_validation
#   GPU:        NVIDIA RTX PRO 6000 Blackwell Server Edition
#   Eval time:  481.2s (3.5s/file)
#
#
#
#
#
#
# ============================================================
#                  — Primary metrics —
# ============================================================
#
#   Metric                                     P        R       F1
#   ------------------------------------------------------------
#   Note (onset+pitch)                    0.9895   0.9148   0.9499
#   Note w/ offset                        0.6557   0.6059   0.6292
#   Note w/ offset+vel                    0.6247   0.5777   0.5997
#   Frame                                 0.8031   0.7604   0.7793
#
#
#   ------------------------------------------------------------
#   Avg notes/file:  pred=4264  gt=4667  ratio=0.91
#
#
#
#
#
# ============================================================
#          — Supplementary error analysis —
# ============================================================
#
#   Offset MAE                           110.0 ms
#   Onset MAE                            4.1 ms
#   Chord completeness                   0.9109
#   Duplicate note rate                  0.0000
#
#   Results saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_validation_minimal_comb_validation
# ============================================================
#
# Hero minimal DONE ✓

# %% [markdown]
# ### Exp 11 — Method 2 & Method 3 & Method 4: Frame-Level Smoothing & Minimum Note Duration & Velocity-Aware Duplicate Removal

# %%
# M2+M3+M4 (without M6)
ALL_SUMMARIES[' M2+M3+M4_comb'] = run_advanced_evaluation(
    **EVAL_KWARGS,
    config_name=' M2+M3+M4_comb_validation',
    use_frame_smoothing     = True,
    frame_smoothing_kernel  = 3,
    frame_smoothing_method  = 'closing',
    min_note_duration_ms    = 55.0,
    use_duplicate_removal   = True,
    duplicate_tolerance_sec = 0.06,
)
# Out:
# Device: NVIDIA RTX PRO 6000 Blackwell Server Edition
# Loaded checkpoint: /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/checkpoints/best.pt
#   Trained for 990 epochs, val_loss=0.0453
#   Model parameters: 26,491,256
#
#   Post-processing config: 'full_comb_validation'
#     ✓ Frame Smoothing (kernel=3, method=closing)
#     ✓ Min Note Duration = 55.0ms
#     ✓ Duplicate Removal (tol=60ms)
#
# Evaluating 137/137 files from 'validation' split...
#   Strategy: full-length single-pass inference + advanced post-processing
#
#   Evaluated 137/137 files in 1353.7s
#
#
#
#
#
#
#
# ============================================================
#         — Decoding + evaluation protocol —
# ============================================================
#
#   Decode thresholds:
#     onset_threshold:   0.40
#     frame_threshold:   0.40
#     offset_threshold:  0.50
#   Evaluation tolerances:
#     onset_tolerance:   50 ms
#     pitch_tolerance:   0.25 (25 cents)
#     offset_ratio:      0.2
#     offset_min_tol:    50 ms
#     velocity_tolerance:0.1
#     mir_eval version:  0.8.2
#
#
#
#
#
# ============================================================
#   EVALUATION SUMMARY — validation split (n=137)
# ============================================================
#
#   Dataset:    MAESTRO v3.0.0, validation split
#   Model:      OnsetsAndFrames (complexity=48, 26,491,256 params)
#   Checkpoint: epoch 990, val_loss=0.0453
#   Config:     full_comb_validation
#   GPU:        NVIDIA RTX PRO 6000 Blackwell Server Edition
#   Eval time:  1353.7s (9.9s/file)
#
#
#
#
#
#
# ============================================================
#                  — Primary metrics —
# ============================================================
#
#   Metric                                     P        R       F1
#   ------------------------------------------------------------
#   Note (onset+pitch)                    0.9902   0.9125   0.9489
#   Note w/ offset                        0.6637   0.6112   0.6357
#   Note w/ offset+vel                    0.6325   0.5828   0.6061
#   Frame                                 0.8344   0.7221   0.7720
#
#
#   ------------------------------------------------------------
#   Avg notes/file:  pred=4249  gt=4667  ratio=0.91
#
#
#
#
#
# ============================================================
#          — Supplementary error analysis —
# ============================================================
#
#   Offset MAE                           109.6 ms
#   Onset MAE                            4.1 ms
#   Chord completeness                   0.9086
#   Duplicate note rate                  0.0000
#
#   Results saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_validation_full_comb_validation
# ============================================================
#
# Hero no-M6 DONE ✓

# %% [markdown]
# ### Exp 12 — Method 2 & Method 3 & Method 4 & method 6: Frame-Level Smoothing & Minimum Note Duration & Velocity-Aware Duplicate Removal & Adaptive Thresholds

# %%
# ── configuration: M2 + M3 + M4 + M6 ON ; M1, M5, M7 OFF ──
ALL_SUMMARIES['all_methods_final'] = run_advanced_evaluation(
    **EVAL_KWARGS,
    config_name='all_methods_final_validation',

    # M1 OFF — confirmed bad at 0.2, 0.5, 0.9 across three attempts
    # (do not pass use_onset_conditioned_offset)


    # M2 ON — closing k=3, small positive at 0.4/0.4
    use_frame_smoothing      = True,
    frame_smoothing_kernel   = 3,
    frame_smoothing_method   = 'closing',

    # M3 ON — 55 ms optimal at 0.4/0.4
    min_note_duration_ms     = 55.0,

    # M4 ON — 60 ms optimal.
    use_duplicate_removal    = True,
    duplicate_tolerance_sec  = 0.06,

    # M5 OFF — reserved for separate chord reconstruction (qualitative only)

    # M6 ON — k = +0.3, small positive at 0.4/0.4
    use_adaptive_thresholds  = True,
    adaptive_onset_k         = 0.2,
    adaptive_frame_k         = 0.2,


    # M7 OFF — turned negative at 0.4/0.4 (lower frame_threshold implicitly
)
# Out:
# Device: NVIDIA RTX PRO 6000 Blackwell Server Edition
# Loaded checkpoint: /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/checkpoints/best.pt
#   Trained for 990 epochs, val_loss=0.0453
#   Model parameters: 26,491,256
#
#   Post-processing config: 'all_methods_final_validation'
#     ✓ Frame Smoothing (kernel=3, method=closing)
#     ✓ Min Note Duration = 55.0ms
#     ✓ Duplicate Removal (tol=60ms)
#     ✓ Adaptive Thresholds (onset_k=0.2, frame_k=0.2)
#
# Evaluating 137/137 files from 'validation' split...
#   Strategy: full-length single-pass inference + advanced post-processing
#
#   Evaluated 137/137 files in 1350.6s
#
#
#
#
#
#
#
# ============================================================
#         — Decoding + evaluation protocol —
# ============================================================
#
#   Decode thresholds:
#     onset_threshold:   0.40
#     frame_threshold:   0.40
#     offset_threshold:  0.50
#   Evaluation tolerances:
#     onset_tolerance:   50 ms
#     pitch_tolerance:   0.25 (25 cents)
#     offset_ratio:      0.2
#     offset_min_tol:    50 ms
#     velocity_tolerance:0.1
#     mir_eval version:  0.8.2
#
#
#
#
#
# ============================================================
#   EVALUATION SUMMARY — validation split (n=137)
# ============================================================
#
#   Dataset:    MAESTRO v3.0.0, validation split
#   Model:      OnsetsAndFrames (complexity=48, 26,491,256 params)
#   Checkpoint: epoch 990, val_loss=0.0453
#   Config:     all_methods_final_validation
#   GPU:        NVIDIA RTX PRO 6000 Blackwell Server Edition
#   Eval time:  1350.6s (9.9s/file)
#
#
#
#
#
#
# ============================================================
#                  — Primary metrics —
# ============================================================
#
#   Metric                                     P        R       F1
#   ------------------------------------------------------------
#   Note (onset+pitch)                    0.9905   0.9110   0.9482
#   Note w/ offset                        0.6640   0.6102   0.6353
#   Note w/ offset+vel                    0.6329   0.5820   0.6058
#   Frame                                 0.8347   0.7217   0.7719
#
#
#   ------------------------------------------------------------
#   Avg notes/file:  pred=4239  gt=4667  ratio=0.91
#
#
#
#
#
# ============================================================
#          — Supplementary error analysis —
# ============================================================
#
#   Offset MAE                           109.6 ms
#   Onset MAE                            4.1 ms
#   Chord completeness                   0.9070
#   Duplicate note rate                  0.0000
#
#   Results saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_validation_all_methods_final_validation
# ============================================================
#
# Hero final DONE ✓

# %% [markdown]
# ##  choosen final post proccesing method tuning

# %%
EVAL_KWARGS_val_final = dict(
    checkpoint_path      = BEST_CKPT,
    maestro_root         = MAESTRO_ROOT,
    cache_dir            = CACHE_DIR,
    split                = 'validation',   # on valdiation set for tuning
    max_files            = None,
    model_complexity     = 48,
    save_midi            = False,
    save_plots           = False,

    # Global decode thresholds (TUNED)
    onset_threshold      = 0.4,
    frame_threshold      = 0.4,
    offset_threshold     = 0.5,   # NOT USING IT AS METHOD 1 HASNT BEEN HELPFULL WUTH OFFSET EVAL

    # mir_eval tolerances
    onset_tolerance      = 0.05,
    offset_ratio         = 0.2,
    offset_min_tolerance = 0.05,
    velocity_tolerance   = 0.1,
)

# %%
# M2+M3+M4 (without M6)
ALL_SUMMARIES['M2+M3+M4_final_comb'] = run_advanced_evaluation(
    **EVAL_KWARGS_val_final,
    config_name='full_comb_validation',
    use_frame_smoothing     = True,
    frame_smoothing_kernel  = 3,
    frame_smoothing_method  = 'closing',
    min_note_duration_ms    = 55.0,
    use_duplicate_removal   = True,
    duplicate_tolerance_sec = 0.06,
)
# Out:
# Device: NVIDIA RTX PRO 6000 Blackwell Server Edition
# Loaded checkpoint: /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/checkpoints/best.pt
#   Trained for 990 epochs, val_loss=0.0453
#   Model parameters: 26,491,256
#
#   Post-processing config: 'full_comb_validation'
#     ✓ Frame Smoothing (kernel=2, method=closing)
#     ✓ Min Note Duration = 55.0ms
#     ✓ Duplicate Removal (tol=60ms)
#
# Evaluating 137/137 files from 'validation' split...
#   Strategy: full-length single-pass inference + advanced post-processing
#
#   Evaluated 137/137 files in 1343.1s
#
#
#
#
#
#
#
# ============================================================
#         — Decoding + evaluation protocol —
# ============================================================
#
#   Decode thresholds:
#     onset_threshold:   0.40
#     frame_threshold:   0.40
#     offset_threshold:  0.50
#   Evaluation tolerances:
#     onset_tolerance:   50 ms
#     pitch_tolerance:   0.25 (25 cents)
#     offset_ratio:      0.2
#     offset_min_tol:    50 ms
#     velocity_tolerance:0.1
#     mir_eval version:  0.8.2
#
#
#
#
#
# ============================================================
#   EVALUATION SUMMARY — validation split (n=137)
# ============================================================
#
#   Dataset:    MAESTRO v3.0.0, validation split
#   Model:      OnsetsAndFrames (complexity=48, 26,491,256 params)
#   Checkpoint: epoch 990, val_loss=0.0453
#   Config:     full_comb_validation
#   GPU:        NVIDIA RTX PRO 6000 Blackwell Server Edition
#   Eval time:  1343.1s (9.8s/file)
#
#
#
#
#
#
# ============================================================
#                  — Primary metrics —
# ============================================================
#
#   Metric                                     P        R       F1
#   ------------------------------------------------------------
#   Note (onset+pitch)                    0.9902   0.9125   0.9489
#   Note w/ offset                        0.6637   0.6112   0.6357
#   Note w/ offset+vel                    0.6325   0.5828   0.6061
#   Frame                                 0.8344   0.7221   0.7720
#
#
#   ------------------------------------------------------------
#   Avg notes/file:  pred=4249  gt=4667  ratio=0.91
#
#
#
#
#
# ============================================================
#          — Supplementary error analysis —
# ============================================================
#
#   Offset MAE                           109.6 ms
#   Onset MAE                            4.1 ms
#   Chord completeness                   0.9086
#   Duplicate note rate                  0.0000
#
#   Results saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_validation_full_comb_validation
# ============================================================

# %%
# M3+M4
ALL_SUMMARIES['M3+M4_final_comb_m6'] = run_advanced_evaluation(
    **EVAL_KWARGS_val_final,
    config_name='M3+M4_final_comb_validation',
    min_note_duration_ms    = 55.0,
    use_duplicate_removal   = True,
    duplicate_tolerance_sec = 0.06,
)
# Out:
# Device: NVIDIA RTX PRO 6000 Blackwell Server Edition
# Loaded checkpoint: /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/checkpoints/best.pt
#   Trained for 990 epochs, val_loss=0.0453
#   Model parameters: 26,491,256
#
#   Post-processing config: 'M3+M4_final_comb_validation'
#     ✓ Min Note Duration = 55.0ms
#     ✓ Duplicate Removal (tol=60ms)
#
# Evaluating 137/137 files from 'validation' split...
#   Strategy: full-length single-pass inference + advanced post-processing
#
#   Evaluated 137/137 files in 493.4s
#
#
#
#
#
#
#
# ============================================================
#         — Decoding + evaluation protocol —
# ============================================================
#
#   Decode thresholds:
#     onset_threshold:   0.40
#     frame_threshold:   0.40
#     offset_threshold:  0.50
#   Evaluation tolerances:
#     onset_tolerance:   50 ms
#     pitch_tolerance:   0.25 (25 cents)
#     offset_ratio:      0.2
#     offset_min_tol:    50 ms
#     velocity_tolerance:0.1
#     mir_eval version:  0.8.2
#
#
#
#
#
# ============================================================
#   EVALUATION SUMMARY — validation split (n=137)
# ============================================================
#
#   Dataset:    MAESTRO v3.0.0, validation split
#   Model:      OnsetsAndFrames (complexity=48, 26,491,256 params)
#   Checkpoint: epoch 990, val_loss=0.0453
#   Config:     M3+M4_final_comb_validation
#   GPU:        NVIDIA RTX PRO 6000 Blackwell Server Edition
#   Eval time:  493.4s (3.6s/file)
#
#
#
#
#
#
# ============================================================
#                  — Primary metrics —
# ============================================================
#
#   Metric                                     P        R       F1
#   ------------------------------------------------------------
#   Note (onset+pitch)                    0.9895   0.9148   0.9499
#   Note w/ offset                        0.6557   0.6059   0.6292
#   Note w/ offset+vel                    0.6247   0.5777   0.5997
#   Frame                                 0.8031   0.7604   0.7793
#
#
#   ------------------------------------------------------------
#   Avg notes/file:  pred=4264  gt=4667  ratio=0.91
#
#
#
#
#
# ============================================================
#          — Supplementary error analysis —
# ============================================================
#
#   Offset MAE                           110.0 ms
#   Onset MAE                            4.1 ms
#   Chord completeness                   0.9109
#   Duplicate note rate                  0.0000
#
#   Results saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_validation_M3+M4_final_comb_validation
# ============================================================

# %% [markdown]
# ---
# # Individual Method Isolation Tests on test set after tuning on validation set
#
# Each experiment enables exactly ONE method to measure its isolated effect.

# %%
import os, glob

# ── Paths ────────────────────────────────────────────────────────────────────
DRIVE_ROOT   = '/content/drive/MyDrive/piano_amt'
MAESTRO_ROOT = f'{DRIVE_ROOT}/maestro-v3.0.0'
CACHE_DIR    = f'{DRIVE_ROOT}/cache'
RUNS_DIR     = f'{DRIVE_ROOT}/runs'
BEST_CKPT    = f'{RUNS_DIR}/OF_full_run_v2/checkpoints/best.pt'

# ── Evaluation settings ──────────────────────────────────────────────────────
SPLIT            = 'test'     # 'test' for final, 'validation' for tuning
MODEL_COMPLEXITY = 48
MAX_FILES        = None       # None = all files in split

# ── Common kwargs (locked for all experiments) ───────────────────────────────
EVAL_KWARGS_test = dict(
    checkpoint_path      = BEST_CKPT,
    maestro_root         = MAESTRO_ROOT,
    cache_dir            = CACHE_DIR,
    split                = SPLIT,
    max_files            = MAX_FILES,
    model_complexity     = MODEL_COMPLEXITY,
    save_midi            = True,
    save_plots           = True,
    onset_threshold      = 0.4,
    frame_threshold      = 0.4,
    offset_threshold     = 0.5,
    onset_tolerance      = 0.05,
    offset_ratio         = 0.2,
    offset_min_tolerance = 0.05,
    velocity_tolerance   = 0.1,
)

# ── Storage for all results ──────────────────────────────────────────────────
ALL_SUMMARIES = {}  # config_name → summary dict

# ── Verify ───────────────────────────────────────────────────────────────────
assert os.path.exists(BEST_CKPT), f"Checkpoint not found: {BEST_CKPT}"
npzs = glob.glob(f'{CACHE_DIR}/*.npz')
print(f"Checkpoint : {BEST_CKPT}")
print(f"Cache files: {len(npzs)}")
print(f"Split      : {SPLIT}")
print(f"Max files  : {MAX_FILES or 'ALL'}")
print("\nReady ✓")
# Out:
# Checkpoint : /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/checkpoints/best.pt
# Cache files: 1276
# Split      : test
# Max files  : ALL
#
# Ready ✓

# %% [markdown]
# ### Baseline (No Post-Processing)
# All methods OFF. Should match your original `eval_test` results exactly.

# %%
ALL_SUMMARIES['adv_baseline'] = run_advanced_evaluation(
    **EVAL_KWARGS_test,
    config_name='adv_baseline',
)
# Out:
# Device: NVIDIA RTX PRO 6000 Blackwell Server Edition
# Loaded checkpoint: /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/checkpoints/best.pt
#   Trained for 990 epochs, val_loss=0.0453
#   Model parameters: 26,491,256
#
#   Post-processing config: 'adv_baseline'
#     (no post-processing — baseline decode)
#
# Evaluating 177/177 files from 'test' split...
#   Strategy: full-length single-pass inference + advanced post-processing
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_baseline/midi_samples/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_07_WAV.mid  (714 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_baseline/midi_samples/MIDI-Unprocessed_02_R1_2009_03-06_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_04_WAV.mid  (789 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_baseline/midi_samples/MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_04_Track04_wav.mid  (3503 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_baseline/midi_samples/MIDI-Unprocessed_24_R1_2006_01-05_ORIG_MID--AUDIO_24_R1_2006_03_Track03_wav.mid  (3622 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_baseline/midi_samples/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_08_WAV.mid  (3794 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_baseline/midi_samples/MIDI-Unprocessed_Recital13-15_MID--AUDIO_15_R1_2018_wav--1.mid  (3475 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_baseline/midi_samples/MIDI-UNPROCESSED_09-10_R1_2014_MID--AUDIO_09_R1_2014_wav--4.mid  (7288 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_baseline/midi_samples/MIDI-Unprocessed_11_R1_2009_01-05_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_04_WAV.mid  (2626 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_baseline/midi_samples/MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_12_Track12_wav--1.mid  (1932 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_baseline/midi_samples/MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_05_Track05_wav.mid  (2748 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_baseline/midi_samples/MIDI-Unprocessed_05_R1_2008_01-04_ORIG_MID--AUDIO_05_R1_2008_wav--3.mid  (2748 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_baseline/midi_samples/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_12_R2_2015_wav--3.mid  (8182 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_baseline/midi_samples/MIDI-Unprocessed_Recital16_MID--AUDIO_16_R1_2018_wav--3.mid  (380 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_baseline/midi_samples/MIDI-Unprocessed_03_R1_2006_01-05_ORIG_MID--AUDIO_03_R1_2006_04_Track04_wav.mid  (7885 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_baseline/midi_samples/MIDI-Unprocessed_09_R3_2008_01-07_ORIG_MID--AUDIO_09_R3_2008_wav--2.mid  (865 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_baseline/midi_samples/MIDI-Unprocessed_09_R3_2008_01-07_ORIG_MID--AUDIO_09_R3_2008_wav--1.mid  (1156 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_baseline/midi_samples/MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_01_R1_2014_wav--2.mid  (519 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_baseline/midi_samples/MIDI-UNPROCESSED_19-21_R3_2014_MID--AUDIO_21_R3_2014_wav--1.mid  (1723 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_baseline/midi_samples/MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_01_R1_2014_wav--1.mid  (1442 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_baseline/midi_samples/MIDI-Unprocessed_10_R2_2008_01-05_ORIG_MID--AUDIO_10_R2_2008_wav--2.mid  (1783 notes)
#
#   Evaluated 177/177 files in 571.9s
#
#
#
#
#
#
#
# ============================================================
#         — Decoding + evaluation protocol —
# ============================================================
#
#   Decode thresholds:
#     onset_threshold:   0.40
#     frame_threshold:   0.40
#     offset_threshold:  0.50
#   Evaluation tolerances:
#     onset_tolerance:   50 ms
#     pitch_tolerance:   0.25 (25 cents)
#     offset_ratio:      0.2
#     offset_min_tol:    50 ms
#     velocity_tolerance:0.1
#     mir_eval version:  0.8.2
#
#
#
#
#
# ============================================================
#   EVALUATION SUMMARY — test split (n=177)
# ============================================================
#
#   Dataset:    MAESTRO v3.0.0, test split
#   Model:      OnsetsAndFrames (complexity=48, 26,491,256 params)
#   Checkpoint: epoch 990, val_loss=0.0453
#   Config:     adv_baseline
#   GPU:        NVIDIA RTX PRO 6000 Blackwell Server Edition
#   Eval time:  571.9s (3.2s/file)
#
#
#
#
#
#
# ============================================================
#                  — Primary metrics —
# ============================================================
#
#   Metric                                     P        R       F1
#   ------------------------------------------------------------
#   Note (onset+pitch)                    0.9548   0.9181   0.9356
#   Note w/ offset                        0.6804   0.6553   0.6673
#   Note w/ offset+vel                    0.6491   0.6256   0.6368
#   Frame                                 0.8198   0.7808   0.7981
#
#
#   ------------------------------------------------------------
#   Avg notes/file:  pred=3980  gt=4189  ratio=0.95
#
#
#
#
#
# ============================================================
#          — Supplementary error analysis —
# ============================================================
#
#   Offset MAE                           93.1 ms
#   Onset MAE                            3.4 ms
#   Chord completeness                   0.9136
#   Duplicate note rate                  0.0351
#
#   Results saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_baseline
# ============================================================

# %% [markdown]
# ### Method 2 ONLY: Frame-Level Smoothing
# Applies median filter (kernel=7) to frame roll before decoding.

# %%
ALL_SUMMARIES['adv_m2_smooth'] = run_advanced_evaluation(
    **EVAL_KWARGS_test,
    config_name='adv_m2_smooth',
    use_frame_smoothing=True,
    frame_smoothing_kernel=3,
    frame_smoothing_method='closing',
)
# Out:
# Device: NVIDIA RTX PRO 6000 Blackwell Server Edition
# Loaded checkpoint: /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/checkpoints/best.pt
#   Trained for 990 epochs, val_loss=0.0453
#   Model parameters: 26,491,256
#
#   Post-processing config: 'adv_m2_smooth'
#     ✓ Frame Smoothing (kernel=3, method=closing)
#
# Evaluating 177/177 files from 'test' split...
#   Strategy: full-length single-pass inference + advanced post-processing
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_smooth/midi_samples/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_07_WAV.mid  (714 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_smooth/midi_samples/MIDI-Unprocessed_02_R1_2009_03-06_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_04_WAV.mid  (789 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_smooth/midi_samples/MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_04_Track04_wav.mid  (3503 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_smooth/midi_samples/MIDI-Unprocessed_24_R1_2006_01-05_ORIG_MID--AUDIO_24_R1_2006_03_Track03_wav.mid  (3622 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_smooth/midi_samples/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_08_WAV.mid  (3794 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_smooth/midi_samples/MIDI-Unprocessed_Recital13-15_MID--AUDIO_15_R1_2018_wav--1.mid  (3475 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_smooth/midi_samples/MIDI-UNPROCESSED_09-10_R1_2014_MID--AUDIO_09_R1_2014_wav--4.mid  (7288 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_smooth/midi_samples/MIDI-Unprocessed_11_R1_2009_01-05_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_04_WAV.mid  (2626 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_smooth/midi_samples/MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_12_Track12_wav--1.mid  (1932 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_smooth/midi_samples/MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_05_Track05_wav.mid  (2748 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_smooth/midi_samples/MIDI-Unprocessed_05_R1_2008_01-04_ORIG_MID--AUDIO_05_R1_2008_wav--3.mid  (2748 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_smooth/midi_samples/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_12_R2_2015_wav--3.mid  (8182 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_smooth/midi_samples/MIDI-Unprocessed_Recital16_MID--AUDIO_16_R1_2018_wav--3.mid  (380 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_smooth/midi_samples/MIDI-Unprocessed_03_R1_2006_01-05_ORIG_MID--AUDIO_03_R1_2006_04_Track04_wav.mid  (7885 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_smooth/midi_samples/MIDI-Unprocessed_09_R3_2008_01-07_ORIG_MID--AUDIO_09_R3_2008_wav--2.mid  (865 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_smooth/midi_samples/MIDI-Unprocessed_09_R3_2008_01-07_ORIG_MID--AUDIO_09_R3_2008_wav--1.mid  (1156 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_smooth/midi_samples/MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_01_R1_2014_wav--2.mid  (519 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_smooth/midi_samples/MIDI-UNPROCESSED_19-21_R3_2014_MID--AUDIO_21_R3_2014_wav--1.mid  (1723 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_smooth/midi_samples/MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_01_R1_2014_wav--1.mid  (1442 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_smooth/midi_samples/MIDI-Unprocessed_10_R2_2008_01-05_ORIG_MID--AUDIO_10_R2_2008_wav--2.mid  (1783 notes)
#
#   Evaluated 177/177 files in 1379.6s
#
#
#
#
#
#
#
# ============================================================
#         — Decoding + evaluation protocol —
# ============================================================
#
#   Decode thresholds:
#     onset_threshold:   0.40
#     frame_threshold:   0.40
#     offset_threshold:  0.50
#   Evaluation tolerances:
#     onset_tolerance:   50 ms
#     pitch_tolerance:   0.25 (25 cents)
#     offset_ratio:      0.2
#     offset_min_tol:    50 ms
#     velocity_tolerance:0.1
#     mir_eval version:  0.8.2
#
#
#
#
#
# ============================================================
#   EVALUATION SUMMARY — test split (n=177)
# ============================================================
#
#   Dataset:    MAESTRO v3.0.0, test split
#   Model:      OnsetsAndFrames (complexity=48, 26,491,256 params)
#   Checkpoint: epoch 990, val_loss=0.0453
#   Config:     adv_m2_smooth
#   GPU:        NVIDIA RTX PRO 6000 Blackwell Server Edition
#   Eval time:  1379.6s (7.8s/file)
#
#
#
#
#
#
# ============================================================
#                  — Primary metrics —
# ============================================================
#
#   Metric                                     P        R       F1
#   ------------------------------------------------------------
#   Note (onset+pitch)                    0.9551   0.9172   0.9353
#   Note w/ offset                        0.6860   0.6599   0.6723
#   Note w/ offset+vel                    0.6544   0.6300   0.6416
#   Frame                                 0.8483   0.7469   0.7922
#
#
#   ------------------------------------------------------------
#   Avg notes/file:  pred=3973  gt=4189  ratio=0.95
#
#
#
#
#
# ============================================================
#          — Supplementary error analysis —
# ============================================================
#
#   Offset MAE                           92.8 ms
#   Onset MAE                            3.4 ms
#   Chord completeness                   0.9127
#   Duplicate note rate                  0.0351
#
#   Results saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_smooth
# ============================================================

# %% [markdown]
# ### Method 3 ONLY: Minimum Note Duration (50ms)
# Increases MIN_DUR from 16ms to 50ms. Removes spurious very short notes.

# %%
ALL_SUMMARIES['adv_m3_min_dur'] = run_advanced_evaluation(
    **EVAL_KWARGS_test,
    config_name='adv_m3_min_dur',
    min_note_duration_ms=55.0,
)
# Out:
# Device: NVIDIA RTX PRO 6000 Blackwell Server Edition
# Loaded checkpoint: /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/checkpoints/best.pt
#   Trained for 990 epochs, val_loss=0.0453
#   Model parameters: 26,491,256
#
#   Post-processing config: 'adv_m3_min_dur'
#     ✓ Min Note Duration = 55.0ms
#
# Evaluating 177/177 files from 'test' split...
#   Strategy: full-length single-pass inference + advanced post-processing
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_min_dur/midi_samples/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_07_WAV.mid  (674 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_min_dur/midi_samples/MIDI-Unprocessed_02_R1_2009_03-06_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_04_WAV.mid  (731 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_min_dur/midi_samples/MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_04_Track04_wav.mid  (3198 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_min_dur/midi_samples/MIDI-Unprocessed_24_R1_2006_01-05_ORIG_MID--AUDIO_24_R1_2006_03_Track03_wav.mid  (3265 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_min_dur/midi_samples/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_08_WAV.mid  (3471 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_min_dur/midi_samples/MIDI-Unprocessed_Recital13-15_MID--AUDIO_15_R1_2018_wav--1.mid  (3199 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_min_dur/midi_samples/MIDI-UNPROCESSED_09-10_R1_2014_MID--AUDIO_09_R1_2014_wav--4.mid  (6631 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_min_dur/midi_samples/MIDI-Unprocessed_11_R1_2009_01-05_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_04_WAV.mid  (2344 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_min_dur/midi_samples/MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_12_Track12_wav--1.mid  (1751 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_min_dur/midi_samples/MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_05_Track05_wav.mid  (2535 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_min_dur/midi_samples/MIDI-Unprocessed_05_R1_2008_01-04_ORIG_MID--AUDIO_05_R1_2008_wav--3.mid  (2523 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_min_dur/midi_samples/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_12_R2_2015_wav--3.mid  (7630 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_min_dur/midi_samples/MIDI-Unprocessed_Recital16_MID--AUDIO_16_R1_2018_wav--3.mid  (352 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_min_dur/midi_samples/MIDI-Unprocessed_03_R1_2006_01-05_ORIG_MID--AUDIO_03_R1_2006_04_Track04_wav.mid  (7335 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_min_dur/midi_samples/MIDI-Unprocessed_09_R3_2008_01-07_ORIG_MID--AUDIO_09_R3_2008_wav--2.mid  (805 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_min_dur/midi_samples/MIDI-Unprocessed_09_R3_2008_01-07_ORIG_MID--AUDIO_09_R3_2008_wav--1.mid  (1093 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_min_dur/midi_samples/MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_01_R1_2014_wav--2.mid  (495 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_min_dur/midi_samples/MIDI-UNPROCESSED_19-21_R3_2014_MID--AUDIO_21_R3_2014_wav--1.mid  (1570 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_min_dur/midi_samples/MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_01_R1_2014_wav--1.mid  (1359 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_min_dur/midi_samples/MIDI-Unprocessed_10_R2_2008_01-05_ORIG_MID--AUDIO_10_R2_2008_wav--2.mid  (1675 notes)
#
#   Evaluated 177/177 files in 477.5s
#
#
#
#
#
#
#
# ============================================================
#         — Decoding + evaluation protocol —
# ============================================================
#
#   Decode thresholds:
#     onset_threshold:   0.40
#     frame_threshold:   0.40
#     offset_threshold:  0.50
#   Evaluation tolerances:
#     onset_tolerance:   50 ms
#     pitch_tolerance:   0.25 (25 cents)
#     offset_ratio:      0.2
#     offset_min_tol:    50 ms
#     velocity_tolerance:0.1
#     mir_eval version:  0.8.2
#
#
#
#
#
# ============================================================
#   EVALUATION SUMMARY — test split (n=177)
# ============================================================
#
#   Dataset:    MAESTRO v3.0.0, test split
#   Model:      OnsetsAndFrames (complexity=48, 26,491,256 params)
#   Checkpoint: epoch 990, val_loss=0.0453
#   Config:     adv_m3_min_dur
#   GPU:        NVIDIA RTX PRO 6000 Blackwell Server Edition
#   Eval time:  477.5s (2.7s/file)
#
#
#
#
#
#
# ============================================================
#                  — Primary metrics —
# ============================================================
#
#   Metric                                     P        R       F1
#   ------------------------------------------------------------
#   Note (onset+pitch)                    0.9907   0.9158   0.9510
#   Note w/ offset                        0.7057   0.6538   0.6782
#   Note w/ offset+vel                    0.6732   0.6242   0.6473
#   Frame                                 0.8198   0.7808   0.7981
#
#
#   ------------------------------------------------------------
#   Avg notes/file:  pred=3814  gt=4189  ratio=0.91
#
#
#
#
#
# ============================================================
#          — Supplementary error analysis —
# ============================================================
#
#   Offset MAE                           90.3 ms
#   Onset MAE                            4.0 ms
#   Chord completeness                   0.9111
#   Duplicate note rate                  0.0000
#
#   Results saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_min_dur
# ============================================================

# %% [markdown]
# ### Method 4 ONLY: Velocity-Aware Duplicate Removal
# Removes duplicate same-pitch onsets within 50ms, keeps highest velocity.

# %%
ALL_SUMMARIES['adv_m4_dedup'] = run_advanced_evaluation(
    **EVAL_KWARGS_test,
    config_name='adv_m4_dedup',
    use_duplicate_removal=True,
    duplicate_tolerance_sec=0.06,
)
# Out:
# Device: NVIDIA RTX PRO 6000 Blackwell Server Edition
# Loaded checkpoint: /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/checkpoints/best.pt
#   Trained for 990 epochs, val_loss=0.0453
#   Model parameters: 26,491,256
#
#   Post-processing config: 'adv_m4_dedup'
#     ✓ Duplicate Removal (tol=60ms)
#
# Evaluating 177/177 files from 'test' split...
#   Strategy: full-length single-pass inference + advanced post-processing
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m4_dedup/midi_samples/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_07_WAV.mid  (679 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m4_dedup/midi_samples/MIDI-Unprocessed_02_R1_2009_03-06_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_04_WAV.mid  (734 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m4_dedup/midi_samples/MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_04_Track04_wav.mid  (3235 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m4_dedup/midi_samples/MIDI-Unprocessed_24_R1_2006_01-05_ORIG_MID--AUDIO_24_R1_2006_03_Track03_wav.mid  (3306 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m4_dedup/midi_samples/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_08_WAV.mid  (3509 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m4_dedup/midi_samples/MIDI-Unprocessed_Recital13-15_MID--AUDIO_15_R1_2018_wav--1.mid  (3250 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m4_dedup/midi_samples/MIDI-UNPROCESSED_09-10_R1_2014_MID--AUDIO_09_R1_2014_wav--4.mid  (6702 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m4_dedup/midi_samples/MIDI-Unprocessed_11_R1_2009_01-05_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_04_WAV.mid  (2421 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m4_dedup/midi_samples/MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_12_Track12_wav--1.mid  (1769 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m4_dedup/midi_samples/MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_05_Track05_wav.mid  (2546 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m4_dedup/midi_samples/MIDI-Unprocessed_05_R1_2008_01-04_ORIG_MID--AUDIO_05_R1_2008_wav--3.mid  (2539 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m4_dedup/midi_samples/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_12_R2_2015_wav--3.mid  (7689 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m4_dedup/midi_samples/MIDI-Unprocessed_Recital16_MID--AUDIO_16_R1_2018_wav--3.mid  (353 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m4_dedup/midi_samples/MIDI-Unprocessed_03_R1_2006_01-05_ORIG_MID--AUDIO_03_R1_2006_04_Track04_wav.mid  (7357 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m4_dedup/midi_samples/MIDI-Unprocessed_09_R3_2008_01-07_ORIG_MID--AUDIO_09_R3_2008_wav--2.mid  (813 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m4_dedup/midi_samples/MIDI-Unprocessed_09_R3_2008_01-07_ORIG_MID--AUDIO_09_R3_2008_wav--1.mid  (1094 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m4_dedup/midi_samples/MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_01_R1_2014_wav--2.mid  (495 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m4_dedup/midi_samples/MIDI-UNPROCESSED_19-21_R3_2014_MID--AUDIO_21_R3_2014_wav--1.mid  (1573 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m4_dedup/midi_samples/MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_01_R1_2014_wav--1.mid  (1365 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m4_dedup/midi_samples/MIDI-Unprocessed_10_R2_2008_01-05_ORIG_MID--AUDIO_10_R2_2008_wav--2.mid  (1687 notes)
#
#   Evaluated 177/177 files in 478.4s
#
#
#
#
#
#
#
# ============================================================
#         — Decoding + evaluation protocol —
# ============================================================
#
#   Decode thresholds:
#     onset_threshold:   0.40
#     frame_threshold:   0.40
#     offset_threshold:  0.50
#   Evaluation tolerances:
#     onset_tolerance:   50 ms
#     pitch_tolerance:   0.25 (25 cents)
#     offset_ratio:      0.2
#     offset_min_tol:    50 ms
#     velocity_tolerance:0.1
#     mir_eval version:  0.8.2
#
#
#
#
#
# ============================================================
#   EVALUATION SUMMARY — test split (n=177)
# ============================================================
#
#   Dataset:    MAESTRO v3.0.0, test split
#   Model:      OnsetsAndFrames (complexity=48, 26,491,256 params)
#   Checkpoint: epoch 990, val_loss=0.0453
#   Config:     adv_m4_dedup
#   GPU:        NVIDIA RTX PRO 6000 Blackwell Server Edition
#   Eval time:  478.4s (2.7s/file)
#
#
#
#
#
#
# ============================================================
#                  — Primary metrics —
# ============================================================
#
#   Metric                                     P        R       F1
#   ------------------------------------------------------------
#   Note (onset+pitch)                    0.9895   0.9181   0.9518
#   Note w/ offset                        0.7007   0.6515   0.6747
#   Note w/ offset+vel                    0.6687   0.6223   0.6442
#   Frame                                 0.8198   0.7808   0.7981
#
#
#   ------------------------------------------------------------
#   Avg notes/file:  pred=3831  gt=4189  ratio=0.91
#
#
#
#
#
# ============================================================
#          — Supplementary error analysis —
# ============================================================
#
#   Offset MAE                           92.4 ms
#   Onset MAE                            4.1 ms
#   Chord completeness                   0.9136
#   Duplicate note rate                  0.0000
#
#   Results saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m4_dedup
# ============================================================

# %% [markdown]
# ---
# ## Results — Individual Method Comparison

# %%
# ── Phase 1 Results Table ────────────────────────────────────────────────────
import pandas as pd

phase1_configs = [
    'adv_baseline', 'adv_m3_min_dur', 'adv_m2_smooth', 'adv_m4_dedup'
]

baseline = ALL_SUMMARIES.get('adv_baseline', {})
base_note  = baseline.get('adv_note_f1', baseline.get('note_f1', 0))
base_noff  = baseline.get('adv_note_with_offset_f1', baseline.get('note_with_offset_f1', 0))
base_noffv = baseline.get('adv_note_with_offset_vel_f1', baseline.get('note_with_offset_vel_f1', 0))

print('\n' + '=' * 95)
print('INDIVIDUAL METHOD ISOLATION RESULTS')
print('=' * 95)
print(f"\nBaseline: Note F1={base_note:.4f}  N+Off F1={base_noff:.4f}  N+O+V F1={base_noffv:.4f}")
print(f"\n{'Config':<22s}  {'Adv Note F1':>11s}  {'Adv N+O F1':>11s}  {'Adv N+O+V':>10s}  {'Δ Note':>7s}  {'Δ N+O':>7s}  {'Δ N+O+V':>8s}  {'Dup Rate':>8s}")
print('-' * 95)

for cfg in phase1_configs:
    s = ALL_SUMMARIES.get(cfg, {})
    if not s:
        continue
    adv_n   = s.get('adv_note_f1', s.get('note_f1', 0))
    adv_no  = s.get('adv_note_with_offset_f1', s.get('note_with_offset_f1', 0))
    adv_nov = s.get('adv_note_with_offset_vel_f1', s.get('note_with_offset_vel_f1', 0))
    dn  = adv_n - base_note
    dno = adv_no - base_noff
    dnov = adv_nov - base_noffv
    dup = s.get('ea_duplicate_note_rate', 0)
    sn  = '+' if dn >= 0 else ''
    sno = '+' if dno >= 0 else ''
    snov = '+' if dnov >= 0 else ''
    print(f"{cfg:<22s}  {adv_n:>11.4f}  {adv_no:>11.4f}  {adv_nov:>10.4f}  {sn}{dn:>6.4f}  {sno}{dno:>6.4f}  {snov}{dnov:>7.4f}  {dup:>8.4f}")

print()
# Out:
# ===============================================================================================
# INDIVIDUAL METHOD ISOLATION RESULTS
# ===============================================================================================
#
# Baseline: Note F1=0.9356  N+Off F1=0.6673  N+O+V F1=0.6368
#
# Config                  Adv Note F1   Adv N+O F1   Adv N+O+V   Δ Note    Δ N+O   Δ N+O+V  Dup Rate
# -----------------------------------------------------------------------------------------------
# adv_baseline                 0.9356       0.6673      0.6368  +0.0000  +0.0000  + 0.0000    0.0351
# adv_m3_min_dur               0.9510       0.6782      0.6473  +0.0154  +0.0110  + 0.0105    0.0000
# adv_m2_smooth                0.9353       0.6723      0.6416  -0.0004  +0.0050  + 0.0048    0.0351
# adv_m4_dedup                 0.9518       0.6747      0.6442  +0.0161  +0.0074  + 0.0074    0.0000

# %% [markdown]
# ---
# # Combination Experiments on test set
#
# Based on Phase 1 results, combine methods that individually showed improvement.

# %% [markdown]
# ###  Methods 3+4: Minimum Note Duration + Velocity-Aware Duplicate Removal

# %%
ALL_SUMMARIES['adv_m3_m4'] = run_advanced_evaluation(
    **EVAL_KWARGS_test,
    config_name='adv_m3_m4',
    min_note_duration_ms    = 55.0,
    use_duplicate_removal   = True,
    duplicate_tolerance_sec = 0.06,
)
# Out:
# Device: NVIDIA RTX PRO 6000 Blackwell Server Edition
# Loaded checkpoint: /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/checkpoints/best.pt
#   Trained for 990 epochs, val_loss=0.0453
#   Model parameters: 26,491,256
#
#   Post-processing config: 'adv_m3_m4'
#     ✓ Min Note Duration = 55.0ms
#     ✓ Duplicate Removal (tol=60ms)
#
# Evaluating 177/177 files from 'test' split...
#   Strategy: full-length single-pass inference + advanced post-processing
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_m4/midi_samples/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_07_WAV.mid  (674 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_m4/midi_samples/MIDI-Unprocessed_02_R1_2009_03-06_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_04_WAV.mid  (731 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_m4/midi_samples/MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_04_Track04_wav.mid  (3198 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_m4/midi_samples/MIDI-Unprocessed_24_R1_2006_01-05_ORIG_MID--AUDIO_24_R1_2006_03_Track03_wav.mid  (3265 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_m4/midi_samples/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_08_WAV.mid  (3471 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_m4/midi_samples/MIDI-Unprocessed_Recital13-15_MID--AUDIO_15_R1_2018_wav--1.mid  (3199 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_m4/midi_samples/MIDI-UNPROCESSED_09-10_R1_2014_MID--AUDIO_09_R1_2014_wav--4.mid  (6631 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_m4/midi_samples/MIDI-Unprocessed_11_R1_2009_01-05_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_04_WAV.mid  (2344 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_m4/midi_samples/MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_12_Track12_wav--1.mid  (1751 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_m4/midi_samples/MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_05_Track05_wav.mid  (2535 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_m4/midi_samples/MIDI-Unprocessed_05_R1_2008_01-04_ORIG_MID--AUDIO_05_R1_2008_wav--3.mid  (2523 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_m4/midi_samples/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_12_R2_2015_wav--3.mid  (7630 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_m4/midi_samples/MIDI-Unprocessed_Recital16_MID--AUDIO_16_R1_2018_wav--3.mid  (352 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_m4/midi_samples/MIDI-Unprocessed_03_R1_2006_01-05_ORIG_MID--AUDIO_03_R1_2006_04_Track04_wav.mid  (7335 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_m4/midi_samples/MIDI-Unprocessed_09_R3_2008_01-07_ORIG_MID--AUDIO_09_R3_2008_wav--2.mid  (805 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_m4/midi_samples/MIDI-Unprocessed_09_R3_2008_01-07_ORIG_MID--AUDIO_09_R3_2008_wav--1.mid  (1093 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_m4/midi_samples/MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_01_R1_2014_wav--2.mid  (495 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_m4/midi_samples/MIDI-UNPROCESSED_19-21_R3_2014_MID--AUDIO_21_R3_2014_wav--1.mid  (1570 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_m4/midi_samples/MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_01_R1_2014_wav--1.mid  (1359 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_m4/midi_samples/MIDI-Unprocessed_10_R2_2008_01-05_ORIG_MID--AUDIO_10_R2_2008_wav--2.mid  (1675 notes)
#
#   Evaluated 177/177 files in 543.1s
#
#
#
#
#
#
#
# ============================================================
#         — Decoding + evaluation protocol —
# ============================================================
#
#   Decode thresholds:
#     onset_threshold:   0.40
#     frame_threshold:   0.40
#     offset_threshold:  0.50
#   Evaluation tolerances:
#     onset_tolerance:   50 ms
#     pitch_tolerance:   0.25 (25 cents)
#     offset_ratio:      0.2
#     offset_min_tol:    50 ms
#     velocity_tolerance:0.1
#     mir_eval version:  0.8.2
#
#
#
#
#
# ============================================================
#   EVALUATION SUMMARY — test split (n=177)
# ============================================================
#
#   Dataset:    MAESTRO v3.0.0, test split
#   Model:      OnsetsAndFrames (complexity=48, 26,491,256 params)
#   Checkpoint: epoch 990, val_loss=0.0453
#   Config:     adv_m3_m4
#   GPU:        NVIDIA RTX PRO 6000 Blackwell Server Edition
#   Eval time:  543.1s (3.1s/file)
#
#
#
#
#
#
# ============================================================
#                  — Primary metrics —
# ============================================================
#
#   Metric                                     P        R       F1
#   ------------------------------------------------------------
#   Note (onset+pitch)                    0.9907   0.9158   0.9510
#   Note w/ offset                        0.7057   0.6538   0.6782
#   Note w/ offset+vel                    0.6732   0.6242   0.6473
#   Frame                                 0.8198   0.7808   0.7981
#
#
#   ------------------------------------------------------------
#   Avg notes/file:  pred=3814  gt=4189  ratio=0.91
#
#
#
#
#
# ============================================================
#          — Supplementary error analysis —
# ============================================================
#
#   Offset MAE                           90.3 ms
#   Onset MAE                            4.0 ms
#   Chord completeness                   0.9111
#   Duplicate note rate                  0.0000
#
#   Results saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m3_m4
# ============================================================

# %% [markdown]
# ### Methods 2+3+4: Frame-Level Smoothing + Minimum Note Duration + Velocity-Aware Duplicate Removal

# %%
ALL_SUMMARIES['adv_m2_m3_m4'] = run_advanced_evaluation(
    **EVAL_KWARGS_test,
    config_name='adv_m2_m3_m4',
    use_frame_smoothing     = True,
    frame_smoothing_kernel  = 3,
    frame_smoothing_method  = 'closing',
    min_note_duration_ms    = 55.0,
    use_duplicate_removal   = True,
    duplicate_tolerance_sec = 0.06,
)
# Out:
# Device: NVIDIA RTX PRO 6000 Blackwell Server Edition
# Loaded checkpoint: /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/checkpoints/best.pt
#   Trained for 990 epochs, val_loss=0.0453
#   Model parameters: 26,491,256
#
#   Post-processing config: 'adv_m2_m3_m4'
#     ✓ Frame Smoothing (kernel=3, method=closing)
#     ✓ Min Note Duration = 55.0ms
#     ✓ Duplicate Removal (tol=60ms)
#
# Evaluating 177/177 files from 'test' split...
#   Strategy: full-length single-pass inference + advanced post-processing
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_m3_m4/midi_samples/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_07_WAV.mid  (670 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_m3_m4/midi_samples/MIDI-Unprocessed_02_R1_2009_03-06_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_04_WAV.mid  (729 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_m3_m4/midi_samples/MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_04_Track04_wav.mid  (3183 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_m3_m4/midi_samples/MIDI-Unprocessed_24_R1_2006_01-05_ORIG_MID--AUDIO_24_R1_2006_03_Track03_wav.mid  (3252 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_m3_m4/midi_samples/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_08_WAV.mid  (3456 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_m3_m4/midi_samples/MIDI-Unprocessed_Recital13-15_MID--AUDIO_15_R1_2018_wav--1.mid  (3183 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_m3_m4/midi_samples/MIDI-UNPROCESSED_09-10_R1_2014_MID--AUDIO_09_R1_2014_wav--4.mid  (6601 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_m3_m4/midi_samples/MIDI-Unprocessed_11_R1_2009_01-05_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_04_WAV.mid  (2303 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_m3_m4/midi_samples/MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_12_Track12_wav--1.mid  (1748 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_m3_m4/midi_samples/MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_05_Track05_wav.mid  (2528 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_m3_m4/midi_samples/MIDI-Unprocessed_05_R1_2008_01-04_ORIG_MID--AUDIO_05_R1_2008_wav--3.mid  (2518 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_m3_m4/midi_samples/MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_12_R2_2015_wav--3.mid  (7605 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_m3_m4/midi_samples/MIDI-Unprocessed_Recital16_MID--AUDIO_16_R1_2018_wav--3.mid  (351 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_m3_m4/midi_samples/MIDI-Unprocessed_03_R1_2006_01-05_ORIG_MID--AUDIO_03_R1_2006_04_Track04_wav.mid  (7321 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_m3_m4/midi_samples/MIDI-Unprocessed_09_R3_2008_01-07_ORIG_MID--AUDIO_09_R3_2008_wav--2.mid  (802 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_m3_m4/midi_samples/MIDI-Unprocessed_09_R3_2008_01-07_ORIG_MID--AUDIO_09_R3_2008_wav--1.mid  (1091 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_m3_m4/midi_samples/MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_01_R1_2014_wav--2.mid  (495 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_m3_m4/midi_samples/MIDI-UNPROCESSED_19-21_R3_2014_MID--AUDIO_21_R3_2014_wav--1.mid  (1567 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_m3_m4/midi_samples/MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_01_R1_2014_wav--1.mid  (1358 notes)
# Advanced MIDI saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_m3_m4/midi_samples/MIDI-Unprocessed_10_R2_2008_01-05_ORIG_MID--AUDIO_10_R2_2008_wav--2.mid  (1671 notes)
#
#   Evaluated 177/177 files in 1427.8s
#
#
#
#
#
#
#
# ============================================================
#         — Decoding + evaluation protocol —
# ============================================================
#
#   Decode thresholds:
#     onset_threshold:   0.40
#     frame_threshold:   0.40
#     offset_threshold:  0.50
#   Evaluation tolerances:
#     onset_tolerance:   50 ms
#     pitch_tolerance:   0.25 (25 cents)
#     offset_ratio:      0.2
#     offset_min_tol:    50 ms
#     velocity_tolerance:0.1
#     mir_eval version:  0.8.2
#
#
#
#
#
# ============================================================
#   EVALUATION SUMMARY — test split (n=177)
# ============================================================
#
#   Dataset:    MAESTRO v3.0.0, test split
#   Model:      OnsetsAndFrames (complexity=48, 26,491,256 params)
#   Checkpoint: epoch 990, val_loss=0.0453
#   Config:     adv_m2_m3_m4
#   GPU:        NVIDIA RTX PRO 6000 Blackwell Server Edition
#   Eval time:  1427.8s (8.1s/file)
#
#
#
#
#
#
# ============================================================
#                  — Primary metrics —
# ============================================================
#
#   Metric                                     P        R       F1
#   ------------------------------------------------------------
#   Note (onset+pitch)                    0.9913   0.9138   0.9502
#   Note w/ offset                        0.7121   0.6579   0.6833
#   Note w/ offset+vel                    0.6794   0.6282   0.6523
#   Frame                                 0.8483   0.7469   0.7922
#
#
#   ------------------------------------------------------------
#   Avg notes/file:  pred=3800  gt=4189  ratio=0.91
#
#
#
#
#
# ============================================================
#          — Supplementary error analysis —
# ============================================================
#
#   Offset MAE                           89.9 ms
#   Onset MAE                            4.0 ms
#   Chord completeness                   0.9091
#   Duplicate note rate                  0.0000
#
#   Results saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/eval_test_adv_m2_m3_m4
# ============================================================

# %% [markdown]
# ---
# # Final Comparison & Selection

# %%
# ── Complete Results Table ───────────────────────────────────────────────────
import json
from pathlib import Path

run_dir = Path(RUNS_DIR) / 'OF_full_run_v2'

# Also load from disk in case notebook was restarted
eval_dirs = sorted(run_dir.glob(f'eval_{SPLIT}*'))
for d in eval_dirs:
    sf = d / 'summary_metrics.json'
    if sf.exists():
        cfg_name = d.name.replace(f'eval_{SPLIT}_', '')
        if cfg_name == f'eval_{SPLIT}':
            cfg_name = 'original'
        if cfg_name not in ALL_SUMMARIES:
            with open(sf) as f:
                ALL_SUMMARIES[cfg_name] = json.load(f)

print(f"Total configs loaded: {len(ALL_SUMMARIES)}")
for k in sorted(ALL_SUMMARIES.keys()):
    print(f"  {k}")
# Out:
# Total configs loaded: 7
#   adv_baseline
#   adv_m2_m3_m4
#   adv_m2_smooth
#   adv_m3_m4
#   adv_m3_min_dur
#   adv_m4_dedup
#   original

# %%
# ── Full Comparison Table ────────────────────────────────────────────────────
import pandas as pd

baseline = ALL_SUMMARIES.get('adv_baseline', {})
base_note  = baseline.get('adv_note_f1', baseline.get('note_f1', 0))
base_noff  = baseline.get('adv_note_with_offset_f1', baseline.get('note_with_offset_f1', 0))
base_noffv = baseline.get('adv_note_with_offset_vel_f1', baseline.get('note_with_offset_vel_f1', 0))

# Sort: phase 1 first, then phase 2
ordered = sorted(ALL_SUMMARIES.keys())

print('\n' + '=' * 110)
print('COMPLETE POST-PROCESSING ABLATION RESULTS')
print('=' * 110)
print(f"\n{'Config':<22s}  {'Adv Note':>8s}  {'Adv N+O':>8s}  {'Adv NOV':>8s}  {'Frame':>7s}  {'Δ Note':>7s}  {'Δ N+O':>7s}  {'Δ NOV':>7s}  {'OffMAE':>7s}  {'ChordC':>7s}  {'DupR':>6s}")
print('-' * 110)

for cfg in ordered:
    s = ALL_SUMMARIES[cfg]
    adv_n   = s.get('adv_note_f1', s.get('note_f1', 0))
    adv_no  = s.get('adv_note_with_offset_f1', s.get('note_with_offset_f1', 0))
    adv_nov = s.get('adv_note_with_offset_vel_f1', s.get('note_with_offset_vel_f1', 0))
    frame   = s.get('frame_f1', 0)
    off_mae = s.get('ea_offset_mae_ms', 0)
    chord_c = s.get('ea_chord_completeness', 0)
    dup     = s.get('ea_duplicate_note_rate', 0)
    dn   = adv_n - base_note
    dno  = adv_no - base_noff
    dnov = adv_nov - base_noffv
    sn  = '+' if dn >= 0 else ''
    sno = '+' if dno >= 0 else ''
    snov = '+' if dnov >= 0 else ''
    print(f"{cfg:<22s}  {adv_n:>8.4f}  {adv_no:>8.4f}  {adv_nov:>8.4f}  {frame:>7.4f}  {sn}{dn:>6.4f}  {sno}{dno:>6.4f}  {snov}{dnov:>6.4f}  {off_mae:>7.1f}  {chord_c:>7.4f}  {dup:>6.4f}")

print()
# Out:
# ==============================================================================================================
# COMPLETE POST-PROCESSING ABLATION RESULTS
# ==============================================================================================================
#
# Config                  Adv Note   Adv N+O   Adv NOV    Frame   Δ Note    Δ N+O    Δ NOV   OffMAE   ChordC    DupR
# --------------------------------------------------------------------------------------------------------------
# adv_baseline              0.9356    0.6673    0.6368   0.7981  +0.0000  +0.0000  +0.0000     93.1   0.9136  0.0351
# adv_m2_m3_m4              0.9502    0.6833    0.6523   0.7922  +0.0145  +0.0161  +0.0155     89.9   0.9091  0.0000
# adv_m2_smooth             0.9353    0.6723    0.6416   0.7922  -0.0004  +0.0050  +0.0048     92.8   0.9127  0.0351
# adv_m3_m4                 0.9510    0.6782    0.6473   0.7981  +0.0154  +0.0110  +0.0105     90.3   0.9111  0.0000
# adv_m3_min_dur            0.9510    0.6782    0.6473   0.7981  +0.0154  +0.0110  +0.0105     90.3   0.9111  0.0000
# adv_m4_dedup              0.9518    0.6747    0.6442   0.7981  +0.0161  +0.0074  +0.0074     92.4   0.9136  0.0000
# original                  0.9278    0.6670    0.6375   0.7915  -0.0078  -0.0003  +0.0007     95.1   0.8904  0.0293

# %%
# ── Bar Chart ────────────────────────────────────────────────────────────────
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image

ordered = sorted(ALL_SUMMARIES.keys())
configs = ordered
n_configs = len(configs)

metrics_to_plot = [
    ('adv_note_f1', 'note_f1', 'Note F1'),
    ('adv_note_with_offset_f1', 'note_with_offset_f1', 'Note+Off F1'),
    ('adv_note_with_offset_vel_f1', 'note_with_offset_vel_f1', 'N+O+V F1'),
]

x = np.arange(len(metrics_to_plot))
width = 0.8 / max(n_configs, 1)
colors = plt.cm.tab20(np.linspace(0, 1, max(n_configs, 1)))

fig, ax = plt.subplots(figsize=(16, 7))

for i, cfg in enumerate(configs):
    s = ALL_SUMMARIES[cfg]
    vals = []
    for adv_key, orig_key, _ in metrics_to_plot:
        vals.append(s.get(adv_key, s.get(orig_key, 0)))
    offset = (i - n_configs / 2 + 0.5) * width
    bars = ax.bar(x + offset, vals, width, label=cfg, color=colors[i], alpha=0.85)
    for bar, v in zip(bars, vals):
        ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.003,
                f"{v:.3f}", ha='center', va='bottom', fontsize=6, rotation=60)

ax.set_xticks(x)
ax.set_xticklabels([label for _, _, label in metrics_to_plot], fontsize=12)
ax.set_ylim(0, 1.08)
ax.set_ylabel('F1 Score', fontsize=12)
ax.set_title(f'Post-Processing Ablation — OF_full_run_v2 ({SPLIT} split)', fontsize=14)
ax.legend(fontsize=6, loc='lower right', ncol=3)
ax.grid(True, axis='y', alpha=0.3)

plt.tight_layout()
save_path = str(run_dir / f'pp_ablation_{SPLIT}.png')
plt.savefig(save_path, dpi=150, bbox_inches='tight')
print(f"Chart saved → {save_path}")
plt.close(fig)
Image(save_path)
# Out:
# Chart saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/pp_ablation_test.png

# %%
# ── Save CSV + LaTeX ─────────────────────────────────────────

rows_csv = []
for cfg in sorted(ALL_SUMMARIES.keys()):
    s = ALL_SUMMARIES[cfg]
    rows_csv.append({
        'Config': cfg,
        'Note F1': round(s.get('adv_note_f1', s.get('note_f1', 0)), 4),
        'Note+Off F1': round(s.get('adv_note_with_offset_f1', s.get('note_with_offset_f1', 0)), 4),
        'N+O+V F1': round(s.get('adv_note_with_offset_vel_f1', s.get('note_with_offset_vel_f1', 0)), 4),
        'Frame F1': round(s.get('frame_f1', 0), 4),
        'Offset MAE (ms)': round(s.get('ea_offset_mae_ms', 0), 1),
        'Onset MAE (ms)': round(s.get('ea_onset_mae_ms', 0), 1),
        'Chord Comp': round(s.get('ea_chord_completeness', 0), 4),
        'Dup Rate': round(s.get('ea_duplicate_note_rate', 0), 4),
        'Eval Time (s)': s.get('eval_time_total_s', 0),
    })

df = pd.DataFrame(rows_csv)

# ── CSV export ────────────────────────────────────────────────
csv_path = str(run_dir / f'pp_ablation_{SPLIT}.csv')
df.to_csv(csv_path, index=False)
print(f"CSV saved → {csv_path}")

# ── LaTeX export ──────────────────────────────────────────────
latex_path = str(run_dir / f'pp_ablation_{SPLIT}.tex')

# Escape underscores in config names for LaTeX safety
df_latex = df.copy()
df_latex['Config'] = df_latex['Config'].str.replace('_', r'\_', regex=False)

latex_str = df_latex.to_latex(
    index=False,
    float_format=lambda x: f'{x:.4f}' if isinstance(x, float) and abs(x) < 100 else f'{x:.1f}',
    caption=(
        f'Post-processing ablation results on the MAESTRO v3.0.0 '
        f'{SPLIT} split (n=137). All configurations evaluated with '
        f'decode thresholds (onset=0.40, frame=0.40, offset=0.50) '
        f'and mir\\_eval tolerances (onset=50ms, offset\\_ratio=0.2, '
        f'velocity=0.1).'
    ),
    label=f'tab:pp_ablation_{SPLIT}',
    column_format='l' + 'r' * (len(df.columns) - 1),
    escape=False,
    position='htbp',
)

with open(latex_path, 'w') as f:
    f.write(latex_str)

print(f"LaTeX saved → {latex_path}")
print()
print(df.to_string(index=False))
print()
print("─" * 60)
print("LaTeX preview:")
print("─" * 60)
print(latex_str)
# Out:
# CSV saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/pp_ablation_test.csv
# LaTeX saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/pp_ablation_test.tex
#
#         Config  Note F1  Note+Off F1  N+O+V F1  Frame F1  Offset MAE (ms)  Onset MAE (ms)  Chord Comp  Dup Rate  Eval Time (s)
#   adv_baseline   0.9356       0.6673    0.6368    0.7981             93.1             3.4      0.9136    0.0351          571.9
#   adv_m2_m3_m4   0.9502       0.6833    0.6523    0.7922             89.9             4.0      0.9091    0.0000         1427.8
#  adv_m2_smooth   0.9353       0.6723    0.6416    0.7922             92.8             3.4      0.9127    0.0351         1379.6
#      adv_m3_m4   0.9510       0.6782    0.6473    0.7981             90.3             4.0      0.9111    0.0000          543.1
# adv_m3_min_dur   0.9510       0.6782    0.6473    0.7981             90.3             4.0      0.9111    0.0000          477.5
#   adv_m4_dedup   0.9518       0.6747    0.6442    0.7981             92.4             4.1      0.9136    0.0000          478.4
#       original   0.9278       0.6670    0.6375    0.7915             95.1             4.1      0.8904    0.0293          583.5
#
# ────────────────────────────────────────────────────────────
# LaTeX preview:
# ────────────────────────────────────────────────────────────
# \begin{table}[htbp]
# \caption{Post-processing ablation results on the MAESTRO v3.0.0 test split (n=137). All configurations evaluated with decode thresholds (onset=0.40, frame=0.40, offset=0.50) and mir\_eval tolerances (onset=50ms, offset\_ratio=0.2, velocity=0.1).}
# \label{tab:pp_ablation_test}
# \begin{tabular}{lrrrrrrrrr}
# \toprule
# Config & Note F1 & Note+Off F1 & N+O+V F1 & Frame F1 & Offset MAE (ms) & Onset MAE (ms) & Chord Comp & Dup Rate & Eval Time (s) \\
# \midrule
# adv\_baseline & 0.9356 & 0.6673 & 0.6368 & 0.7981 & 93.1000 & 3.4000 & 0.9136 & 0.0351 & 571.9 \\
# adv\_m2\_m3\_m4 & 0.9502 & 0.6833 & 0.6523 & 0.7922 & 89.9000 & 4.0000 & 0.9091 & 0.0000 & 1427.8 \\
# adv\_m2\_smooth & 0.9353 & 0.6723 & 0.6416 & 0.7922 & 92.8000 & 3.4000 & 0.9127 & 0.0351 & 1379.6 \\
# adv\_m3\_m4 & 0.9510 & 0.6782 & 0.6473 & 0.7981 & 90.3000 & 4.0000 & 0.9111 & 0.0000 & 543.1 \\
# adv\_m3\_min\_dur & 0.9510 & 0.6782 & 0.6473 & 0.7981 & 90.3000 & 4.0000 & 0.9111 & 0.0000 & 477.5 \\
# adv\_m4\_dedup & 0.9518 & 0.6747 & 0.6442 & 0.7981 & 92.4000 & 4.1000 & 0.9136 & 0.0000 & 478.4 \\
# original & 0.9278 & 0.6670 & 0.6375 & 0.7915 & 95.1000 & 4.1000 & 0.8904 & 0.0293 & 583.5 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
# ── Save CSV  ────────────────────────────────────────────────

rows_csv = []
for cfg in sorted(ALL_SUMMARIES.keys()):
    s = ALL_SUMMARIES[cfg]
    rows_csv.append({
        'Config': cfg,
        'Note F1': round(s.get('adv_note_f1', s.get('note_f1', 0)), 4),
        'Note+Off F1': round(s.get('adv_note_with_offset_f1', s.get('note_with_offset_f1', 0)), 4),
        'N+O+V F1': round(s.get('adv_note_with_offset_vel_f1', s.get('note_with_offset_vel_f1', 0)), 4),
        'Frame F1': round(s.get('frame_f1', 0), 4),
        'Offset MAE (ms)': round(s.get('ea_offset_mae_ms', 0), 1),
        'Onset MAE (ms)': round(s.get('ea_onset_mae_ms', 0), 1),
        'Chord Comp': round(s.get('ea_chord_completeness', 0), 4),
        'Dup Rate': round(s.get('ea_duplicate_note_rate', 0), 4),
        'Eval Time (s)': s.get('eval_time_total_s', 0),
    })

df = pd.DataFrame(rows_csv)
csv_path = str(run_dir / f'pp_ablation_{SPLIT}.csv')
df.to_csv(csv_path, index=False)
print(f"CSV saved → {csv_path}")
print()
print(df.to_string(index=False))
# Out:
# CSV saved → /content/drive/MyDrive/piano_amt/runs/OF_full_run_v2/pp_ablation_test.csv
#
#         Config  Note F1  Note+Off F1  N+O+V F1  Frame F1  Offset MAE (ms)  Onset MAE (ms)  Chord Comp  Dup Rate  Eval Time (s)
#   adv_baseline   0.9356       0.6673    0.6368    0.7981             93.1             3.4      0.9136    0.0351          571.9
#   adv_m2_m3_m4   0.9502       0.6833    0.6523    0.7922             89.9             4.0      0.9091    0.0000         1427.8
#  adv_m2_smooth   0.9353       0.6723    0.6416    0.7922             92.8             3.4      0.9127    0.0351         1379.6
#      adv_m3_m4   0.9510       0.6782    0.6473    0.7981             90.3             4.0      0.9111    0.0000          543.1
# adv_m3_min_dur   0.9510       0.6782    0.6473    0.7981             90.3             4.0      0.9111    0.0000          477.5
#   adv_m4_dedup   0.9518       0.6747    0.6442    0.7981             92.4             4.1      0.9136    0.0000          478.4
#       original   0.9278       0.6670    0.6375    0.7915             95.1             4.1      0.8904    0.0293          583.5
