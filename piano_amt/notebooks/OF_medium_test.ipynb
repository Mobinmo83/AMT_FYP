# %% [markdown]
# # Train OnsetsAndFrames (jongwook architecture)
#
# ## Training Stages
#
# | Stage | `max_files` | Approx. data | Purpose |
# |-------|-------------|--------------|---------|
# | 2 — small | 100 | ~4 hr | Tune hyperparameters, verify loss convergence |
#
# ---
#
# ## Hardware & Compute
#
# | Property | Value |
# |----------|-------|
# | GPU | NVIDIA Tesla T4 |
# | GPU VRAM | 15 GB |
# | System RAM | 12.7 GB |
# | Platform | Google Colab |
# | Mixed Precision (AMP) | float16 via torch.amp.autocast |
# | torch.compile | Enabled (PyTorch 2.0+) |
# | TF32 | Disabled (T4 is Turing, not Ampere) |
# | cuDNN benchmark | Enabled |
#
# ---
#
# ## Model
#
# | Property | Value |
# |----------|-------|
# | Architecture | OnsetsAndFrames (jongwook PyTorch reimplementation) |
# | model_complexity | 48 |
# | model_size (hidden) | 768 (complexity × 16) |
# | Total parameters | 26,491,256 (~26.5M) |
# | Heads | onset, frame, offset (BCE), velocity (masked MSE) |
# | Activations | post-sigmoid on onset/frame/offset; raw on velocity |
# | Device | CUDA (T4) |
#
# ---
#
# ## Hyperparameters
#
# | Hyperparameter | Value | Reference |
# |----------------|-------|-----------|
# | Optimizer | Adam | Hawthorne 2018a §3.2 |
# | Learning rate | 6e-4 | Hawthorne 2018a §3.2 |
# | LR scheduler | ReduceLROnPlateau (factor=0.5, patience=3) | jongwook |
# | Epochs | 50 | this run |
# | Train batch size | 4 | jongwook default 8, reduced for T4 |
# | Val batch size | 1 | this run |
# | Per-param grad clip norm | 3.0 | jongwook |
# | Loss: onset/frame/offset | F.binary_cross_entropy ( with pos_weight for onset and offset and frame ) | jongwook + Magenta + Curtis Hawthorne ONSETS AND FRAMES |
# |'pos_weight_onset':  | 25.0 |
# |'pos_weight_frame':  | 6.0 |
# |'pos_weight_offset': | 25.0 |
# | Loss: velocity | Masked MSE at onset positions | Hawthorne 2018a §3.2 |
# | num_workers | 2 | jongwook |
#
# ---
#
#
# ## Segmentation & Data
#
# | Property | Value |
# |----------|-------|
# | Dataset | MAESTRO v3.0.0 |
# | Subset | 100 files (max_files=100) |
# | Train segment length | 640 frames (~20s) — matches jongwook sequence_length=327,680 samples |
# | Val segment length | 1920 frames (~60s) — 3 times train, fixed-size crops |
# | Test segment | Full pieces — sliding window via sliding_windows() |
# | Train shuffle | Yes |
# | Val shuffle | No |
# | drop_last | Train only |
# | Augmentation | Pitch shift (train only) |
# | Train batches | 25 (100 files ÷ batch_size=4) |
# | Val batches | 50 |
#
# ---
#
# ## Tensor Shapes (verified)
#
# | Tensor | Shape | Notes |
# |--------|-------|-------|
# | mel | (B, 229, 640) | log-mel spectrogram, freq-first |
# | onset | (B, 640, 88) | binary piano roll |
# | frame | (B, 640, 88) | binary piano roll |
# | offset | (B, 640, 88) | binary piano roll |
# | velocity | (B, 640, 88) | normalised [0,1] |
#
# ---
#
# ## Model Output at Initialisation (sanity check)
#
# | Head | Min | Max | Expected |
# |------|-----|-----|----------|
# | onset | 0.486 | 0.516 | ~0.5 (random init, post-sigmoid) |
# | frame | 0.467 | 0.534 | ~0.5 (random init, post-sigmoid) |
# | offset | 0.486 | 0.516 | ~0.5 (random init, post-sigmoid) |
# | velocity | -0.053 | 0.057 | ~0.0 (random init, no sigmoid) |
#
# All heads initialise near uniform — correct behaviour before any training.
#
# ---
#
# ## Checkpointing & Outputs
#
# All checkpoints are saved to Google Drive and survive Colab restarts.
# Every run auto-creates `runs/<run_name>/` with:
#
# - `checkpoints/` — `latest.pt` every epoch + `best.pt` on val loss improvement + `epoch_NNN.pt` every 5 epochs
# - `plots/` — loss curve PNG (total + per-head) saved after every epoch
# - `metrics.json` — all epoch losses + timing, updated live
# - `timing_summary.json` — per-epoch and cumulative training time
# - `config.json` — exact config used for this run

# %% [markdown]
# ## Cell 1 — Environment setup
#
# Run every session. Mounts Drive, installs packages, clones repo, sets paths.

# %%
# ── GPU check ─────────────────────────────────────────────────────────────
import torch
assert torch.cuda.is_available(), "No GPU! Change runtime to T4 GPU."
print(f"GPU : {torch.cuda.get_device_name(0)}")
print(f"CUDA: {torch.version.cuda}")
print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
# Out:
# GPU : Tesla T4
# CUDA: 12.8
# VRAM: 15.6 GB

# %%
# ── Mount Google Drive ─────────────────────────────────────────────────────
from google.colab import drive
drive.mount('/content/drive')
print("Drive mounted ✓")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive mounted ✓

# %%
# ── Clone / update repo ────────────────────────────────────────────────────
import os
from getpass import getpass

REPO_DIR = '/content/AMT_FYP'
TOKEN    = getpass('GitHub token: ')

if not os.path.exists(REPO_DIR):
    os.system(f"git clone https://{TOKEN}@github.com/Mobinmo83/AMT_FYP.git {REPO_DIR}")
    print(f"Cloned → {REPO_DIR}")
else:
    os.system(f"cd {REPO_DIR} && git pull")
    print(f"Pulled latest → {REPO_DIR}")
# Out:
# GitHub token: ··········
# Pulled latest → /content/AMT_FYP

# %%
# %cd /content/AMT_FYP/piano_amt
# !pip install -q -r requirements.txt # torch torchaudio pretty_midi pandas tqdm matplotlib pyyaml mir_eval
print("Packages installed ✓")
# Out:
# /content/AMT_FYP/piano_amt
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 52.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 14.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.8/102.8 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 89.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 92.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 86.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 6.1 MB/s eta 0:00:00
#   Building wheel for pretty_midi (setup.py) ... done
# Packages installed ✓

# %%
# ── sys.path + project root ────────────────────────────────────────────────
import sys

PROJECT_ROOT = '/content/AMT_FYP/piano_amt'
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

# Quick sanity check
from src.constants import N_MELS, FRAMES_PER_SECOND, N_KEYS
assert N_MELS == 229 and abs(FRAMES_PER_SECOND - 31.25) < 1e-6 and N_KEYS == 88
print("Imports OK ✓")
# Out:
# Imports OK ✓

# %%
# ── Path constants  (edit ONLY these if your Drive layout differs) ──────────
DRIVE_ROOT   = '/content/drive/MyDrive/piano_amt'
MAESTRO_ROOT = f'{DRIVE_ROOT}/maestro-v3.0.0'
CACHE_DIR    = f'{DRIVE_ROOT}/cache'
RUNS_DIR     = f'{DRIVE_ROOT}/runs'

import os
os.makedirs(RUNS_DIR, exist_ok=True)

# Verify cache exists
import glob
npzs = glob.glob(f'{CACHE_DIR}/*.npz')
print(f"Cache files : {len(npzs)}")
assert len(npzs) > 0, "Run 02_build_cache.ipynb first!"
print(f"MAESTRO root: {MAESTRO_ROOT}")
print(f"Runs dir    : {RUNS_DIR}")
# Out:
# Cache files : 1276
# MAESTRO root: /content/drive/MyDrive/piano_amt/maestro-v3.0.0
# Runs dir    : /content/drive/MyDrive/piano_amt/runs

# %% [markdown]
# ## Cell 2 — Training configuration
#
# **Edit the `CONFIG` dict to choose your training stage.**
#
# Key parameters:
# - `run_name`: unique name saved to Drive — use descriptive names like `of_baseline_stage1`
# - `max_files`: controls dataset size (None = full 962 training files)
# - `model_complexity`: 48 = full jongwook model (~26M params); 16 = small debug model (~1M params)
# - `epochs`: use fewer epochs for smoke/tiny tests; 30+ for real training
# - `resume`: path to a `.pt` checkpoint to resume from; None to start fresh

# %%
# ═══════════════════════════════════════════════════════════════════════════
# TRAINING CONFIGURATION — edit this cell
# ═══════════════════════════════════════════════════════════════════════════

CONFIG = {
    # ── Identity ───────────────────────────────────────────────────────────
    # Choose a descriptive name; results saved to RUNS_DIR/<run_name>/
    'run_name':   'OF_medium_test',   # <-- CHANGE THIS each run

    # ── Dataset size ──────────────────────────────────────────────────────
    # Stage 0 (smoke): max_files=5     (~10 min audio, 2 epochs, verify loop)
    # Stage 1 (tiny):  max_files=30    (~1 hr audio, 5 epochs)
    # Stage 2 (small): max_files=100   (~4 hr audio, 15 epochs)
    # Stage 3 (medium):max_files=400   (~20 hr audio, 30 epochs)
    # Stage 4 (full):  max_files=None  (~178 hr audio, 30+ epochs)
    'max_files':  800,

    # ── Model ─────────────────────────────────────────────────────────────
    # 48 = full jongwook (~26M params) — use for stage 2+
    # 16 = small debug (~1M params) — use for stage 0+1 to move faster
    'model_complexity': 48,

    # ── Training ─────────────────────────────────────────────────────────
    'epochs':        100,      # smoke=2, tiny=5, small=15, medium=30, full=30+
    'batch_size_train': 8,   # for training (can be 8 on better GPUs)
    'batch_size_val':   1,
    'lr':            6e-4,   # Hawthorne 2018a §3.2
    'max_grad_norm': 3.0,
    'num_workers':   0,
    'log_every':     10,     # print loss every N steps

    # Stage 2 (small,  max_files=100):  onset=25, frame=6,  offset=25
    # Stage 3 (medium, max_files=400):  onset=10, frame=3,  offset=10
    # Stage 4 (full,   max_files=None): onset=1,  frame=1,  offset=1   ← plain BCE like jongwook
    'pos_weight_onset':  8.0,
    'pos_weight_frame':   2.0,
    'pos_weight_offset': 8.0,

    # ── Resume from checkpoint (set to None to start fresh) ───────────────
    # Example: f'{RUNS_DIR}/of_baseline_stage1/checkpoints/best.pt'
    'resume': None,
}

# ─── Print config summary ─────────────────────────────────────────────────
print("Training configuration:")
for k, v in CONFIG.items():
    print(f"  {k:20s}: {v}")
# Out:
# Training configuration:
#   run_name            : OF_medium_test
#   max_files           : 800
#   model_complexity    : 48
#   epochs              : 100
#   batch_size_train    : 8
#   batch_size_val      : 1
#   lr                  : 0.0006
#   max_grad_norm       : 3.0
#   num_workers         : 0
#   log_every           : 10
#   pos_weight_onset    : 8.0
#   pos_weight_frame    : 2.0
#   pos_weight_offset   : 8.0
#   resume              : None

# %% [markdown]
# ## Cell 3 — Build model and inspect

# %%
import torch
from models.onsets_frames.model import OnsetsAndFrames

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model  = OnsetsAndFrames(model_complexity=CONFIG['model_complexity'])

n_params = model.count_parameters()
print(f"Model          : OnsetsAndFrames")
print(f"model_complexity: {CONFIG['model_complexity']}")
print(f"Parameters     : {n_params:,}")
print(f"Device         : {device}")

# Quick forward pass to check shapes
model = model.to(device)
dummy = torch.zeros(2, 229, 640).to(device)
with torch.no_grad():
    out = model(dummy)
for k, v in out.items():
    print(f"  {k:10s}: {tuple(v.shape)}  min={v.min():.3f} max={v.max():.3f}")

assert out['onset'].shape  == (2, 640, 88), "Onset shape wrong"
assert out['frame'].shape  == (2, 640, 88), "Frame shape wrong"
assert out['offset'].shape == (2, 640, 88), "Offset shape wrong"
print("\nModel shapes OK ✓")
# Out:
# Model          : OnsetsAndFrames
# model_complexity: 48
# Parameters     : 26,491,256
# Device         : cuda
#   onset     : (2, 640, 88)  min=0.482 max=0.513
#   frame     : (2, 640, 88)  min=0.459 max=0.549
#   offset    : (2, 640, 88)  min=0.488 max=0.516
#   velocity  : (2, 640, 88)  min=-0.074 max=0.062
#
# Model shapes OK ✓

# %% [markdown]
# ## Cell 4 — Build DataLoaders

# %%
from src.dataloader import get_dataloader

train_loader = get_dataloader(
    maestro_root   = MAESTRO_ROOT,
    split          = 'train',
    batch_size     = CONFIG['batch_size_train'],
    num_workers    = CONFIG['num_workers'],
    cache_dir      = CACHE_DIR,
    max_files      = CONFIG['max_files'],
    use_augmentation = True,
    pin_memory     = True,
)
val_loader = get_dataloader(
    maestro_root   = MAESTRO_ROOT,
    split          = 'validation',
    batch_size     = CONFIG['batch_size_val'],
    num_workers    = CONFIG['num_workers'],
    cache_dir      = CACHE_DIR,
    max_files      = CONFIG['max_files'],
    use_augmentation = False,
    pin_memory     = True,
)
print(f"Train batches : {len(train_loader)}  (batch_size={CONFIG['batch_size_train']})")
print(f"Val batches   : {len(val_loader)}")

# Peek at one batch
batch = next(iter(train_loader))
print(f"\nSample batch:")
for k, v in batch.items():
    if hasattr(v, 'shape'):
        print(f"  {k:12s}: {tuple(v.shape)}")
print("DataLoaders OK ✓")
# Out:
# Train batches : 100  (batch_size=8)
# Val batches   : 137
#
# Sample batch:
#   mel         : (8, 229, 640)
#   onset       : (8, 640, 88)
#   frame       : (8, 640, 88)
#   offset      : (8, 640, 88)
#   velocity    : (8, 640, 88)
# DataLoaders OK ✓

# %%
val_batch = next(iter(val_loader))
print(f"Val mel shape  : {val_batch['mel'].shape}")    # expect (B, 229, 1920)
print(f"Val onset shape: {val_batch['onset'].shape}")  # expect (B, 1920, 88)
train_batch = next(iter(train_loader))
print(f"Train mel shape: {train_batch['mel'].shape}")  # expect (B, 229, 640)
# Out:
# Val mel shape  : torch.Size([1, 229, 1920])
# Val onset shape: torch.Size([1, 1920, 88])
# Train mel shape: torch.Size([8, 229, 640])

# %% [markdown]
# ## Cell 5 — Train
#
# This cell runs the full training loop.
# Loss curves are saved to Drive after every epoch — if Colab disconnects,
# you can resume from `best.pt` by setting `CONFIG['resume']` above.
#
# **Watch:** the `[ep NNN step NNN]` lines show per-batch loss in real time.

# %%
from models.onsets_frames.train import OnsetsFramesLoss, Trainer, RunDirectory

# Create run directory
run_dir = RunDirectory(RUNS_DIR, CONFIG['run_name'])

# Save config
import json
cfg_to_save = dict(CONFIG)
cfg_to_save.update({'maestro_root': MAESTRO_ROOT, 'cache_dir': CACHE_DIR,
                    'device': str(device)})
run_dir.save_config(cfg_to_save)

# Fresh model
model = OnsetsAndFrames(model_complexity=CONFIG['model_complexity'])

# Trainer with GPU optimizations
trainer = Trainer(
    model          = model,
    train_loader   = train_loader,
    val_loader     = val_loader,
    device         = device,
    run_dir        = run_dir,
    lr             = CONFIG['lr'],
    # pos_weight     = CONFIG['pos_weight'],
    max_grad_norm  = CONFIG['max_grad_norm'],
    log_every      = CONFIG['log_every'],
    use_amp        = True,
    use_compile    = True,
    pos_weight_onset  = CONFIG['pos_weight_onset'],   # ADD
    pos_weight_frame  = CONFIG['pos_weight_frame'],   # ADD
    pos_weight_offset = CONFIG['pos_weight_offset'],  # ADD
)

# Resume from checkpoint if specified
start_epoch = 1
if CONFIG['resume']:
    ckpt_path = CONFIG['resume']
    print(f"Resuming from: {ckpt_path}")
    ckpt = torch.load(ckpt_path, map_location=device)

    # Handle torch.compile wrapper
    model_to_load = trainer.model
    if hasattr(trainer.model, '_orig_mod'):
        model_to_load = trainer.model._orig_mod
    model_to_load.load_state_dict(ckpt['model_state'])

    if 'optimizer_state' in ckpt:
        trainer.optimizer.load_state_dict(ckpt['optimizer_state'])
    if 'scheduler_state' in ckpt:
        trainer.scheduler.load_state_dict(ckpt['scheduler_state'])
    if 'scaler_state' in ckpt and trainer.scaler is not None:
        trainer.scaler.load_state_dict(ckpt['scaler_state'])

    start_epoch = ckpt['epoch'] + 1
    trainer.global_step = ckpt.get('global_step', 0)
    trainer.best_val_loss = ckpt.get('best_val_loss', ckpt.get('val_loss', float('inf')))
    print(f"  Resumed at epoch {start_epoch}, best_val_loss={trainer.best_val_loss:.4f}")

trainer.fit(epochs=CONFIG['epochs'], start_epoch=start_epoch)

print(f"\n\u2713 Training complete. Run directory: {run_dir.root}")
print(f"  Best val loss : {trainer.best_val_loss:.4f}")
print(f"  Best checkpoint: {run_dir.best_checkpoint_path()}")
# Out:
# ============================================================
# Starting training: epochs 1→100
# Run directory: /content/drive/MyDrive/piano_amt/runs/OF_medium_test
# Best val loss so far: inf
# Cumulative training time: 0.0s
# ============================================================
#
# --- Epoch 1/100 ---
# W0402 23:55:43.004000 2397 torch/_inductor/utils.py:1679] [1/0] Not enough SMs to use max_autotune_gemm mode
#   [ep 001  step     10]  total=2.3778  onset=0.1533  frame=0.2570  offset=0.1521  vel=1.8155  (126.3s)
#   [ep 001  step     20]  total=1.1876  onset=0.1013  frame=0.2136  offset=0.1008  vel=0.7719  (83.2s)
#   [ep 001  step     30]  total=0.9247  onset=0.1358  frame=0.1911  offset=0.1351  vel=0.4626  (77.6s)
#   [ep 001  step     40]  total=0.8275  onset=0.1564  frame=0.2000  offset=0.1582  vel=0.3128  (81.1s)
#   [ep 001  step     50]  total=0.7817  onset=0.1696  frame=0.1958  offset=0.1701  vel=0.2462  (76.1s)
#   [ep 001  step     60]  total=0.6338  onset=0.1310  frame=0.1839  offset=0.1310  vel=0.1879  (86.1s)
#   [ep 001  step     70]  total=0.5749  onset=0.1278  frame=0.1864  offset=0.1279  vel=0.1329  (78.8s)
#   [ep 001  step     80]  total=0.5270  onset=0.1080  frame=0.1673  offset=0.1086  vel=0.1430  (86.0s)
#   [ep 001  step     90]  total=0.5730  onset=0.1320  frame=0.1609  offset=0.1316  vel=0.1484  (79.3s)
#   [ep 001  step    100]  total=0.5686  onset=0.1170  frame=0.1796  offset=0.1170  vel=0.1550  (82.2s)
#   train_loss=1.3137  val_loss=0.5101  lr=6.00e-04  time=1017s  ETA: ~1678min ★ NEW BEST
#
# --- Epoch 2/100 ---
#   [ep 002  step    110]  total=0.5496  onset=0.1444  frame=0.1716  offset=0.1437  vel=0.0899  (17.0s)
#   [ep 002  step    120]  total=0.5806  onset=0.1617  frame=0.1849  offset=0.1613  vel=0.0727  (18.6s)
#   [ep 002  step    130]  total=0.5556  onset=0.1363  frame=0.1959  offset=0.1359  vel=0.0875  (17.7s)
#   [ep 002  step    140]  total=0.5022  onset=0.1278  frame=0.1857  offset=0.1277  vel=0.0609  (20.1s)
#   [ep 002  step    150]  total=0.5379  onset=0.1485  frame=0.1605  offset=0.1484  vel=0.0804  (16.9s)
#   [ep 002  step    160]  total=0.4197  onset=0.0996  frame=0.1621  offset=0.0993  vel=0.0587  (19.1s)
#   [ep 002  step    170]  total=0.4586  onset=0.1061  frame=0.1964  offset=0.1060  vel=0.0501  (18.8s)
#   [ep 002  step    180]  total=0.4239  onset=0.1021  frame=0.1632  offset=0.1023  vel=0.0563  (20.2s)
#   [ep 002  step    190]  total=0.4984  onset=0.1291  frame=0.1861  offset=0.1281  vel=0.0552  (19.9s)
#   [ep 002  step    200]  total=0.5111  onset=0.1329  frame=0.1939  offset=0.1323  vel=0.0521  (18.8s)
#   train_loss=0.5087  val_loss=0.4550  lr=6.00e-04  time=230s  ETA: ~376min ★ NEW BEST
#
# --- Epoch 3/100 ---
#   [ep 003  step    210]  total=0.4935  onset=0.1186  frame=0.1816  offset=0.1181  vel=0.0752  (34.4s)
#   [ep 003  step    220]  total=0.5667  onset=0.1564  frame=0.1703  offset=0.1567  vel=0.0833  (18.5s)
#   [ep 003  step    230]  total=0.4494  onset=0.1117  frame=0.1846  offset=0.1123  vel=0.0409  (20.0s)
#   [ep 003  step    240]  total=0.5060  onset=0.1306  frame=0.1978  offset=0.1320  vel=0.0456  (18.5s)
#   [ep 003  step    250]  total=0.4281  onset=0.0998  frame=0.1832  offset=0.1001  vel=0.0451  (18.6s)
#   [ep 003  step    260]  total=0.5410  onset=0.1269  frame=0.1980  offset=0.1290  vel=0.0871  (17.7s)
#   [ep 003  step    270]  total=0.5045  onset=0.1338  frame=0.1842  offset=0.1370  vel=0.0495  (18.0s)
#   [ep 003  step    280]  total=0.5468  onset=0.1305  frame=0.2074  offset=0.1348  vel=0.0740  (19.5s)
#   [ep 003  step    290]  total=0.5235  onset=0.1256  frame=0.2114  offset=0.1320  vel=0.0545  (18.5s)
#   [ep 003  step    300]  total=0.4381  onset=0.1103  frame=0.1683  offset=0.1203  vel=0.0392  (18.4s)
#   train_loss=0.4873  val_loss=0.4391  lr=6.00e-04  time=243s  ETA: ~394min ★ NEW BEST
#
# --- Epoch 4/100 ---
#   [ep 004  step    310]  total=0.4339  onset=0.1082  frame=0.1624  offset=0.1209  vel=0.0424  (31.3s)
#   [ep 004  step    320]  total=0.4691  onset=0.1169  frame=0.1830  offset=0.1313  vel=0.0378  (19.1s)
#   [ep 004  step    330]  total=0.4449  onset=0.0981  frame=0.1963  offset=0.1145  vel=0.0360  (17.3s)
#   [ep 004  step    340]  total=0.4884  onset=0.1231  frame=0.1864  offset=0.1434  vel=0.0355  (19.5s)
#   [ep 004  step    350]  total=0.4599  onset=0.1163  frame=0.1680  offset=0.1384  vel=0.0373  (19.9s)
#   [ep 004  step    360]  total=0.4508  onset=0.1076  frame=0.1790  offset=0.1273  vel=0.0369  (18.7s)
#   [ep 004  step    370]  total=0.4812  onset=0.1149  frame=0.1814  offset=0.1380  vel=0.0469  (19.1s)
#   [ep 004  step    380]  total=0.4187  onset=0.0915  frame=0.1776  offset=0.1185  vel=0.0310  (17.2s)
#   [ep 004  step    390]  total=0.4108  onset=0.0823  frame=0.1834  offset=0.1094  vel=0.0357  (18.0s)
#   [ep 004  step    400]  total=0.4099  onset=0.0839  frame=0.1755  offset=0.1081  vel=0.0424  (17.8s)
#   train_loss=0.4484  val_loss=0.4182  lr=6.00e-04  time=239s  ETA: ~382min ★ NEW BEST
#
# --- Epoch 5/100 ---
#   [ep 005  step    410]  total=0.4401  onset=0.0878  frame=0.1942  offset=0.1140  vel=0.0441  (34.6s)
#   [ep 005  step    420]  total=0.4449  onset=0.0850  frame=0.1988  offset=0.1103  vel=0.0508  (18.5s)
#   [ep 005  step    430]  total=0.4245  onset=0.0968  frame=0.1663  offset=0.1201  vel=0.0413  (19.5s)
#   [ep 005  step    440]  total=0.3508  onset=0.0466  frame=0.1977  offset=0.0698  vel=0.0367  (19.6s)
#   [ep 005  step    450]  total=0.4248  onset=0.0979  frame=0.1729  offset=0.1283  vel=0.0256  (17.4s)
#   [ep 005  step    460]  total=0.3926  onset=0.0882  frame=0.1581  offset=0.1124  vel=0.0339  (17.6s)
#   [ep 005  step    470]  total=0.3931  onset=0.0829  frame=0.1752  offset=0.1123  vel=0.0227  (17.4s)
#   [ep 005  step    480]  total=0.3914  onset=0.0778  frame=0.1790  offset=0.1068  vel=0.0277  (18.6s)
#   [ep 005  step    490]  total=0.5237  onset=0.1388  frame=0.1746  offset=0.1682  vel=0.0421  (16.3s)
#   [ep 005  step    500]  total=0.4698  onset=0.1047  frame=0.1933  offset=0.1331  vel=0.0387  (17.5s)
#   train_loss=0.4362  val_loss=0.4009  lr=6.00e-04  time=238s  ETA: ~376min ★ NEW BEST
#
# --- Epoch 6/100 ---
#   [ep 006  step    510]  total=0.3925  onset=0.0854  frame=0.1696  offset=0.1064  vel=0.0311  (32.1s)
#   [ep 006  step    520]  total=0.3812  onset=0.0760  frame=0.1839  offset=0.1022  vel=0.0192  (20.6s)
#   [ep 006  step    530]  total=0.4543  onset=0.1027  frame=0.1941  offset=0.1351  vel=0.0225  (18.6s)
#   [ep 006  step    540]  total=0.4643  onset=0.1068  frame=0.1909  offset=0.1385  vel=0.0282  (17.6s)
#   [ep 006  step    550]  total=0.3789  onset=0.0767  frame=0.1650  offset=0.1055  vel=0.0317  (20.4s)
#   [ep 006  step    560]  total=0.4603  onset=0.0979  frame=0.1817  offset=0.1246  vel=0.0560  (21.1s)
#   [ep 006  step    570]  total=0.4409  onset=0.0951  frame=0.1863  offset=0.1203  vel=0.0392  (17.3s)
#   [ep 006  step    580]  total=0.4365  onset=0.1040  frame=0.1737  offset=0.1324  vel=0.0264  (17.2s)
#   [ep 006  step    590]  total=0.3975  onset=0.0809  frame=0.1871  offset=0.1080  vel=0.0215  (17.9s)
#   [ep 006  step    600]  total=0.3656  onset=0.0662  frame=0.1853  offset=0.0950  vel=0.0190  (17.2s)
#   train_loss=0.4201  val_loss=0.3962  lr=6.00e-04  time=241s  ETA: ~378min ★ NEW BEST
#
# --- Epoch 7/100 ---
#   [ep 007  step    610]  total=0.3943  onset=0.0825  frame=0.1821  offset=0.1132  vel=0.0166  (33.8s)
#   [ep 007  step    620]  total=0.4954  onset=0.1175  frame=0.2001  offset=0.1508  vel=0.0271  (20.5s)
#   [ep 007  step    630]  total=0.3411  onset=0.0668  frame=0.1680  offset=0.0906  vel=0.0157  (19.4s)
#   [ep 007  step    640]  total=0.4081  onset=0.0858  frame=0.1902  offset=0.1160  vel=0.0161  (16.7s)
#   [ep 007  step    650]  total=0.3831  onset=0.0831  frame=0.1689  offset=0.1153  vel=0.0158  (20.1s)
#   [ep 007  step    660]  total=0.4832  onset=0.1144  frame=0.1862  offset=0.1618  vel=0.0209  (17.9s)
#   [ep 007  step    670]  total=0.3633  onset=0.0690  frame=0.1622  offset=0.1079  vel=0.0242  (17.5s)
#   [ep 007  step    680]  total=0.4175  onset=0.0891  frame=0.1582  offset=0.1389  vel=0.0312  (18.0s)
#   [ep 007  step    690]  total=0.3833  onset=0.0738  frame=0.1729  offset=0.1149  vel=0.0218  (19.2s)
#   [ep 007  step    700]  total=0.4075  onset=0.0722  frame=0.1890  offset=0.1244  vel=0.0219  (16.6s)
#   train_loss=0.4097  val_loss=0.3790  lr=6.00e-04  time=241s  ETA: ~373min ★ NEW BEST
#
# --- Epoch 8/100 ---
#   [ep 008  step    710]  total=0.3829  onset=0.0644  frame=0.1904  offset=0.1078  vel=0.0203  (31.8s)
#   [ep 008  step    720]  total=0.3871  onset=0.0731  frame=0.1721  offset=0.1242  vel=0.0177  (22.3s)
#   [ep 008  step    730]  total=0.4352  onset=0.0799  frame=0.1982  offset=0.1395  vel=0.0176  (18.2s)
#   [ep 008  step    740]  total=0.4478  onset=0.0840  frame=0.2037  offset=0.1410  vel=0.0193  (18.5s)
#   [ep 008  step    750]  total=0.4365  onset=0.0745  frame=0.1902  offset=0.1439  vel=0.0279  (16.1s)
#   [ep 008  step    760]  total=0.3864  onset=0.0565  frame=0.2001  offset=0.1108  vel=0.0191  (18.5s)
#   [ep 008  step    770]  total=0.3817  onset=0.0659  frame=0.1683  offset=0.1289  vel=0.0187  (18.1s)
#   [ep 008  step    780]  total=0.3700  onset=0.0476  frame=0.1882  offset=0.1075  vel=0.0267  (16.3s)
#   [ep 008  step    790]  total=0.3390  onset=0.0403  frame=0.1827  offset=0.0878  vel=0.0281  (17.2s)
#   [ep 008  step    800]  total=0.3397  onset=0.0427  frame=0.1835  offset=0.0942  vel=0.0193  (19.9s)
#   train_loss=0.3785  val_loss=0.3539  lr=6.00e-04  time=237s  ETA: ~363min ★ NEW BEST
#
# --- Epoch 9/100 ---
#   [ep 009  step    810]  total=0.3211  onset=0.0368  frame=0.1719  offset=0.0958  vel=0.0165  (33.2s)
#   [ep 009  step    820]  total=0.3440  onset=0.0499  frame=0.1619  offset=0.1134  vel=0.0188  (19.4s)
#   [ep 009  step    830]  total=0.3606  onset=0.0453  frame=0.1923  offset=0.1029  vel=0.0201  (19.1s)
#   [ep 009  step    840]  total=0.3191  onset=0.0364  frame=0.1724  offset=0.0954  vel=0.0148  (16.9s)
#   [ep 009  step    850]  total=0.4292  onset=0.0698  frame=0.1890  offset=0.1359  vel=0.0344  (18.6s)
#   [ep 009  step    860]  total=0.3336  onset=0.0370  frame=0.1930  offset=0.0921  vel=0.0115  (17.8s)
#   [ep 009  step    870]  total=0.3013  onset=0.0351  frame=0.1596  offset=0.0890  vel=0.0177  (15.1s)
#   [ep 009  step    880]  total=0.3115  onset=0.0303  frame=0.1860  offset=0.0856  vel=0.0095  (18.6s)
#   [ep 009  step    890]  total=0.3305  onset=0.0361  frame=0.1817  offset=0.0937  vel=0.0190  (18.7s)
#   [ep 009  step    900]  total=0.3831  onset=0.0590  frame=0.1844  offset=0.1188  vel=0.0209  (17.5s)
#   train_loss=0.3523  val_loss=0.3201  lr=6.00e-04  time=235s  ETA: ~356min ★ NEW BEST
#
# --- Epoch 10/100 ---
#   [ep 010  step    910]  total=0.3920  onset=0.0699  frame=0.1769  offset=0.1251  vel=0.0201  (30.2s)
#   [ep 010  step    920]  total=0.3175  onset=0.0303  frame=0.1968  offset=0.0771  vel=0.0133  (17.6s)
#   [ep 010  step    930]  total=0.3453  onset=0.0454  frame=0.1926  offset=0.0920  vel=0.0152  (17.6s)
#   [ep 010  step    940]  total=0.2917  onset=0.0332  frame=0.1641  offset=0.0822  vel=0.0122  (20.3s)
#   [ep 010  step    950]  total=0.3245  onset=0.0386  frame=0.1828  offset=0.0898  vel=0.0133  (16.3s)
#   [ep 010  step    960]  total=0.2745  onset=0.0324  frame=0.1559  offset=0.0715  vel=0.0147  (18.1s)
#   [ep 010  step    970]  total=0.2771  onset=0.0215  frame=0.1802  offset=0.0604  vel=0.0150  (20.0s)
#   [ep 010  step    980]  total=0.3580  onset=0.0536  frame=0.1819  offset=0.1040  vel=0.0184  (19.7s)
#   [ep 010  step    990]  total=0.3787  onset=0.0596  frame=0.1948  offset=0.1036  vel=0.0207  (19.2s)
#   [ep 010  step   1000]  total=0.3090  onset=0.0373  frame=0.1789  offset=0.0809  vel=0.0120  (17.8s)
#   train_loss=0.3255  val_loss=0.3036  lr=6.00e-04  time=237s  ETA: ~356min ★ NEW BEST
#
# --- Epoch 11/100 ---
#   [ep 011  step   1010]  total=0.3031  onset=0.0404  frame=0.1698  offset=0.0811  vel=0.0119  (32.6s)
#   [ep 011  step   1020]  total=0.2963  onset=0.0369  frame=0.1691  offset=0.0779  vel=0.0125  (16.3s)
#   [ep 011  step   1030]  total=0.2985  onset=0.0278  frame=0.1924  offset=0.0664  vel=0.0119  (20.6s)
#   [ep 011  step   1040]  total=0.3039  onset=0.0388  frame=0.1759  offset=0.0723  vel=0.0169  (17.0s)
#   [ep 011  step   1050]  total=0.2691  onset=0.0276  frame=0.1654  offset=0.0615  vel=0.0146  (19.3s)
#   [ep 011  step   1060]  total=0.2690  onset=0.0302  frame=0.1651  offset=0.0608  vel=0.0128  (18.1s)
#   [ep 011  step   1070]  total=0.3094  onset=0.0287  frame=0.1956  offset=0.0714  vel=0.0137  (20.4s)
#   [ep 011  step   1080]  total=0.2726  onset=0.0274  frame=0.1625  offset=0.0657  vel=0.0171  (18.0s)
#   [ep 011  step   1090]  total=0.2692  onset=0.0225  frame=0.1574  offset=0.0581  vel=0.0313  (17.9s)
#   [ep 011  step   1100]  total=0.3138  onset=0.0382  frame=0.1640  offset=0.0783  vel=0.0333  (16.8s)
#   train_loss=0.3064  val_loss=0.3048  lr=6.00e-04  time=237s  ETA: ~352min
#
# --- Epoch 12/100 ---
#   [ep 012  step   1110]  total=0.3808  onset=0.0557  frame=0.1881  offset=0.0903  vel=0.0468  (25.7s)
#   [ep 012  step   1120]  total=0.2740  onset=0.0290  frame=0.1539  offset=0.0636  vel=0.0275  (17.2s)
#   [ep 012  step   1130]  total=0.2990  onset=0.0293  frame=0.1770  offset=0.0718  vel=0.0208  (17.3s)
#   [ep 012  step   1140]  total=0.3210  onset=0.0341  frame=0.1940  offset=0.0739  vel=0.0191  (19.0s)
#   [ep 012  step   1150]  total=0.3504  onset=0.0587  frame=0.1684  offset=0.1021  vel=0.0213  (18.0s)
#   [ep 012  step   1160]  total=0.3168  onset=0.0444  frame=0.1720  offset=0.0800  vel=0.0204  (16.9s)
#   [ep 012  step   1170]  total=0.3128  onset=0.0467  frame=0.1618  offset=0.0909  vel=0.0133  (19.3s)
#   [ep 012  step   1180]  total=0.3338  onset=0.0566  frame=0.1717  offset=0.0923  vel=0.0133  (20.9s)
#   [ep 012  step   1190]  total=0.3093  onset=0.0428  frame=0.1690  offset=0.0839  vel=0.0136  (17.5s)
#   [ep 012  step   1200]  total=0.2940  onset=0.0389  frame=0.1674  offset=0.0740  vel=0.0138  (18.8s)
#   train_loss=0.2988  val_loss=0.2740  lr=6.00e-04  time=231s  ETA: ~339min ★ NEW BEST
#
# --- Epoch 13/100 ---
#   [ep 013  step   1210]  total=0.2813  onset=0.0286  frame=0.1720  offset=0.0665  vel=0.0142  (32.4s)
#   [ep 013  step   1220]  total=0.3146  onset=0.0525  frame=0.1505  offset=0.0948  vel=0.0168  (18.1s)
#   [ep 013  step   1230]  total=0.2982  onset=0.0398  frame=0.1639  offset=0.0821  vel=0.0123  (19.4s)
#   [ep 013  step   1240]  total=0.2466  onset=0.0311  frame=0.1427  offset=0.0627  vel=0.0101  (19.5s)
#   [ep 013  step   1250]  total=0.2505  onset=0.0246  frame=0.1533  offset=0.0586  vel=0.0140  (18.5s)
#   [ep 013  step   1260]  total=0.2532  onset=0.0306  frame=0.1422  offset=0.0595  vel=0.0208  (17.0s)
#   [ep 013  step   1270]  total=0.2886  onset=0.0373  frame=0.1618  offset=0.0771  vel=0.0124  (17.6s)
#   [ep 013  step   1280]  total=0.3051  onset=0.0458  frame=0.1544  offset=0.0877  vel=0.0172  (19.2s)
#   [ep 013  step   1290]  total=0.3426  onset=0.0542  frame=0.1752  offset=0.0950  vel=0.0182  (16.6s)
#   [ep 013  step   1300]  total=0.2479  onset=0.0284  frame=0.1429  offset=0.0648  vel=0.0119  (19.2s)
#   train_loss=0.2731  val_loss=0.2437  lr=6.00e-04  time=238s  ETA: ~345min ★ NEW BEST
#
# --- Epoch 14/100 ---
#   [ep 014  step   1310]  total=0.2525  onset=0.0345  frame=0.1348  offset=0.0738  vel=0.0094  (31.4s)
#   [ep 014  step   1320]  total=0.2446  onset=0.0341  frame=0.1319  offset=0.0671  vel=0.0115  (15.4s)
#   [ep 014  step   1330]  total=0.3229  onset=0.0579  frame=0.1480  offset=0.1034  vel=0.0135  (18.3s)
#   [ep 014  step   1340]  total=0.2543  onset=0.0277  frame=0.1503  offset=0.0661  vel=0.0101  (19.7s)
#   [ep 014  step   1350]  total=0.2612  onset=0.0410  frame=0.1294  offset=0.0809  vel=0.0099  (19.1s)
#   [ep 014  step   1360]  total=0.2646  onset=0.0402  frame=0.1339  offset=0.0790  vel=0.0115  (19.7s)
#   [ep 014  step   1370]  total=0.2496  onset=0.0317  frame=0.1381  offset=0.0680  vel=0.0118  (18.7s)
#   [ep 014  step   1380]  total=0.2312  onset=0.0331  frame=0.1162  offset=0.0714  vel=0.0106  (18.8s)
#   [ep 014  step   1390]  total=0.2766  onset=0.0534  frame=0.1266  offset=0.0848  vel=0.0119  (17.7s)
#   [ep 014  step   1400]  total=0.2500  onset=0.0377  frame=0.1222  offset=0.0753  vel=0.0149  (18.7s)
#   train_loss=0.2516  val_loss=0.2300  lr=6.00e-04  time=237s  ETA: ~340min ★ NEW BEST
#
# --- Epoch 15/100 ---
#   [ep 015  step   1410]  total=0.2591  onset=0.0358  frame=0.1389  offset=0.0732  vel=0.0113  (30.3s)
#   [ep 015  step   1420]  total=0.2381  onset=0.0383  frame=0.1150  offset=0.0747  vel=0.0100  (18.3s)
#   [ep 015  step   1430]  total=0.2395  onset=0.0245  frame=0.1402  offset=0.0643  vel=0.0106  (17.5s)
#   [ep 015  step   1440]  total=0.2313  onset=0.0343  frame=0.1149  offset=0.0716  vel=0.0105  (18.5s)
#   [ep 015  step   1450]  total=0.2362  onset=0.0222  frame=0.1450  offset=0.0581  vel=0.0109  (18.9s)
#   [ep 015  step   1460]  total=0.2213  onset=0.0331  frame=0.1140  offset=0.0641  vel=0.0102  (18.0s)
#   [ep 015  step   1470]  total=0.2560  onset=0.0318  frame=0.1313  offset=0.0701  vel=0.0228  (19.2s)
#   [ep 015  step   1480]  total=0.1975  onset=0.0161  frame=0.1226  offset=0.0446  vel=0.0142  (19.7s)
#   [ep 015  step   1490]  total=0.2667  onset=0.0418  frame=0.1311  offset=0.0806  vel=0.0133  (17.6s)
#   [ep 015  step   1500]  total=0.2204  onset=0.0227  frame=0.1314  offset=0.0588  vel=0.0074  (17.8s)
#   train_loss=0.2352  val_loss=0.2233  lr=6.00e-04  time=236s  ETA: ~335min ★ NEW BEST
#
# --- Epoch 16/100 ---
#   [ep 016  step   1510]  total=0.1794  onset=0.0211  frame=0.0971  offset=0.0528  vel=0.0086  (30.1s)
#   [ep 016  step   1520]  total=0.2290  onset=0.0331  frame=0.1125  offset=0.0694  vel=0.0141  (16.9s)
#   [ep 016  step   1530]  total=0.2279  onset=0.0230  frame=0.1332  offset=0.0614  vel=0.0103  (19.8s)
#   [ep 016  step   1540]  total=0.2348  onset=0.0269  frame=0.1304  offset=0.0704  vel=0.0071  (17.7s)
#   [ep 016  step   1550]  total=0.2249  onset=0.0269  frame=0.1194  offset=0.0653  vel=0.0132  (17.7s)
#   [ep 016  step   1560]  total=0.2242  onset=0.0273  frame=0.1178  offset=0.0681  vel=0.0111  (19.6s)
#   [ep 016  step   1570]  total=0.2270  onset=0.0349  frame=0.1149  offset=0.0660  vel=0.0113  (20.1s)
#   [ep 016  step   1580]  total=0.2361  onset=0.0248  frame=0.1321  offset=0.0660  vel=0.0132  (17.8s)
#   [ep 016  step   1590]  total=0.2505  onset=0.0343  frame=0.1303  offset=0.0763  vel=0.0096  (20.9s)
#   [ep 016  step   1600]  total=0.2435  onset=0.0302  frame=0.1321  offset=0.0705  vel=0.0107  (20.1s)
#   train_loss=0.2236  val_loss=0.2061  lr=6.00e-04  time=242s  ETA: ~338min ★ NEW BEST
#
# --- Epoch 17/100 ---
#   [ep 017  step   1610]  total=0.2409  onset=0.0340  frame=0.1219  offset=0.0763  vel=0.0086  (31.2s)
#   [ep 017  step   1620]  total=0.2230  onset=0.0279  frame=0.1175  offset=0.0683  vel=0.0093  (17.9s)
#   [ep 017  step   1630]  total=0.2227  onset=0.0326  frame=0.1127  offset=0.0676  vel=0.0098  (19.9s)
#   [ep 017  step   1640]  total=0.2342  onset=0.0386  frame=0.1106  offset=0.0729  vel=0.0122  (19.3s)
#   [ep 017  step   1650]  total=0.2134  onset=0.0319  frame=0.1067  offset=0.0599  vel=0.0149  (18.2s)
#   [ep 017  step   1660]  total=0.2085  onset=0.0296  frame=0.1049  offset=0.0629  vel=0.0111  (17.9s)
#   [ep 017  step   1670]  total=0.1963  onset=0.0194  frame=0.1143  offset=0.0541  vel=0.0086  (18.2s)
#   [ep 017  step   1680]  total=0.2242  onset=0.0315  frame=0.1143  offset=0.0685  vel=0.0099  (18.4s)
#   [ep 017  step   1690]  total=0.2034  onset=0.0289  frame=0.1062  offset=0.0602  vel=0.0081  (18.2s)
#   [ep 017  step   1700]  total=0.1953  onset=0.0246  frame=0.1057  offset=0.0574  vel=0.0076  (18.7s)
#   train_loss=0.2193  val_loss=0.2071  lr=6.00e-04  time=239s  ETA: ~330min
#
# --- Epoch 18/100 ---
#   [ep 018  step   1710]  total=0.2896  onset=0.0428  frame=0.1565  offset=0.0791  vel=0.0112  (25.4s)
#   [ep 018  step   1720]  total=0.2540  onset=0.0360  frame=0.1334  offset=0.0711  vel=0.0135  (21.1s)
#   [ep 018  step   1730]  total=0.2064  onset=0.0287  frame=0.1066  offset=0.0603  vel=0.0108  (18.4s)
#   [ep 018  step   1740]  total=0.2154  onset=0.0265  frame=0.1199  offset=0.0597  vel=0.0093  (16.2s)
#   [ep 018  step   1750]  total=0.2649  onset=0.0530  frame=0.1104  offset=0.0872  vel=0.0144  (19.6s)
#   [ep 018  step   1760]  total=0.2241  onset=0.0347  frame=0.1054  offset=0.0693  vel=0.0148  (19.5s)
#   [ep 018  step   1770]  total=0.2847  onset=0.0536  frame=0.1210  offset=0.0945  vel=0.0156  (18.2s)
#   [ep 018  step   1780]  total=0.1983  onset=0.0243  frame=0.1067  offset=0.0584  vel=0.0089  (16.6s)
#   [ep 018  step   1790]  total=0.2783  onset=0.0498  frame=0.1259  offset=0.0913  vel=0.0113  (17.1s)
#   [ep 018  step   1800]  total=0.2111  onset=0.0318  frame=0.1032  offset=0.0674  vel=0.0086  (18.0s)
#   train_loss=0.2204  val_loss=0.2043  lr=6.00e-04  time=230s  ETA: ~315min ★ NEW BEST
#
# --- Epoch 19/100 ---
#   [ep 019  step   1810]  total=0.1966  onset=0.0266  frame=0.1044  offset=0.0582  vel=0.0074  (31.0s)
#   [ep 019  step   1820]  total=0.2234  onset=0.0343  frame=0.1169  offset=0.0635  vel=0.0088  (19.6s)
#   [ep 019  step   1830]  total=0.1926  onset=0.0231  frame=0.0995  offset=0.0610  vel=0.0089  (18.8s)
#   [ep 019  step   1840]  total=0.1930  onset=0.0233  frame=0.1035  offset=0.0580  vel=0.0082  (17.7s)
#   [ep 019  step   1850]  total=0.2253  onset=0.0304  frame=0.1183  offset=0.0669  vel=0.0097  (17.6s)
#   [ep 019  step   1860]  total=0.2688  onset=0.0478  frame=0.1223  offset=0.0881  vel=0.0106  (18.3s)
#   [ep 019  step   1870]  total=0.2430  onset=0.0443  frame=0.1042  offset=0.0791  vel=0.0155  (19.5s)
#   [ep 019  step   1880]  total=0.2460  onset=0.0399  frame=0.0949  offset=0.0759  vel=0.0353  (16.0s)
#   [ep 019  step   1890]  total=0.2140  onset=0.0260  frame=0.1044  offset=0.0650  vel=0.0185  (17.7s)
#   [ep 019  step   1900]  total=0.2198  onset=0.0269  frame=0.1049  offset=0.0647  vel=0.0232  (18.7s)
#   train_loss=0.2160  val_loss=0.2058  lr=6.00e-04  time=235s  ETA: ~317min
#
# --- Epoch 20/100 ---
#   [ep 020  step   1910]  total=0.2006  onset=0.0229  frame=0.0987  offset=0.0585  vel=0.0205  (23.3s)
#   [ep 020  step   1920]  total=0.2060  onset=0.0267  frame=0.1033  offset=0.0621  vel=0.0140  (14.8s)
#   [ep 020  step   1930]  total=0.1660  onset=0.0178  frame=0.0909  offset=0.0484  vel=0.0089  (19.4s)
#   [ep 020  step   1940]  total=0.2068  onset=0.0252  frame=0.1109  offset=0.0571  vel=0.0135  (17.5s)
#   [ep 020  step   1950]  total=0.2111  onset=0.0316  frame=0.0998  offset=0.0676  vel=0.0122  (17.2s)
#   [ep 020  step   1960]  total=0.2504  onset=0.0331  frame=0.1325  offset=0.0701  vel=0.0147  (19.2s)
#   [ep 020  step   1970]  total=0.2550  onset=0.0349  frame=0.1327  offset=0.0756  vel=0.0118  (21.2s)
#   [ep 020  step   1980]  total=0.2653  onset=0.0439  frame=0.1263  offset=0.0787  vel=0.0165  (19.5s)
#   [ep 020  step   1990]  total=0.1954  onset=0.0299  frame=0.0943  offset=0.0628  vel=0.0084  (19.3s)
#   [ep 020  step   2000]  total=0.2120  onset=0.0302  frame=0.1059  offset=0.0616  vel=0.0142  (18.0s)
#   train_loss=0.2103  val_loss=0.1962  lr=6.00e-04  time=230s  ETA: ~307min ★ NEW BEST
#
# --- Epoch 21/100 ---
#   [ep 021  step   2010]  total=0.2266  onset=0.0349  frame=0.1054  offset=0.0738  vel=0.0126  (32.5s)
#   [ep 021  step   2020]  total=0.1834  onset=0.0229  frame=0.0960  offset=0.0551  vel=0.0095  (17.2s)
#   [ep 021  step   2030]  total=0.2234  onset=0.0375  frame=0.0965  offset=0.0792  vel=0.0102  (18.3s)
#   [ep 021  step   2040]  total=0.1795  onset=0.0176  frame=0.1041  offset=0.0510  vel=0.0067  (18.0s)
#   [ep 021  step   2050]  total=0.1865  onset=0.0258  frame=0.0895  offset=0.0593  vel=0.0119  (18.6s)
#   [ep 021  step   2060]  total=0.1933  onset=0.0326  frame=0.0877  offset=0.0656  vel=0.0074  (18.4s)
#   [ep 021  step   2070]  total=0.1984  onset=0.0304  frame=0.0907  offset=0.0692  vel=0.0081  (17.7s)
#   [ep 021  step   2080]  total=0.1982  onset=0.0236  frame=0.1051  offset=0.0606  vel=0.0089  (20.1s)
#   [ep 021  step   2090]  total=0.1680  onset=0.0224  frame=0.0862  offset=0.0524  vel=0.0070  (16.5s)
#   [ep 021  step   2100]  total=0.1839  onset=0.0200  frame=0.0974  offset=0.0589  vel=0.0075  (17.3s)
#   train_loss=0.2044  val_loss=0.1892  lr=6.00e-04  time=235s  ETA: ~310min ★ NEW BEST
#
# --- Epoch 22/100 ---
#   [ep 022  step   2110]  total=0.1777  onset=0.0231  frame=0.0893  offset=0.0547  vel=0.0106  (30.2s)
#   [ep 022  step   2120]  total=0.2508  onset=0.0408  frame=0.1109  offset=0.0868  vel=0.0124  (16.1s)
#   [ep 022  step   2130]  total=0.1953  onset=0.0280  frame=0.0976  offset=0.0609  vel=0.0088  (18.1s)
#   [ep 022  step   2140]  total=0.1903  onset=0.0161  frame=0.1125  offset=0.0545  vel=0.0072  (20.8s)
#   [ep 022  step   2150]  total=0.1747  onset=0.0204  frame=0.0903  offset=0.0548  vel=0.0092  (15.6s)
#   [ep 022  step   2160]  total=0.2617  onset=0.0447  frame=0.1209  offset=0.0862  vel=0.0099  (19.2s)
#   [ep 022  step   2170]  total=0.1928  onset=0.0207  frame=0.0973  offset=0.0576  vel=0.0172  (20.8s)
#   [ep 022  step   2180]  total=0.2166  onset=0.0296  frame=0.1122  offset=0.0666  vel=0.0083  (18.7s)
#   [ep 022  step   2190]  total=0.1949  onset=0.0298  frame=0.0937  offset=0.0640  vel=0.0073  (18.6s)
#   [ep 022  step   2200]  total=0.2172  onset=0.0266  frame=0.1150  offset=0.0674  vel=0.0082  (19.5s)
#   train_loss=0.2034  val_loss=0.1871  lr=6.00e-04  time=238s  ETA: ~310min ★ NEW BEST
#
# --- Epoch 23/100 ---
#   [ep 023  step   2210]  total=0.1880  onset=0.0305  frame=0.0835  offset=0.0658  vel=0.0082  (29.7s)
#   [ep 023  step   2220]  total=0.1802  onset=0.0163  frame=0.1078  offset=0.0472  vel=0.0089  (16.5s)
#   [ep 023  step   2230]  total=0.2503  onset=0.0446  frame=0.1098  offset=0.0814  vel=0.0145  (17.3s)
#   [ep 023  step   2240]  total=0.1759  onset=0.0169  frame=0.0994  offset=0.0528  vel=0.0069  (20.4s)
#   [ep 023  step   2250]  total=0.2247  onset=0.0310  frame=0.1126  offset=0.0688  vel=0.0123  (21.2s)
#   [ep 023  step   2260]  total=0.1948  onset=0.0341  frame=0.0829  offset=0.0697  vel=0.0080  (18.9s)
#   [ep 023  step   2270]  total=0.2025  onset=0.0233  frame=0.1101  offset=0.0616  vel=0.0074  (17.9s)
#   [ep 023  step   2280]  total=0.2048  onset=0.0355  frame=0.0887  offset=0.0714  vel=0.0093  (16.9s)
#   [ep 023  step   2290]  total=0.1753  onset=0.0233  frame=0.0887  offset=0.0568  vel=0.0065  (19.3s)
#   [ep 023  step   2300]  total=0.1877  onset=0.0280  frame=0.0916  offset=0.0606  vel=0.0074  (18.9s)
#   train_loss=0.1928  val_loss=0.1820  lr=6.00e-04  time=237s  ETA: ~305min ★ NEW BEST
#
# --- Epoch 24/100 ---
#   [ep 024  step   2310]  total=0.1649  onset=0.0177  frame=0.0930  offset=0.0448  vel=0.0094  (33.4s)
#   [ep 024  step   2320]  total=0.1795  onset=0.0189  frame=0.0981  offset=0.0555  vel=0.0070  (16.5s)
#   [ep 024  step   2330]  total=0.2244  onset=0.0445  frame=0.0921  offset=0.0752  vel=0.0126  (17.5s)
#   [ep 024  step   2340]  total=0.2088  onset=0.0286  frame=0.0968  offset=0.0629  vel=0.0204  (18.2s)
#   [ep 024  step   2350]  total=0.1774  onset=0.0219  frame=0.0919  offset=0.0553  vel=0.0083  (18.0s)
#   [ep 024  step   2360]  total=0.2073  onset=0.0360  frame=0.0912  offset=0.0693  vel=0.0107  (14.6s)
#   [ep 024  step   2370]  total=0.1986  onset=0.0319  frame=0.0975  offset=0.0602  vel=0.0091  (21.3s)
#   [ep 024  step   2380]  total=0.2058  onset=0.0284  frame=0.1025  offset=0.0621  vel=0.0128  (18.8s)
#   [ep 024  step   2390]  total=0.2233  onset=0.0339  frame=0.1043  offset=0.0690  vel=0.0162  (19.8s)
#   [ep 024  step   2400]  total=0.1902  onset=0.0235  frame=0.0970  offset=0.0615  vel=0.0083  (19.3s)
#   train_loss=0.1940  val_loss=0.1762  lr=6.00e-04  time=237s  ETA: ~300min ★ NEW BEST
#
# --- Epoch 25/100 ---
#   [ep 025  step   2410]  total=0.2296  onset=0.0410  frame=0.1017  offset=0.0742  vel=0.0127  (30.4s)
#   [ep 025  step   2420]  total=0.1958  onset=0.0349  frame=0.0856  offset=0.0633  vel=0.0120  (18.4s)
#   [ep 025  step   2430]  total=0.1582  onset=0.0178  frame=0.0785  offset=0.0524  vel=0.0094  (20.0s)
#   [ep 025  step   2440]  total=0.2024  onset=0.0426  frame=0.0787  offset=0.0711  vel=0.0100  (17.8s)
#   [ep 025  step   2450]  total=0.2583  onset=0.0557  frame=0.0981  offset=0.0918  vel=0.0128  (18.4s)
#   [ep 025  step   2460]  total=0.1884  onset=0.0262  frame=0.0920  offset=0.0634  vel=0.0068  (16.8s)
#   [ep 025  step   2470]  total=0.1860  onset=0.0203  frame=0.0986  offset=0.0604  vel=0.0067  (17.8s)
#   [ep 025  step   2480]  total=0.1594  onset=0.0179  frame=0.0816  offset=0.0492  vel=0.0107  (20.6s)
#   [ep 025  step   2490]  total=0.2319  onset=0.0402  frame=0.0986  offset=0.0775  vel=0.0155  (16.6s)
#   [ep 025  step   2500]  total=0.1820  onset=0.0259  frame=0.0847  offset=0.0637  vel=0.0077  (19.4s)
#   train_loss=0.1887  val_loss=0.1758  lr=6.00e-04  time=236s  ETA: ~295min ★ NEW BEST
#
# --- Epoch 26/100 ---
#   [ep 026  step   2510]  total=0.1629  onset=0.0222  frame=0.0775  offset=0.0541  vel=0.0091  (32.6s)
#   [ep 026  step   2520]  total=0.1773  onset=0.0142  frame=0.1154  offset=0.0411  vel=0.0067  (18.9s)
#   [ep 026  step   2530]  total=0.2090  onset=0.0395  frame=0.0868  offset=0.0722  vel=0.0106  (17.6s)
#   [ep 026  step   2540]  total=0.1909  onset=0.0279  frame=0.0891  offset=0.0594  vel=0.0145  (18.3s)
#   [ep 026  step   2550]  total=0.2118  onset=0.0429  frame=0.0778  offset=0.0742  vel=0.0170  (16.4s)
#   [ep 026  step   2560]  total=0.1839  onset=0.0302  frame=0.0820  offset=0.0629  vel=0.0088  (17.8s)
#   [ep 026  step   2570]  total=0.1538  onset=0.0148  frame=0.0818  offset=0.0500  vel=0.0071  (18.1s)
#   [ep 026  step   2580]  total=0.1685  onset=0.0234  frame=0.0853  offset=0.0519  vel=0.0079  (18.0s)
#   [ep 026  step   2590]  total=0.1748  onset=0.0216  frame=0.0863  offset=0.0595  vel=0.0074  (18.7s)
#   [ep 026  step   2600]  total=0.1780  onset=0.0154  frame=0.1053  offset=0.0498  vel=0.0075  (18.0s)
#   train_loss=0.1913  val_loss=0.1805  lr=6.00e-04  time=234s  ETA: ~289min
#
# --- Epoch 27/100 ---
#   [ep 027  step   2610]  total=0.1397  onset=0.0132  frame=0.0794  offset=0.0412  vel=0.0060  (25.7s)
#   [ep 027  step   2620]  total=0.1659  onset=0.0212  frame=0.0825  offset=0.0527  vel=0.0096  (19.3s)
#   [ep 027  step   2630]  total=0.1886  onset=0.0283  frame=0.0887  offset=0.0620  vel=0.0096  (17.1s)
#   [ep 027  step   2640]  total=0.1524  onset=0.0153  frame=0.0852  offset=0.0445  vel=0.0074  (19.3s)
#   [ep 027  step   2650]  total=0.1423  onset=0.0189  frame=0.0678  offset=0.0480  vel=0.0075  (15.8s)
#   [ep 027  step   2660]  total=0.2164  onset=0.0355  frame=0.1008  offset=0.0661  vel=0.0139  (17.7s)
#   [ep 027  step   2670]  total=0.1971  onset=0.0296  frame=0.0924  offset=0.0680  vel=0.0071  (19.1s)
#   [ep 027  step   2680]  total=0.2049  onset=0.0374  frame=0.0838  offset=0.0743  vel=0.0094  (20.0s)
#   [ep 027  step   2690]  total=0.1526  onset=0.0187  frame=0.0748  offset=0.0506  vel=0.0084  (17.4s)
#   [ep 027  step   2700]  total=0.1714  onset=0.0176  frame=0.0914  offset=0.0536  vel=0.0088  (16.7s)
#   train_loss=0.1843  val_loss=0.1785  lr=6.00e-04  time=228s  ETA: ~277min
#
# --- Epoch 28/100 ---
#   [ep 028  step   2710]  total=0.1810  onset=0.0274  frame=0.0781  offset=0.0620  vel=0.0134  (25.1s)
#   [ep 028  step   2720]  total=0.2049  onset=0.0316  frame=0.0934  offset=0.0704  vel=0.0095  (18.4s)
#   [ep 028  step   2730]  total=0.2135  onset=0.0296  frame=0.1114  offset=0.0627  vel=0.0097  (17.9s)
#   [ep 028  step   2740]  total=0.1546  onset=0.0202  frame=0.0787  offset=0.0485  vel=0.0072  (18.6s)
#   [ep 028  step   2750]  total=0.2406  onset=0.0433  frame=0.1013  offset=0.0862  vel=0.0098  (19.8s)
#   [ep 028  step   2760]  total=0.1959  onset=0.0195  frame=0.1126  offset=0.0530  vel=0.0108  (18.0s)
#   [ep 028  step   2770]  total=0.1701  onset=0.0249  frame=0.0782  offset=0.0567  vel=0.0104  (19.8s)
#   [ep 028  step   2780]  total=0.1774  onset=0.0216  frame=0.0868  offset=0.0600  vel=0.0090  (18.0s)
#   [ep 028  step   2790]  total=0.1583  onset=0.0175  frame=0.0811  offset=0.0520  vel=0.0077  (16.0s)
#   [ep 028  step   2800]  total=0.1790  onset=0.0230  frame=0.0916  offset=0.0555  vel=0.0090  (18.2s)
#   train_loss=0.1826  val_loss=0.1743  lr=6.00e-04  time=231s  ETA: ~277min ★ NEW BEST
#
# --- Epoch 29/100 ---
#   [ep 029  step   2810]  total=0.1427  onset=0.0182  frame=0.0693  offset=0.0476  vel=0.0075  (33.9s)
#   [ep 029  step   2820]  total=0.1682  onset=0.0173  frame=0.0859  offset=0.0565  vel=0.0085  (20.2s)
#   [ep 029  step   2830]  total=0.1926  onset=0.0286  frame=0.0847  offset=0.0714  vel=0.0079  (18.2s)
#   [ep 029  step   2840]  total=0.2375  onset=0.0401  frame=0.0965  offset=0.0831  vel=0.0178  (18.1s)
#   [ep 029  step   2850]  total=0.1702  onset=0.0230  frame=0.0822  offset=0.0555  vel=0.0095  (18.8s)
#   [ep 029  step   2860]  total=0.1410  onset=0.0153  frame=0.0748  offset=0.0445  vel=0.0064  (18.6s)
#   [ep 029  step   2870]  total=0.1977  onset=0.0347  frame=0.0907  offset=0.0636  vel=0.0087  (18.1s)
#   [ep 029  step   2880]  total=0.1793  onset=0.0237  frame=0.0876  offset=0.0579  vel=0.0101  (18.4s)
#   [ep 029  step   2890]  total=0.1763  onset=0.0293  frame=0.0753  offset=0.0621  vel=0.0096  (17.5s)
#   [ep 029  step   2900]  total=0.1961  onset=0.0264  frame=0.0950  offset=0.0650  vel=0.0097  (17.5s)
#   train_loss=0.1829  val_loss=0.1628  lr=6.00e-04  time=240s  ETA: ~284min ★ NEW BEST
#
# --- Epoch 30/100 ---
#   [ep 030  step   2910]  total=0.2214  onset=0.0366  frame=0.0943  offset=0.0795  vel=0.0111  (30.5s)
#   [ep 030  step   2920]  total=0.1854  onset=0.0338  frame=0.0748  offset=0.0680  vel=0.0089  (17.0s)
#   [ep 030  step   2930]  total=0.1921  onset=0.0161  frame=0.1200  offset=0.0454  vel=0.0106  (18.9s)
#   [ep 030  step   2940]  total=0.1934  onset=0.0258  frame=0.1006  offset=0.0597  vel=0.0073  (17.8s)
#   [ep 030  step   2950]  total=0.1556  onset=0.0196  frame=0.0765  offset=0.0511  vel=0.0083  (19.5s)
#   [ep 030  step   2960]  total=0.1921  onset=0.0343  frame=0.0807  offset=0.0651  vel=0.0120  (21.1s)
#   [ep 030  step   2970]  total=0.1975  onset=0.0258  frame=0.0943  offset=0.0668  vel=0.0106  (19.0s)
#   [ep 030  step   2980]  total=0.2024  onset=0.0331  frame=0.0919  offset=0.0684  vel=0.0089  (17.8s)
#   [ep 030  step   2990]  total=0.1648  onset=0.0220  frame=0.0745  offset=0.0590  vel=0.0093  (18.3s)
#   [ep 030  step   3000]  total=0.1742  onset=0.0215  frame=0.0861  offset=0.0564  vel=0.0102  (17.1s)
#   train_loss=0.1802  val_loss=0.1679  lr=6.00e-04  time=237s  ETA: ~277min
#
# --- Epoch 31/100 ---
#   [ep 031  step   3010]  total=0.2042  onset=0.0254  frame=0.1078  offset=0.0626  vel=0.0083  (24.5s)
#   [ep 031  step   3020]  total=0.2551  onset=0.0441  frame=0.1062  offset=0.0855  vel=0.0193  (18.5s)
#   [ep 031  step   3030]  total=0.2028  onset=0.0352  frame=0.0791  offset=0.0703  vel=0.0182  (20.5s)
#   [ep 031  step   3040]  total=0.1893  onset=0.0277  frame=0.0915  offset=0.0624  vel=0.0077  (18.5s)
#   [ep 031  step   3050]  total=0.1666  onset=0.0265  frame=0.0724  offset=0.0580  vel=0.0097  (18.3s)
#   [ep 031  step   3060]  total=0.1814  onset=0.0176  frame=0.0961  offset=0.0557  vel=0.0120  (18.4s)
#   [ep 031  step   3070]  total=0.1374  onset=0.0176  frame=0.0643  offset=0.0454  vel=0.0100  (17.7s)
#   [ep 031  step   3080]  total=0.1379  onset=0.0132  frame=0.0721  offset=0.0434  vel=0.0092  (20.8s)
#   [ep 031  step   3090]  total=0.1686  onset=0.0197  frame=0.0875  offset=0.0532  vel=0.0082  (16.4s)
#   [ep 031  step   3100]  total=0.1803  onset=0.0269  frame=0.0781  offset=0.0642  vel=0.0111  (16.8s)
#   train_loss=0.1822  val_loss=0.1715  lr=6.00e-04  time=231s  ETA: ~265min
#
# --- Epoch 32/100 ---
#   [ep 032  step   3110]  total=0.1706  onset=0.0191  frame=0.0886  offset=0.0516  vel=0.0112  (26.5s)
#   [ep 032  step   3120]  total=0.1971  onset=0.0314  frame=0.0937  offset=0.0634  vel=0.0087  (17.8s)
#   [ep 032  step   3130]  total=0.1850  onset=0.0281  frame=0.0799  offset=0.0677  vel=0.0093  (17.8s)
#   [ep 032  step   3140]  total=0.1681  onset=0.0216  frame=0.0825  offset=0.0558  vel=0.0082  (17.8s)
#   [ep 032  step   3150]  total=0.1650  onset=0.0151  frame=0.0875  offset=0.0558  vel=0.0065  (16.8s)
#   [ep 032  step   3160]  total=0.2030  onset=0.0411  frame=0.0769  offset=0.0737  vel=0.0113  (18.9s)
#   [ep 032  step   3170]  total=0.1744  onset=0.0264  frame=0.0767  offset=0.0613  vel=0.0100  (19.8s)
#   [ep 032  step   3180]  total=0.1827  onset=0.0286  frame=0.0810  offset=0.0651  vel=0.0080  (17.0s)
#   [ep 032  step   3190]  total=0.2006  onset=0.0363  frame=0.0829  offset=0.0697  vel=0.0116  (18.9s)
#   [ep 032  step   3200]  total=0.1608  onset=0.0195  frame=0.0804  offset=0.0531  vel=0.0079  (18.6s)
#   train_loss=0.1761  val_loss=0.1632  lr=6.00e-04  time=230s  ETA: ~261min
#
# --- Epoch 33/100 ---
#   [ep 033  step   3210]  total=0.1734  onset=0.0229  frame=0.0912  offset=0.0518  vel=0.0074  (25.5s)
#   [ep 033  step   3220]  total=0.1637  onset=0.0229  frame=0.0780  offset=0.0546  vel=0.0081  (18.5s)
#   [ep 033  step   3230]  total=0.1584  onset=0.0231  frame=0.0725  offset=0.0550  vel=0.0078  (19.3s)
#   [ep 033  step   3240]  total=0.1674  onset=0.0142  frame=0.0972  offset=0.0485  vel=0.0075  (19.8s)
#   [ep 033  step   3250]  total=0.1551  onset=0.0193  frame=0.0763  offset=0.0525  vel=0.0070  (19.7s)
#   [ep 033  step   3260]  total=0.2313  onset=0.0485  frame=0.0861  offset=0.0845  vel=0.0122  (18.9s)
#   [ep 033  step   3270]  total=0.1401  onset=0.0172  frame=0.0654  offset=0.0490  vel=0.0085  (18.5s)
#   [ep 033  step   3280]  total=0.1548  onset=0.0204  frame=0.0682  offset=0.0537  vel=0.0125  (16.3s)
#   [ep 033  step   3290]  total=0.1456  onset=0.0153  frame=0.0740  offset=0.0493  vel=0.0071  (17.4s)
#   [ep 033  step   3300]  total=0.1543  onset=0.0239  frame=0.0688  offset=0.0532  vel=0.0085  (17.4s)
#   train_loss=0.1727  val_loss=0.1648  lr=3.00e-04  time=232s  ETA: ~259min
#
# --- Epoch 34/100 ---
#   [ep 034  step   3310]  total=0.1921  onset=0.0291  frame=0.0883  offset=0.0657  vel=0.0090  (25.0s)
#   [ep 034  step   3320]  total=0.1503  onset=0.0114  frame=0.0900  offset=0.0405  vel=0.0083  (21.7s)
#   [ep 034  step   3330]  total=0.1720  onset=0.0262  frame=0.0822  offset=0.0555  vel=0.0081  (19.0s)
#   [ep 034  step   3340]  total=0.1919  onset=0.0227  frame=0.0991  offset=0.0605  vel=0.0095  (19.5s)
#   [ep 034  step   3350]  total=0.1594  onset=0.0181  frame=0.0796  offset=0.0525  vel=0.0093  (18.8s)
#   [ep 034  step   3360]  total=0.1496  onset=0.0225  frame=0.0705  offset=0.0509  vel=0.0058  (17.7s)
#   [ep 034  step   3370]  total=0.1590  onset=0.0251  frame=0.0673  offset=0.0599  vel=0.0067  (16.1s)
#   [ep 034  step   3380]  total=0.1635  onset=0.0229  frame=0.0712  offset=0.0621  vel=0.0073  (19.3s)
#   [ep 034  step   3390]  total=0.1940  onset=0.0378  frame=0.0736  offset=0.0730  vel=0.0096  (17.2s)
#   [ep 034  step   3400]  total=0.1538  onset=0.0200  frame=0.0757  offset=0.0524  vel=0.0056  (18.3s)
#   train_loss=0.1684  val_loss=0.1574  lr=3.00e-04  time=233s  ETA: ~256min ★ NEW BEST
#
# --- Epoch 35/100 ---
#   [ep 035  step   3410]  total=0.1742  onset=0.0262  frame=0.0792  offset=0.0602  vel=0.0085  (34.8s)
#   [ep 035  step   3420]  total=0.1494  onset=0.0208  frame=0.0631  offset=0.0591  vel=0.0064  (19.5s)
#   [ep 035  step   3430]  total=0.1662  onset=0.0171  frame=0.0829  offset=0.0586  vel=0.0076  (19.3s)
#   [ep 035  step   3440]  total=0.1762  onset=0.0291  frame=0.0767  offset=0.0621  vel=0.0083  (17.3s)
#   [ep 035  step   3450]  total=0.1495  onset=0.0184  frame=0.0737  offset=0.0508  vel=0.0066  (17.8s)
#   [ep 035  step   3460]  total=0.1866  onset=0.0309  frame=0.0869  offset=0.0609  vel=0.0079  (17.6s)
#   [ep 035  step   3470]  total=0.1651  onset=0.0288  frame=0.0699  offset=0.0575  vel=0.0088  (18.4s)
#   [ep 035  step   3480]  total=0.1593  onset=0.0248  frame=0.0710  offset=0.0569  vel=0.0066  (15.9s)
#   [ep 035  step   3490]  total=0.1868  onset=0.0318  frame=0.0795  offset=0.0679  vel=0.0076  (17.4s)
#   [ep 035  step   3500]  total=0.2136  onset=0.0339  frame=0.0980  offset=0.0720  vel=0.0097  (19.7s)
#   train_loss=0.1660  val_loss=0.1569  lr=3.00e-04  time=238s  ETA: ~258min ★ NEW BEST
#
# --- Epoch 36/100 ---
#   [ep 036  step   3510]  total=0.1351  onset=0.0199  frame=0.0634  offset=0.0460  vel=0.0058  (32.4s)
#   [ep 036  step   3520]  total=0.1984  onset=0.0410  frame=0.0748  offset=0.0722  vel=0.0105  (19.7s)
#   [ep 036  step   3530]  total=0.2010  onset=0.0334  frame=0.0866  offset=0.0739  vel=0.0071  (17.7s)
#   [ep 036  step   3540]  total=0.1715  onset=0.0250  frame=0.0808  offset=0.0591  vel=0.0066  (18.4s)
#   [ep 036  step   3550]  total=0.1629  onset=0.0249  frame=0.0713  offset=0.0602  vel=0.0066  (18.7s)
#   [ep 036  step   3560]  total=0.1312  onset=0.0149  frame=0.0638  offset=0.0480  vel=0.0046  (17.6s)
#   [ep 036  step   3570]  total=0.1894  onset=0.0322  frame=0.0840  offset=0.0653  vel=0.0079  (18.7s)
#   [ep 036  step   3580]  total=0.1530  onset=0.0192  frame=0.0744  offset=0.0517  vel=0.0077  (17.3s)
#   [ep 036  step   3590]  total=0.1649  onset=0.0279  frame=0.0726  offset=0.0569  vel=0.0074  (18.8s)
#   [ep 036  step   3600]  total=0.1444  onset=0.0104  frame=0.0866  offset=0.0429  vel=0.0045  (19.8s)
#   train_loss=0.1629  val_loss=0.1580  lr=3.00e-04  time=239s  ETA: ~255min
#
# --- Epoch 37/100 ---
#   [ep 037  step   3610]  total=0.1375  onset=0.0118  frame=0.0774  offset=0.0441  vel=0.0042  (24.1s)
#   [ep 037  step   3620]  total=0.1908  onset=0.0352  frame=0.0786  offset=0.0674  vel=0.0097  (19.1s)
#   [ep 037  step   3630]  total=0.1480  onset=0.0241  frame=0.0655  offset=0.0513  vel=0.0072  (18.4s)
#   [ep 037  step   3640]  total=0.1491  onset=0.0196  frame=0.0719  offset=0.0520  vel=0.0056  (19.5s)
#   [ep 037  step   3650]  total=0.2096  onset=0.0322  frame=0.0992  offset=0.0723  vel=0.0060  (17.8s)
#   [ep 037  step   3660]  total=0.1665  onset=0.0202  frame=0.0852  offset=0.0531  vel=0.0079  (17.9s)
#   [ep 037  step   3670]  total=0.1485  onset=0.0142  frame=0.0780  offset=0.0474  vel=0.0090  (17.5s)
#   [ep 037  step   3680]  total=0.1542  onset=0.0211  frame=0.0756  offset=0.0507  vel=0.0069  (18.0s)
#   [ep 037  step   3690]  total=0.1712  onset=0.0248  frame=0.0790  offset=0.0605  vel=0.0068  (19.2s)
#   [ep 037  step   3700]  total=0.1894  onset=0.0390  frame=0.0713  offset=0.0729  vel=0.0062  (19.4s)
#   train_loss=0.1667  val_loss=0.1607  lr=3.00e-04  time=231s  ETA: ~243min
#
# --- Epoch 38/100 ---
#   [ep 038  step   3710]  total=0.1494  onset=0.0149  frame=0.0829  offset=0.0462  vel=0.0054  (25.7s)
#   [ep 038  step   3720]  total=0.1902  onset=0.0303  frame=0.0853  offset=0.0685  vel=0.0062  (17.5s)
#   [ep 038  step   3730]  total=0.1710  onset=0.0226  frame=0.0839  offset=0.0558  vel=0.0088  (18.5s)
#   [ep 038  step   3740]  total=0.1217  onset=0.0152  frame=0.0556  offset=0.0448  vel=0.0061  (16.6s)
#   [ep 038  step   3750]  total=0.1903  onset=0.0308  frame=0.0900  offset=0.0626  vel=0.0069  (19.5s)
#   [ep 038  step   3760]  total=0.1724  onset=0.0300  frame=0.0706  offset=0.0637  vel=0.0081  (18.8s)
#   [ep 038  step   3770]  total=0.1561  onset=0.0173  frame=0.0841  offset=0.0498  vel=0.0049  (18.2s)
#   [ep 038  step   3780]  total=0.2009  onset=0.0430  frame=0.0709  offset=0.0783  vel=0.0087  (18.0s)
#   [ep 038  step   3790]  total=0.1284  onset=0.0108  frame=0.0733  offset=0.0387  vel=0.0056  (19.1s)
#   [ep 038  step   3800]  total=0.1894  onset=0.0257  frame=0.0888  offset=0.0673  vel=0.0075  (17.3s)
#   train_loss=0.1650  val_loss=0.1595  lr=3.00e-04  time=230s  ETA: ~237min
#
# --- Epoch 39/100 ---
#   [ep 039  step   3810]  total=0.1481  onset=0.0172  frame=0.0774  offset=0.0474  vel=0.0061  (26.5s)
#   [ep 039  step   3820]  total=0.1728  onset=0.0246  frame=0.0804  offset=0.0606  vel=0.0072  (18.2s)
#   [ep 039  step   3830]  total=0.1735  onset=0.0284  frame=0.0751  offset=0.0619  vel=0.0081  (18.6s)
#   [ep 039  step   3840]  total=0.2077  onset=0.0408  frame=0.0801  offset=0.0788  vel=0.0079  (20.4s)
#   [ep 039  step   3850]  total=0.2143  onset=0.0401  frame=0.0859  offset=0.0801  vel=0.0082  (19.2s)
#   [ep 039  step   3860]  total=0.1505  onset=0.0164  frame=0.0827  offset=0.0451  vel=0.0063  (20.7s)
#   [ep 039  step   3870]  total=0.1701  onset=0.0227  frame=0.0848  offset=0.0528  vel=0.0098  (17.3s)
#   [ep 039  step   3880]  total=0.1855  onset=0.0252  frame=0.0878  offset=0.0653  vel=0.0073  (19.1s)
#   [ep 039  step   3890]  total=0.1459  onset=0.0169  frame=0.0782  offset=0.0457  vel=0.0051  (19.2s)
#   [ep 039  step   3900]  total=0.1706  onset=0.0248  frame=0.0783  offset=0.0604  vel=0.0071  (19.2s)
#   train_loss=0.1609  val_loss=0.1582  lr=1.50e-04  time=242s  ETA: ~246min
#
# --- Epoch 40/100 ---
#   [ep 040  step   3910]  total=0.1596  onset=0.0216  frame=0.0778  offset=0.0526  vel=0.0076  (27.1s)
#   [ep 040  step   3920]  total=0.1895  onset=0.0353  frame=0.0762  offset=0.0702  vel=0.0078  (17.1s)
#   [ep 040  step   3930]  total=0.1772  onset=0.0339  frame=0.0684  offset=0.0663  vel=0.0086  (17.0s)
#   [ep 040  step   3940]  total=0.1488  onset=0.0226  frame=0.0613  offset=0.0577  vel=0.0072  (21.4s)
#   [ep 040  step   3950]  total=0.1649  onset=0.0339  frame=0.0651  offset=0.0603  vel=0.0056  (17.9s)
#   [ep 040  step   3960]  total=0.1583  onset=0.0196  frame=0.0823  offset=0.0513  vel=0.0051  (17.5s)
#   [ep 040  step   3970]  total=0.1672  onset=0.0238  frame=0.0765  offset=0.0595  vel=0.0075  (17.8s)
#   [ep 040  step   3980]  total=0.1562  onset=0.0225  frame=0.0727  offset=0.0537  vel=0.0074  (19.1s)
#   [ep 040  step   3990]  total=0.1650  onset=0.0153  frame=0.0962  offset=0.0488  vel=0.0047  (20.5s)
#   [ep 040  step   4000]  total=0.1903  onset=0.0336  frame=0.0800  offset=0.0691  vel=0.0077  (19.2s)
#   train_loss=0.1577  val_loss=0.1523  lr=1.50e-04  time=236s  ETA: ~236min ★ NEW BEST
#
# --- Epoch 41/100 ---
#   [ep 041  step   4010]  total=0.1556  onset=0.0188  frame=0.0827  offset=0.0476  vel=0.0065  (34.3s)
#   [ep 041  step   4020]  total=0.1511  onset=0.0195  frame=0.0722  offset=0.0543  vel=0.0050  (16.8s)
#   [ep 041  step   4030]  total=0.1207  onset=0.0155  frame=0.0571  offset=0.0435  vel=0.0046  (17.7s)
#   [ep 041  step   4040]  total=0.1363  onset=0.0194  frame=0.0634  offset=0.0495  vel=0.0040  (18.7s)
#   [ep 041  step   4050]  total=0.1470  onset=0.0228  frame=0.0649  offset=0.0542  vel=0.0051  (18.5s)
#   [ep 041  step   4060]  total=0.1851  onset=0.0336  frame=0.0677  offset=0.0749  vel=0.0088  (18.2s)
#   [ep 041  step   4070]  total=0.1542  onset=0.0201  frame=0.0720  offset=0.0571  vel=0.0050  (17.7s)
#   [ep 041  step   4080]  total=0.1988  onset=0.0324  frame=0.0839  offset=0.0749  vel=0.0076  (21.2s)
#   [ep 041  step   4090]  total=0.1578  onset=0.0179  frame=0.0773  offset=0.0573  vel=0.0053  (20.6s)
#   [ep 041  step   4100]  total=0.1522  onset=0.0179  frame=0.0803  offset=0.0491  vel=0.0050  (17.9s)
#   train_loss=0.1595  val_loss=0.1553  lr=1.50e-04  time=243s  ETA: ~239min
#
# --- Epoch 42/100 ---
#   [ep 042  step   4110]  total=0.1606  onset=0.0218  frame=0.0692  offset=0.0627  vel=0.0069  (25.8s)
#   [ep 042  step   4120]  total=0.1513  onset=0.0246  frame=0.0656  offset=0.0548  vel=0.0062  (20.6s)
#   [ep 042  step   4130]  total=0.1761  onset=0.0278  frame=0.0752  offset=0.0667  vel=0.0065  (18.2s)
#   [ep 042  step   4140]  total=0.2076  onset=0.0438  frame=0.0779  offset=0.0759  vel=0.0100  (20.2s)
#   [ep 042  step   4150]  total=0.0990  onset=0.0098  frame=0.0501  offset=0.0347  vel=0.0044  (19.1s)
#   [ep 042  step   4160]  total=0.1746  onset=0.0204  frame=0.0929  offset=0.0542  vel=0.0071  (17.8s)
#   [ep 042  step   4170]  total=0.1683  onset=0.0194  frame=0.0840  offset=0.0593  vel=0.0056  (17.1s)
#   [ep 042  step   4180]  total=0.2342  onset=0.0522  frame=0.0836  offset=0.0905  vel=0.0079  (18.4s)
#   [ep 042  step   4190]  total=0.1749  onset=0.0346  frame=0.0629  offset=0.0697  vel=0.0076  (17.6s)
#   [ep 042  step   4200]  total=0.1969  onset=0.0355  frame=0.0819  offset=0.0733  vel=0.0062  (17.2s)
#   train_loss=0.1605  val_loss=0.1537  lr=1.50e-04  time=233s  ETA: ~225min
#
# --- Epoch 43/100 ---
#   [ep 043  step   4210]  total=0.1387  onset=0.0190  frame=0.0634  offset=0.0512  vel=0.0051  (25.4s)
#   [ep 043  step   4220]  total=0.1591  onset=0.0257  frame=0.0686  offset=0.0575  vel=0.0074  (18.9s)
#   [ep 043  step   4230]  total=0.1434  onset=0.0196  frame=0.0640  offset=0.0547  vel=0.0050  (16.0s)
# ...
#   [ep 089  step   8840]  total=0.1670  onset=0.0304  frame=0.0663  offset=0.0641  vel=0.0062  (17.7s)
#   [ep 089  step   8850]  total=0.1410  onset=0.0191  frame=0.0657  offset=0.0512  vel=0.0050  (16.7s)
#   [ep 089  step   8860]  total=0.1498  onset=0.0222  frame=0.0695  offset=0.0526  vel=0.0056  (21.5s)
#   [ep 089  step   8870]  total=0.1157  onset=0.0141  frame=0.0532  offset=0.0440  vel=0.0044  (19.2s)
#   [ep 089  step   8880]  total=0.1684  onset=0.0242  frame=0.0767  offset=0.0617  vel=0.0058  (17.1s)
#   [ep 089  step   8890]  total=0.1364  onset=0.0186  frame=0.0621  offset=0.0498  vel=0.0059  (20.1s)
#   [ep 089  step   8900]  total=0.1263  onset=0.0174  frame=0.0606  offset=0.0431  vel=0.0053  (18.2s)
#   train_loss=0.1504  val_loss=0.1433  lr=2.93e-07  time=228s  ETA: ~42min
#
# --- Epoch 90/100 ---
#   [ep 090  step   8910]  total=0.1383  onset=0.0195  frame=0.0616  offset=0.0524  vel=0.0047  (24.1s)
#   [ep 090  step   8920]  total=0.1320  onset=0.0191  frame=0.0585  offset=0.0477  vel=0.0066  (17.9s)
#   [ep 090  step   8930]  total=0.1405  onset=0.0186  frame=0.0661  offset=0.0513  vel=0.0044  (20.0s)
#   [ep 090  step   8940]  total=0.1398  onset=0.0172  frame=0.0652  offset=0.0533  vel=0.0041  (19.0s)
#   [ep 090  step   8950]  total=0.1412  onset=0.0177  frame=0.0647  offset=0.0543  vel=0.0044  (18.5s)
#   [ep 090  step   8960]  total=0.1375  onset=0.0159  frame=0.0628  offset=0.0539  vel=0.0049  (18.0s)
#   [ep 090  step   8970]  total=0.1672  onset=0.0234  frame=0.0755  offset=0.0631  vel=0.0052  (18.4s)
#   [ep 090  step   8980]  total=0.1572  onset=0.0261  frame=0.0678  offset=0.0579  vel=0.0054  (16.7s)
#   [ep 090  step   8990]  total=0.1424  onset=0.0241  frame=0.0580  offset=0.0549  vel=0.0055  (17.2s)
#   [ep 090  step   9000]  total=0.2104  onset=0.0414  frame=0.0886  offset=0.0744  vel=0.0060  (17.4s)
#   train_loss=0.1460  val_loss=0.1461  lr=2.93e-07  time=227s  ETA: ~38min
#
# --- Epoch 91/100 ---
#   [ep 091  step   9010]  total=0.1425  onset=0.0237  frame=0.0613  offset=0.0534  vel=0.0041  (24.2s)
#   [ep 091  step   9020]  total=0.1968  onset=0.0365  frame=0.0786  offset=0.0721  vel=0.0096  (16.3s)
#   [ep 091  step   9030]  total=0.1266  onset=0.0113  frame=0.0683  offset=0.0424  vel=0.0046  (17.8s)
#   [ep 091  step   9040]  total=0.1711  onset=0.0308  frame=0.0664  offset=0.0682  vel=0.0057  (18.3s)
#   [ep 091  step   9050]  total=0.1248  onset=0.0140  frame=0.0590  offset=0.0474  vel=0.0045  (21.7s)
#   [ep 091  step   9060]  total=0.1309  onset=0.0187  frame=0.0610  offset=0.0471  vel=0.0042  (18.5s)
#   [ep 091  step   9070]  total=0.1554  onset=0.0200  frame=0.0759  offset=0.0540  vel=0.0055  (17.5s)
#   [ep 091  step   9080]  total=0.1460  onset=0.0177  frame=0.0708  offset=0.0512  vel=0.0063  (16.5s)
#   [ep 091  step   9090]  total=0.1660  onset=0.0300  frame=0.0649  offset=0.0642  vel=0.0069  (18.4s)
#   [ep 091  step   9100]  total=0.1486  onset=0.0232  frame=0.0603  offset=0.0600  vel=0.0051  (17.8s)
#   train_loss=0.1492  val_loss=0.1495  lr=2.93e-07  time=226s  ETA: ~34min
#
# --- Epoch 92/100 ---
#   [ep 092  step   9110]  total=0.1588  onset=0.0127  frame=0.0940  offset=0.0478  vel=0.0043  (23.1s)
#   [ep 092  step   9120]  total=0.1733  onset=0.0293  frame=0.0724  offset=0.0633  vel=0.0083  (17.6s)
#   [ep 092  step   9130]  total=0.1290  onset=0.0101  frame=0.0786  offset=0.0359  vel=0.0044  (16.8s)
#   [ep 092  step   9140]  total=0.1536  onset=0.0264  frame=0.0682  offset=0.0539  vel=0.0051  (15.9s)
#   [ep 092  step   9150]  total=0.1644  onset=0.0177  frame=0.0875  offset=0.0529  vel=0.0062  (16.8s)
#   [ep 092  step   9160]  total=0.1336  onset=0.0213  frame=0.0565  offset=0.0494  vel=0.0064  (20.1s)
#   [ep 092  step   9170]  total=0.1504  onset=0.0239  frame=0.0659  offset=0.0549  vel=0.0057  (20.0s)
#   [ep 092  step   9180]  total=0.1664  onset=0.0258  frame=0.0667  offset=0.0643  vel=0.0096  (18.8s)
#   [ep 092  step   9190]  total=0.1362  onset=0.0203  frame=0.0618  offset=0.0489  vel=0.0052  (19.3s)
#   [ep 092  step   9200]  total=0.1636  onset=0.0180  frame=0.0836  offset=0.0571  vel=0.0049  (18.7s)
#   train_loss=0.1495  val_loss=0.1423  lr=2.93e-07  time=227s  ETA: ~30min
#
# --- Epoch 93/100 ---
#   [ep 093  step   9210]  total=0.1643  onset=0.0285  frame=0.0695  offset=0.0598  vel=0.0065  (23.6s)
#   [ep 093  step   9220]  total=0.1369  onset=0.0167  frame=0.0691  offset=0.0461  vel=0.0049  (18.2s)
#   [ep 093  step   9230]  total=0.1551  onset=0.0161  frame=0.0874  offset=0.0470  vel=0.0046  (19.8s)
#   [ep 093  step   9240]  total=0.1991  onset=0.0412  frame=0.0809  offset=0.0703  vel=0.0067  (19.1s)
#   [ep 093  step   9250]  total=0.1127  onset=0.0146  frame=0.0534  offset=0.0402  vel=0.0046  (18.8s)
#   [ep 093  step   9260]  total=0.1373  onset=0.0165  frame=0.0646  offset=0.0522  vel=0.0039  (17.3s)
#   [ep 093  step   9270]  total=0.1433  onset=0.0156  frame=0.0722  offset=0.0516  vel=0.0039  (19.0s)
#   [ep 093  step   9280]  total=0.1154  onset=0.0119  frame=0.0591  offset=0.0409  vel=0.0036  (18.4s)
#   [ep 093  step   9290]  total=0.1249  onset=0.0169  frame=0.0548  offset=0.0492  vel=0.0040  (17.0s)
#   [ep 093  step   9300]  total=0.1781  onset=0.0254  frame=0.0818  offset=0.0646  vel=0.0063  (16.6s)
#   train_loss=0.1491  val_loss=0.1495  lr=1.46e-07  time=228s  ETA: ~27min
#
# --- Epoch 94/100 ---
#   [ep 094  step   9310]  total=0.1426  onset=0.0216  frame=0.0601  offset=0.0565  vel=0.0044  (24.3s)
#   [ep 094  step   9320]  total=0.1527  onset=0.0205  frame=0.0701  offset=0.0566  vel=0.0054  (17.6s)
#   [ep 094  step   9330]  total=0.1942  onset=0.0349  frame=0.0824  offset=0.0713  vel=0.0056  (18.2s)
#   [ep 094  step   9340]  total=0.1644  onset=0.0247  frame=0.0727  offset=0.0617  vel=0.0054  (20.0s)
#   [ep 094  step   9350]  total=0.1297  onset=0.0133  frame=0.0665  offset=0.0450  vel=0.0049  (17.2s)
#   [ep 094  step   9360]  total=0.1585  onset=0.0197  frame=0.0776  offset=0.0561  vel=0.0052  (18.8s)
#   [ep 094  step   9370]  total=0.1526  onset=0.0179  frame=0.0759  offset=0.0529  vel=0.0059  (18.8s)
#   [ep 094  step   9380]  total=0.0969  onset=0.0096  frame=0.0485  offset=0.0344  vel=0.0044  (16.8s)
#   [ep 094  step   9390]  total=0.1426  onset=0.0174  frame=0.0702  offset=0.0505  vel=0.0045  (19.7s)
#   [ep 094  step   9400]  total=0.1363  onset=0.0191  frame=0.0622  offset=0.0509  vel=0.0041  (16.4s)
#   train_loss=0.1500  val_loss=0.1433  lr=1.46e-07  time=228s  ETA: ~23min
#
# --- Epoch 95/100 ---
#   [ep 095  step   9410]  total=0.1566  onset=0.0229  frame=0.0694  offset=0.0584  vel=0.0059  (24.8s)
#   [ep 095  step   9420]  total=0.1524  onset=0.0173  frame=0.0796  offset=0.0494  vel=0.0060  (17.3s)
#   [ep 095  step   9430]  total=0.1815  onset=0.0304  frame=0.0701  offset=0.0751  vel=0.0060  (19.1s)
#   [ep 095  step   9440]  total=0.1680  onset=0.0272  frame=0.0757  offset=0.0593  vel=0.0057  (19.2s)
#   [ep 095  step   9450]  total=0.1008  onset=0.0079  frame=0.0521  offset=0.0375  vel=0.0033  (16.8s)
#   [ep 095  step   9460]  total=0.1674  onset=0.0213  frame=0.0840  offset=0.0545  vel=0.0076  (18.9s)
#   [ep 095  step   9470]  total=0.1226  onset=0.0138  frame=0.0613  offset=0.0434  vel=0.0041  (20.0s)
#   [ep 095  step   9480]  total=0.1536  onset=0.0213  frame=0.0703  offset=0.0570  vel=0.0050  (17.0s)
#   [ep 095  step   9490]  total=0.1412  onset=0.0194  frame=0.0641  offset=0.0516  vel=0.0061  (18.4s)
#   [ep 095  step   9500]  total=0.1435  onset=0.0208  frame=0.0624  offset=0.0538  vel=0.0065  (15.0s)
#   train_loss=0.1507  val_loss=0.1439  lr=1.46e-07  time=226s  ETA: ~19min
#
# --- Epoch 96/100 ---
#   [ep 096  step   9510]  total=0.1640  onset=0.0242  frame=0.0791  offset=0.0544  vel=0.0063  (24.0s)
#   [ep 096  step   9520]  total=0.1633  onset=0.0271  frame=0.0656  offset=0.0646  vel=0.0059  (15.8s)
#   [ep 096  step   9530]  total=0.1552  onset=0.0273  frame=0.0613  offset=0.0606  vel=0.0059  (18.8s)
#   [ep 096  step   9540]  total=0.1554  onset=0.0231  frame=0.0673  offset=0.0596  vel=0.0054  (19.6s)
#   [ep 096  step   9550]  total=0.1353  onset=0.0201  frame=0.0634  offset=0.0469  vel=0.0049  (18.5s)
#   [ep 096  step   9560]  total=0.1786  onset=0.0316  frame=0.0743  offset=0.0676  vel=0.0052  (18.5s)
#   [ep 096  step   9570]  total=0.1329  onset=0.0174  frame=0.0590  offset=0.0521  vel=0.0044  (19.3s)
#   [ep 096  step   9580]  total=0.1504  onset=0.0226  frame=0.0700  offset=0.0525  vel=0.0053  (20.1s)
#   [ep 096  step   9590]  total=0.1970  onset=0.0322  frame=0.0786  offset=0.0786  vel=0.0075  (17.2s)
#   [ep 096  step   9600]  total=0.1801  onset=0.0290  frame=0.0746  offset=0.0706  vel=0.0058  (17.7s)
#   train_loss=0.1507  val_loss=0.1452  lr=1.46e-07  time=230s  ETA: ~15min
#
# --- Epoch 97/100 ---
#   [ep 097  step   9610]  total=0.1131  onset=0.0126  frame=0.0574  offset=0.0391  vel=0.0039  (22.2s)
#   [ep 097  step   9620]  total=0.1488  onset=0.0232  frame=0.0625  offset=0.0570  vel=0.0061  (17.0s)
#   [ep 097  step   9630]  total=0.1393  onset=0.0177  frame=0.0660  offset=0.0512  vel=0.0044  (19.3s)
#   [ep 097  step   9640]  total=0.1439  onset=0.0158  frame=0.0776  offset=0.0441  vel=0.0064  (19.0s)
#   [ep 097  step   9650]  total=0.1929  onset=0.0345  frame=0.0771  offset=0.0758  vel=0.0057  (17.2s)
#   [ep 097  step   9660]  total=0.1933  onset=0.0367  frame=0.0807  offset=0.0695  vel=0.0065  (20.6s)
#   [ep 097  step   9670]  total=0.2023  onset=0.0352  frame=0.0831  offset=0.0763  vel=0.0076  (19.6s)
#   [ep 097  step   9680]  total=0.1711  onset=0.0257  frame=0.0793  offset=0.0601  vel=0.0059  (18.6s)
#   [ep 097  step   9690]  total=0.1196  onset=0.0126  frame=0.0570  offset=0.0454  vel=0.0046  (17.3s)
#   [ep 097  step   9700]  total=0.1503  onset=0.0211  frame=0.0718  offset=0.0511  vel=0.0063  (17.3s)
#   train_loss=0.1510  val_loss=0.1474  lr=7.32e-08  time=228s  ETA: ~11min
#
# --- Epoch 98/100 ---
#   [ep 098  step   9710]  total=0.1454  onset=0.0236  frame=0.0621  offset=0.0542  vel=0.0055  (23.3s)
#   [ep 098  step   9720]  total=0.1697  onset=0.0296  frame=0.0661  offset=0.0676  vel=0.0065  (18.4s)
#   [ep 098  step   9730]  total=0.1320  onset=0.0174  frame=0.0607  offset=0.0486  vel=0.0052  (18.0s)
#   [ep 098  step   9740]  total=0.1988  onset=0.0354  frame=0.0810  offset=0.0747  vel=0.0077  (17.5s)
#   [ep 098  step   9750]  total=0.1244  onset=0.0098  frame=0.0711  offset=0.0391  vel=0.0045  (19.5s)
#   [ep 098  step   9760]  total=0.1423  onset=0.0280  frame=0.0529  offset=0.0555  vel=0.0058  (17.1s)
#   [ep 098  step   9770]  total=0.1325  onset=0.0141  frame=0.0673  offset=0.0472  vel=0.0039  (19.1s)
#   [ep 098  step   9780]  total=0.1426  onset=0.0250  frame=0.0555  offset=0.0576  vel=0.0045  (17.9s)
#   [ep 098  step   9790]  total=0.1451  onset=0.0175  frame=0.0672  offset=0.0548  vel=0.0056  (19.1s)
#   [ep 098  step   9800]  total=0.1637  onset=0.0292  frame=0.0639  offset=0.0647  vel=0.0059  (15.4s)
#   train_loss=0.1499  val_loss=0.1477  lr=7.32e-08  time=225s  ETA: ~7min
#
# --- Epoch 99/100 ---
#   [ep 099  step   9810]  total=0.1439  onset=0.0226  frame=0.0586  offset=0.0574  vel=0.0052  (26.5s)
#   [ep 099  step   9820]  total=0.1509  onset=0.0188  frame=0.0751  offset=0.0522  vel=0.0048  (20.5s)
#   [ep 099  step   9830]  total=0.1605  onset=0.0169  frame=0.0842  offset=0.0543  vel=0.0051  (18.2s)
#   [ep 099  step   9840]  total=0.1340  onset=0.0144  frame=0.0678  offset=0.0475  vel=0.0043  (19.7s)
#   [ep 099  step   9850]  total=0.1523  onset=0.0195  frame=0.0736  offset=0.0538  vel=0.0055  (17.3s)
#   [ep 099  step   9860]  total=0.1386  onset=0.0207  frame=0.0613  offset=0.0524  vel=0.0043  (16.4s)
#   [ep 099  step   9870]  total=0.1368  onset=0.0124  frame=0.0756  offset=0.0452  vel=0.0037  (18.0s)
#   [ep 099  step   9880]  total=0.1326  onset=0.0196  frame=0.0609  offset=0.0476  vel=0.0046  (18.0s)
#   [ep 099  step   9890]  total=0.1372  onset=0.0200  frame=0.0575  offset=0.0542  vel=0.0055  (17.0s)
#   [ep 099  step   9900]  total=0.1211  onset=0.0141  frame=0.0567  offset=0.0459  vel=0.0044  (16.2s)
#   train_loss=0.1489  val_loss=0.1462  lr=7.32e-08  time=228s  ETA: ~4min
#
# --- Epoch 100/100 ---
#   [ep 100  step   9910]  total=0.1306  onset=0.0142  frame=0.0624  offset=0.0498  vel=0.0043  (23.8s)
#   [ep 100  step   9920]  total=0.1329  onset=0.0194  frame=0.0573  offset=0.0514  vel=0.0048  (20.6s)
#   [ep 100  step   9930]  total=0.1655  onset=0.0305  frame=0.0667  offset=0.0624  vel=0.0059  (22.2s)
#   [ep 100  step   9940]  total=0.1558  onset=0.0236  frame=0.0690  offset=0.0582  vel=0.0051  (21.5s)
#   [ep 100  step   9950]  total=0.1523  onset=0.0246  frame=0.0634  offset=0.0589  vel=0.0053  (18.6s)
#   [ep 100  step   9960]  total=0.1459  onset=0.0170  frame=0.0727  offset=0.0505  vel=0.0057  (17.3s)
#   [ep 100  step   9970]  total=0.1309  onset=0.0173  frame=0.0578  offset=0.0515  vel=0.0043  (19.9s)
#   [ep 100  step   9980]  total=0.1342  onset=0.0223  frame=0.0541  offset=0.0503  vel=0.0076  (18.9s)
#   [ep 100  step   9990]  total=0.1746  onset=0.0298  frame=0.0722  offset=0.0662  vel=0.0065  (17.5s)
#   [ep 100  step  10000]  total=0.1397  onset=0.0199  frame=0.0648  offset=0.0500  vel=0.0050  (18.5s)
#   train_loss=0.1488  val_loss=0.1421  lr=7.32e-08  time=240s ★ NEW BEST
#
#
# ============================================================
#   TRAINING COMPLETE
# ============================================================
#   Run directory     : /content/drive/MyDrive/piano_amt/runs/OF_medium_test
#   Epochs trained    : 1→100 (100 epochs)
#   Best val loss     : 0.1421 (epoch 100)
#   Session time      : 24366.8 seconds
#   Total train time  : 24076.1 seconds
#   Avg epoch time    : 240.8 seconds
#
#   Saved files:
#     ✓ Config: /content/drive/MyDrive/piano_amt/runs/OF_medium_test/config.json
#     ✓ Metrics: /content/drive/MyDrive/piano_amt/runs/OF_medium_test/metrics.json
#     ✓ Timing summary: /content/drive/MyDrive/piano_amt/runs/OF_medium_test/timing_summary.json
#     ✓ Latest checkpoint: /content/drive/MyDrive/piano_amt/runs/OF_medium_test/checkpoints/latest.pt
#     ✓ Best checkpoint: /content/drive/MyDrive/piano_amt/runs/OF_medium_test/checkpoints/best.pt
#     ✓ Epoch checkpoints (54):
#       - epoch_001_valloss_0.5101.pt
#       - epoch_002_valloss_0.4550.pt
#       - epoch_003_valloss_0.4391.pt
#       - epoch_004_valloss_0.4182.pt
#       - epoch_005.pt
#       - epoch_005_valloss_0.4009.pt
#       - epoch_006_valloss_0.3962.pt
#       - epoch_007_valloss_0.3790.pt
#       - epoch_008_valloss_0.3539.pt
#       - epoch_009_valloss_0.3201.pt
#       - epoch_010.pt
#       - epoch_010_valloss_0.3036.pt
#       - epoch_012_valloss_0.2740.pt
#       - epoch_013_valloss_0.2437.pt
#       - epoch_014_valloss_0.2300.pt
#       - epoch_015.pt
#       - epoch_015_valloss_0.2233.pt
#       - epoch_016_valloss_0.2061.pt
#       - epoch_018_valloss_0.2043.pt
#       - epoch_020.pt
#       - epoch_020_valloss_0.1962.pt
#       - epoch_021_valloss_0.1892.pt
#       - epoch_022_valloss_0.1871.pt
#       - epoch_023_valloss_0.1820.pt
#       - epoch_024_valloss_0.1762.pt
#       - epoch_025.pt
#       - epoch_025_valloss_0.1758.pt
#       - epoch_028_valloss_0.1743.pt
#       - epoch_029_valloss_0.1628.pt
#       - epoch_030.pt
#       - epoch_034_valloss_0.1574.pt
#       - epoch_035.pt
#       - epoch_035_valloss_0.1569.pt
#       - epoch_040.pt
#       - epoch_040_valloss_0.1523.pt
#       - epoch_044_valloss_0.1501.pt
#       - epoch_045.pt
#       - epoch_050.pt
#       - epoch_050_valloss_0.1459.pt
#       - epoch_055.pt
#       - epoch_055_valloss_0.1450.pt
#       - epoch_060.pt
#       - epoch_060_valloss_0.1441.pt
#       - epoch_064_valloss_0.1431.pt
#       - epoch_065.pt
#       - epoch_070.pt
#       - epoch_075.pt
#       - epoch_077_valloss_0.1421.pt
#       - epoch_080.pt
#       - epoch_085.pt
#       - epoch_090.pt
#       - epoch_095.pt
#       - epoch_100.pt
#       - epoch_100_valloss_0.1421.pt
#     ✓ Loss curve plots (100) saved in: /content/drive/MyDrive/piano_amt/runs/OF_medium_test/plots
# ============================================================
#
# ✓ Training complete. Run directory: /content/drive/MyDrive/piano_amt/runs/OF_medium_test
#   Best val loss : 0.1421
#   Best checkpoint: /content/drive/MyDrive/piano_amt/runs/OF_medium_test/checkpoints/best.pt

# %% [markdown]
# ## Cell 6 — Visualise training curves
#
# Plot the saved loss curves from this run. Also saves a final high-res PNG
# for the report.

# %%
# ═══════════════════════════════════════════════════════════════════════════
# TRAINING SUMMARY — run after training completes
# ═══════════════════════════════════════════════════════════════════════════
import json, os
import matplotlib.pyplot as plt

run_dir = f'{RUNS_DIR}/OF_medium_test'  # <-- match your run_name
metrics_path = os.path.join(run_dir, 'metrics.json')

with open(metrics_path, 'r') as f:
    h = json.load(f)

ep = h['epoch']

print("═" * 65)
print("TRAINING SUMMARY")
print("═" * 65)
print(f"  Total epochs:  {len(ep)}  (epoch {ep[0]} → {ep[-1]})")
print(f"  Final train loss: {h['train_loss'][-1]:.6f}")
print(f"  Final val loss:   {h['val_loss'][-1]:.6f}")

# Find best epoch
best_idx = min(range(len(h['val_loss'])), key=lambda i: h['val_loss'][i])
print(f"  Best val loss:    {h['val_loss'][best_idx]:.6f}  (epoch {ep[best_idx]})")
print(f"  Final LR:         {h['lr'][-1]:.2e}")
print(f"  Starting LR:      {h['lr'][0]:.2e}")

# Plateau detection
last_50 = h['val_loss'][-50:] if len(h['val_loss']) >= 50 else h['val_loss']
if max(last_50) - min(last_50) < 0.005:
    print(f"  ⚠ PLATEAU: last {len(last_50)} epochs vary by only {max(last_50)-min(last_50):.5f}")

# Overfitting check
if h['val_loss'][-1] > h['val_loss'][best_idx] * 1.05:
    pct = ((h['val_loss'][-1] / h['val_loss'][best_idx]) - 1) * 100
    print(f"  ⚠ POSSIBLE OVERFIT: final val is {pct:.1f}% above best")

# Timing
if 'epoch_time_seconds' in h and h['epoch_time_seconds']:
    times = h['epoch_time_seconds']
    total_hrs = sum(times) / 3600
    print(f"  Total training time: {total_hrs:.1f} hours")
    print(f"  Avg epoch time: {sum(times)/len(times):.0f}s")

# ── Key epochs table (every 50th + first + last + best) ────────────────
print(f"\n{'Epoch':>6} {'Train Loss':>12} {'Val Loss':>12} {'LR':>12}")
print("─" * 46)

show_epochs = set([0, best_idx, len(ep)-1])
show_epochs.update(range(0, len(ep), 5))  # every 50 epochs
show_epochs.update(range(0, len(ep), 10))  # every 100 epochs

for i in sorted(show_epochs):
    if i < len(ep):
        marker = " ★" if i == best_idx else ""
        print(f"{ep[i]:>6} {h['train_loss'][i]:>12.6f} {h['val_loss'][i]:>12.6f} {h['lr'][i]:>12.2e}{marker}")
# Out:
# ═════════════════════════════════════════════════════════════════
# TRAINING SUMMARY
# ═════════════════════════════════════════════════════════════════
#   Total epochs:  100  (epoch 1 → 100)
#   Final train loss: 0.148825
#   Final val loss:   0.142071
#   Best val loss:    0.142071  (epoch 100)
#   Final LR:         7.32e-08
#   Starting LR:      6.00e-04
#   Total training time: 6.7 hours
#   Avg epoch time: 241s
#
#  Epoch   Train Loss     Val Loss           LR
# ──────────────────────────────────────────────
#      1     1.313721     0.510112     6.00e-04
#      6     0.420144     0.396244     6.00e-04
#     11     0.306436     0.304778     6.00e-04
#     16     0.223632     0.206093     6.00e-04
#     21     0.204420     0.189162     6.00e-04
#     26     0.191309     0.180467     6.00e-04
#     31     0.182208     0.171539     6.00e-04
#     36     0.162867     0.157968     3.00e-04
#     41     0.159469     0.155260     1.50e-04
#     46     0.157480     0.151363     1.50e-04
#     51     0.153101     0.147397     7.50e-05
#     56     0.154680     0.148104     3.75e-05
#     61     0.150951     0.146177     1.87e-05
#     66     0.154490     0.152717     1.87e-05
#     71     0.149472     0.146419     9.37e-06
#     76     0.149301     0.145060     2.34e-06
#     81     0.150405     0.144825     1.17e-06
#     86     0.151910     0.147708     5.86e-07
#     91     0.149242     0.149493     2.93e-07
#     96     0.150726     0.145162     1.46e-07
#    100     0.148825     0.142071     7.32e-08 ★

# %%
import matplotlib
matplotlib.use('Agg')   # headless
import matplotlib.pyplot as plt
import json

from evaluate.plots import plot_training_curves

metrics_path = run_dir.root / 'metrics.json'
save_path    = run_dir.plots / 'training_curves_final.png'

plot_training_curves(
    metrics_path = metrics_path,
    save_path    = save_path,
    title        = f"Training curves — {CONFIG['run_name']}",
)

# Also display in notebook
from IPython.display import Image
Image(str(save_path))
# Out:
# Training curves saved → /content/drive/MyDrive/piano_amt/runs/OF_medium_test/plots/training_curves_final.png

# %% [markdown]
# ## Cell 7 — Evaluate on validation set
#
# Runs the best checkpoint on the validation split and computes all AMT metrics.
# Results saved to `runs/<run_name>/eval_validation/`.

# %%
from models.onsets_frames.evaluate import run_evaluation

import mir_eval


# best_ckpt = str(run_dir.best_checkpoint_path())
# print(f"Evaluating: {best_ckpt}")
best_ckpt = "/content/drive/MyDrive/piano_amt/runs/OF_medium_test/checkpoints/best.pt"
print(f"Evaluating: {best_ckpt}")


val_summary = run_evaluation(
    checkpoint_path  = best_ckpt,
    maestro_root     = MAESTRO_ROOT,
    cache_dir        = CACHE_DIR,
    split            = 'validation',
    max_files        = CONFIG['max_files'],    # same subset for fair comparison
    save_midi        = True,
    save_plots       = True,
    model_complexity = CONFIG['model_complexity'],
    onset_threshold  = 0.5,
    frame_threshold  = 0.5,
    onset_tolerance  = 0.05,
    offset_ratio     = 0.2,
    offset_min_tolerance = 0.05,
    velocity_tolerance   = 0.1,

)
# Out:
# Evaluating: /content/drive/MyDrive/piano_amt/runs/OF_medium_test/checkpoints/best.pt
# Device: NVIDIA A100-SXM4-80GB
# Loaded checkpoint: /content/drive/MyDrive/piano_amt/runs/OF_medium_test/checkpoints/best.pt
#   Trained for 100 epochs, val_loss=0.1421
#   Model parameters: 26,491,256
#
# Evaluating 137/137 files from 'validation' split...
#   Strategy: full-length single-pass inference
#
#   Evaluated 137/137 files in 1908.3s
#
#           — Decoding + evaluation protocol —
#   Decode thresholds:
#     onset_threshold:   0.50
#     frame_threshold:   0.50
#   Evaluation tolerances:
#     onset_tolerance:   50 ms
#     pitch_tolerance:   0.25 (25 cents)
#     offset_ratio:      0.2
#     offset_min_tol:    50 ms
#     velocity_tolerance:0.1
#     mir_eval version:  0.8.2
#
#   Results saved → /content/drive/MyDrive/piano_amt/runs/OF_medium_test/eval_validation
# ============================================================
#
#
# ============================================================
#   EVALUATION SUMMARY — validation split (n=137)
# ============================================================
#   Dataset:    MAESTRO v3.0.0, validation split
#   Model:      OnsetsAndFrames (complexity=48, 26,491,256 params)
#   Checkpoint: epoch 100, val_loss=0.1421
#   GPU:        NVIDIA A100-SXM4-80GB
#   Eval time:  1908.3s (13.9s/file)
#
#                  — Primary metrics —
#   Metric                                     P        R       F1
#   ------------------------------------------------------------
#   Note (onset+pitch)                    0.6190   0.9160   0.7382
#   Note w/ offset                        0.2834   0.4170   0.3372
#   Note w/ offset+vel                    0.2596   0.3817   0.3088
#   Frame                                 0.6267   0.6761   0.6472
#
#   Avg notes/file:  pred=6994  gt=4667  ratio=1.50
#
#            — Supplementary error analysis —
#   Offset MAE                           198.7 ms
#   Onset MAE                            10.5 ms
#   Chord completeness                   0.9107
#   Duplicate note rate                  0.2790
#
# Validation summary:
#   onset_f1                           : 0.0000
#   frame_f1                           : 0.6472
#   note_with_offset_f1                : 0.3372
#   note_with_offset_vel_f1            : 0.3088
#   ea_offset_mae_ms                   : 198.6975
#   ea_chord_completeness              : 0.9107

# %% [markdown]
# ## Cell 8 — Evaluate on test set
#
# Only run this once per stage (after hyperparameters are finalised).
# Results saved to `runs/<run_name>/eval_test/`.

# %%
from models.onsets_frames.evaluate import run_evaluation

import mir_eval



best_ckpt = "/content/drive/MyDrive/piano_amt/runs/OF_medium_test/checkpoints/best.pt"
print(f"Evaluating: {best_ckpt}")


test_summary = run_evaluation(
    checkpoint_path  = best_ckpt,
    maestro_root     = MAESTRO_ROOT,
    cache_dir        = CACHE_DIR,
    split            = 'test',
    max_files        = CONFIG['max_files'],
    save_midi        = True,
    save_plots       = True,
    model_complexity = CONFIG['model_complexity'],
    onset_threshold  = 0.5,
    frame_threshold  = 0.5,
    onset_tolerance  = 0.05,
    offset_ratio     = 0.2,
    offset_min_tolerance = 0.05,
    velocity_tolerance   = 0.1,

)
# Out:
# Evaluating: /content/drive/MyDrive/piano_amt/runs/OF_medium_test/checkpoints/best.pt
# Device: NVIDIA A100-SXM4-80GB
# Loaded checkpoint: /content/drive/MyDrive/piano_amt/runs/OF_medium_test/checkpoints/best.pt
#   Trained for 100 epochs, val_loss=0.1421
#   Model parameters: 26,491,256
#
# Evaluating 177/177 files from 'test' split...
#   Strategy: full-length single-pass inference (cuDNN disabled for LSTM)
#   Thresholds: onset=0.5, frame=0.5
#   [10/177] MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R... 5.6s
#   [20/177] MIDI-Unprocessed_10_R2_2008_01-05_ORIG_M... 4.2s
#   [30/177] MIDI-Unprocessed_14_R1_2008_01-05_ORIG_M... 6.0s
#   [40/177] MIDI-Unprocessed_04_R3_2008_01-07_ORIG_M... 10.8s
#   [50/177] MIDI-Unprocessed_08_R1_2009_01-04_ORIG_M... 6.3s
#   [60/177] MIDI-Unprocessed_23_R2_2011_MID--AUDIO_R... 7.0s
#   [70/177] MIDI-Unprocessed_03_R1_2009_03-08_ORIG_M... 10.6s
#   [80/177] MIDI-Unprocessed_24_R1_2011_MID--AUDIO_R... 3.9s
#   [90/177] MIDI-Unprocessed_22_R2_2011_MID--AUDIO_R... 10.6s
#   [100/177] ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_07... 9.2s
#   [110/177] MIDI-Unprocessed_14_R1_2008_01-05_ORIG_M... 5.1s
#   [120/177] ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_14... 6.8s
#   [130/177] MIDI-Unprocessed_046_PIANO046_MID--AUDIO... 6.8s
#   [140/177] MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-fr... 12.2s
#   [150/177] MIDI-Unprocessed_17_R1_2009_01-03_ORIG_M... 9.4s
#   [160/177] MIDI-Unprocessed_08_R1_2008_01-05_ORIG_M... 6.1s
#   [170/177] MIDI-Unprocessed_03_R2_2011_MID--AUDIO_R... 4.0s
#
#   Evaluated 177/177 files in 1975.7s
#
# ============================================================
#   EVALUATION SUMMARY — test split (n=177)
# ============================================================
#   Dataset:    MAESTRO v3.0.0, test split
#   Model:      OnsetsAndFrames (complexity=48, 26,491,256 params)
#   Checkpoint: epoch 100, val_loss=0.1421
#   GPU:        NVIDIA A100-SXM4-80GB
#   Eval time:  1975.7s (11.2s/file)
#
#     — Primary metrics (Hawthorne 2018a Table 1) —
#   Metric                                     P        R       F1
#   ------------------------------------------------------------
#   Note (onset+pitch)                    0.6319   0.9171   0.7475
#   Note w/ offset                        0.3132   0.4526   0.3698
#   Note w/ offset+vel                    0.2876   0.4156   0.3396
#   Frame                                 0.6494   0.6889   0.6663
#
#   Avg notes/file:  pred=6218  gt=4189  ratio=1.48
#
#            — Supplementary error analysis —
#   Offset MAE                           172.3 ms
#   Onset MAE                            10.3 ms
#   Chord completeness                   0.9112
#   Duplicate note rate                  0.2759
#
#                — Evaluation protocol —
#   onset_tolerance:   50 ms
#   pitch_tolerance:   0.25 (25 cents)
#   offset_ratio:      0.2
#   offset_min_tol:    50 ms
#   velocity_tolerance:0.1
#   mir_eval version:  0.8.2
#
#   Results saved → /content/drive/MyDrive/piano_amt/runs/OF_medium_test/eval_test
# ============================================================
#
#
# Test summary:
#   onset_f1                           : 0.0000
#   frame_f1                           : 0.6663
#   note_with_offset_f1                : 0.3698
#   ea_offset_mae_ms                   : 172.3464
#   ea_chord_completeness              : 0.9112

# %%
from src.dataset import load_from_cache, _cache_path
from src.constants import MAX_SEGMENT_FRAMES, FRAMES_PER_SECOND
import torch, pandas as pd
from pathlib import Path

# Load one file directly
csv_files = sorted(Path(MAESTRO_ROOT).glob("*.csv"))
df = pd.read_csv(csv_files[0])
val_df = df[df["split"] == "validation"].reset_index(drop=True)
row = val_df.iloc[0]
audio_path = str(Path(MAESTRO_ROOT) / row["audio_filename"])
cp = _cache_path(audio_path, CACHE_DIR)

data = load_from_cache(cp)
mel = data["mel"]  # (229, T)

# Run model
model.eval()
with torch.no_grad():
    out = model(mel.unsqueeze(0).to(device))

pred_onset = out["onset"][0].cpu()   # (T, 88)
pred_frame = out["frame"][0].cpu()

print(f"mel shape      : {mel.shape}")
print(f"pred_onset     : min={pred_onset.min():.4f}  max={pred_onset.max():.4f}  mean={pred_onset.mean():.4f}")
print(f"pred_frame     : min={pred_frame.min():.4f}  max={pred_frame.max():.4f}  mean={pred_frame.mean():.4f}")
print(f"onset > 0.5    : {(pred_onset > 0.5).sum().item()} frames")
print(f"frame > 0.5    : {(pred_frame > 0.5).sum().item()} frames")
print(f"gt onset sum   : {data['onset'].sum().item():.0f}")
print(f"gt frame sum   : {data['frame'].sum().item():.0f}")
# Out:
# mel shape      : torch.Size([229, 12510])
# pred_onset     : min=0.4385  max=0.5575  mean=0.5022
# pred_frame     : min=0.4568  max=0.5540  mean=0.5002
# onset > 0.5    : 645568 frames
# frame > 0.5    : 584784 frames
# gt onset sum   : 4019
# gt frame sum   : 20320

# %%
import json
with open('/content/drive/MyDrive/piano_amt/runs/OF_medium_test/metrics.json') as f:
    m = json.load(f)
print("Onset loss first 5 epochs:", m['train_onset'][:5])
print("Onset loss last 5 epochs:",  m['train_onset'][-5:])
print("Val loss progression:",       m['val_loss'][:10])
# Out:
# Onset loss first 5 epochs: [0.15136526666581632, 0.12481648840010166, 0.12154743149876594, 0.10359136916697026, 0.09480066314339637]
# Onset loss last 5 epochs: [0.02190119670704007, 0.022012700131163, 0.021764568015933038, 0.021466331565752627, 0.02147908365353942]
# Val loss progression: [0.5101123293385889, 0.4550464109782755, 0.43907734882222477, 0.4181925382492316, 0.4009467074035728, 0.3962444299764007, 0.37898750418294086, 0.3539101929560195, 0.3201494769458353, 0.30361679283371806]

# %%
# Run this on your actual data to get the exact value
import torch
from src.dataset import MAESTRODataset, _cache_path
from src.constants import MAX_SEGMENT_FRAMES
from pathlib import Path
import pandas as pd

csv_files = sorted(Path(MAESTRO_ROOT).glob("*.csv"))
df = pd.read_csv(csv_files[0])
train_df = df[df["split"] == "train"].head(100)

total_pos = 0
total_neg = 0

for _, row in train_df.iterrows():
    audio_path = str(Path(MAESTRO_ROOT) / row["audio_filename"])
    cp = _cache_path(audio_path, CACHE_DIR)
    if cp.exists():
        import numpy as np
        data = np.load(str(cp))
        onset = data["onset"]
        total_pos += (onset > 0.5).sum()
        total_neg += (onset <= 0.5).sum()

ratio = total_neg / total_pos
print(f"Negative frames : {total_neg:,}")
print(f"Positive frames : {total_pos:,}")
print(f"Ratio (theoretical pos_weight): {ratio:.1f}")
# Out:
# Negative frames : 136,721,063
# Positive frames : 474,281
# Ratio (theoretical pos_weight): 288.3

# %%
# Look at one file's onset roll directly
import numpy as np
from src.dataset import _cache_path
from pathlib import Path
import pandas as pd

csv_files = sorted(Path(MAESTRO_ROOT).glob("*.csv"))
df = pd.read_csv(csv_files[0])
row = df[df["split"] == "train"].iloc[0]
audio_path = str(Path(MAESTRO_ROOT) / row["audio_filename"])
cp = _cache_path(audio_path, CACHE_DIR)

data = np.load(str(cp))
onset  = data["onset"]
frame  = data["frame"]

print(f"Piece length       : {onset.shape[0]} frames")
print(f"Onset shape        : {onset.shape}")
print(f"Onset sum          : {(onset > 0.5).sum()}")
print(f"Frame sum          : {(frame > 0.5).sum()}")
print(f"Onset max value    : {onset.max():.4f}")
print(f"Onset unique values: {np.unique(onset[:100, :20])}")
print(f"Onset ratio        : {(onset <= 0.5).sum() / max((onset > 0.5).sum(), 1):.1f}")
print(f"Frame ratio        : {(frame <= 0.5).sum() / max((frame > 0.5).sum(), 1):.1f}")
# Out:
# Piece length       : 22009 frames
# Onset shape        : (22009, 88)
# Onset sum          : 4197
# Frame sum          : 56300
# Onset max value    : 1.0000
# Onset unique values: [0.]
# Onset ratio        : 460.5
# Frame ratio        : 33.4
